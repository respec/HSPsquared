# %% [markdown]
# HDF5 for HSP2 Input & Output Storage
# ===
#
# [HDF5](https://www.hdfgroup.org/solutions/hdf5/) (Hierarchical Data Format v5) was chosen as a primary data storage file format for HSP2 model inputs and outputs. It is a high-performance, open binary format that has a long [history](https://en.wikipedia.org/wiki/Hierarchical_Data_Format) of use by academia, federal agencies, and industry. For more information on its selection, read [Why HSP2?: The Solution](https://github.com/respec/HSPsquared/wiki/Why-HSP2%3F#the-solution---hsp2).
#
# HDF5 has many benefits, but can nevertheless present challenges to new users.
#
# **This notebook demonstrates different approaches for opening and interacting with HDF5 files within the Python environment for HSP2** (i.e. the conda environment created by `environment_hsp2_py38.yml`).
#
# The [HDFView](https://www.hdfgroup.org/downloads/hdfview/) desktop utility software provides a visual HDF5 file browser that can support exploration of HDF5 files. We recommend downloading and using it.

# %%
# Confirm environments, using '!' magic command to run conda commands as if from a console.
# The active environment has a '*' in front of it.
# !conda info --envs
# Out:
# # conda environments:
# #
#                          /Users/aaufdenkampe/Documents/Python/holoviz_tutorial/envs/default
#                          /Users/aaufdenkampe/opt/anaconda3
#                          /Users/aaufdenkampe/opt/anaconda3/envs/R
#                          /Users/aaufdenkampe/opt/anaconda3/envs/WikiSRAT
#                          /Users/aaufdenkampe/opt/anaconda3/envs/djangoenv_py27_dev
#                          /Users/aaufdenkampe/opt/anaconda3/envs/djangoenv_py36_dev
#                          /Users/aaufdenkampe/opt/anaconda3/envs/djangoenv_py38_dj22_dev
#                          /Users/aaufdenkampe/opt/anaconda3/envs/hsp2_py38
# base                  *  /Users/aaufdenkampe/opt/anaconda3/envs/hsp2_py38_dev
#                          /Users/aaufdenkampe/opt/anaconda3/envs/pangeo
#                          /Users/aaufdenkampe/opt/anaconda3/envs/webinar

# %%
# An alternate approach to confirming the environment, using Python
import os
os.environ['CONDA_DEFAULT_ENV']
# Out:
# 'hsp2_py38_dev'

# %% [markdown]
# ## Import Dependencies
#
# HSP2 interacts with HDF5 files primarily via the [PyTables](https://www.pytables.org) library, which offers some high-level capabilities and is tightly integrated with Pandas.
#
# The [h5py](http://www.h5py.org) library offers a full Pythonic interface to the HDF5 format and technology suite.
#
# Note: The [jupyterlab-hdf5](https://github.com/jupyterlab/jupyterlab-hdf5) extension is very promising, but not yet compatible with jupyterlab>=3.
# https://github.com/jupyterlab/jupyterlab-hdf5/issues/42

# %%
import tables  # PyTables
import h5py
import pandas as pd

# %% [markdown]
# ## Set Paths to HDF5 Files with `pathlib`
#
# Use the [pathlib](https://docs.python.org/3/library/pathlib.html) library (built-in to Python 3) to manage paths indpendentely of OS or environment.
#
# This blog post describes `pathlib`'s benefits relative to using the `os` library or manual approaches.
# - https://medium.com/@ageitgey/python-3-quick-tip-the-easy-way-to-deal-with-file-paths-on-windows-mac-and-linux-11a072b58d5f

# %%
from pathlib import Path

# %%
# get home directory
Path.home()
# Out:
# PosixPath('/Users/aaufdenkampe')

# %%
# get current working directory
Path.cwd()
# Out:
# PosixPath('/Users/aaufdenkampe/Documents/Python/limno.HSPsquared/tests')

# %%
# use the Path module to construct file paths
project_folder = Path('Documents/Python/limno.HSPsquared/')
data_folder    = Path('_LargeFileStash/')

file_to_open = Path.cwd() / data_folder / "hsp2.h5"
file_to_open
# Out:
# PosixPath('/Users/aaufdenkampe/Documents/Python/limno.HSPsquared/tests/_LargeFileStash/hsp2.h5')

# %%
# list test files 
paths = [
    Path.cwd() / data_folder / 'calleg_hsp2_dev_input.h5',
    Path.cwd() / data_folder / 'calleg_hsp2_devWDM_input-parts.h5',
]
paths
# Out:
# [PosixPath('/Users/aaufdenkampe/Documents/Python/limno.HSPsquared/tests/_LargeFileStash/calleg_hsp2_dev_input.h5'),
#  PosixPath('/Users/aaufdenkampe/Documents/Python/limno.HSPsquared/tests/_LargeFileStash/calleg_hsp2_devWDM_input-parts.h5')]

# %%
# test if your path points to a valid file
paths[0].exists()
# Out:
# True

# %%
paths[1].exists()
# Out:
# True

# %% [markdown]
# # Open an HSP2-created HDF5 file with Pandas
#
# Docs:
# - https://pandas.pydata.org/docs/user_guide/io.html#io-hdf5
# - https://pandas.pydata.org/docs/reference/api/pandas.read_hdf.html

# %%
store0 = pd.HDFStore(paths[0])
store1 = pd.HDFStore(paths[1])

# %%
store0.keys()
# Out:
# ['/TIMESERIES/LAPSE_Table',
#  '/TIMESERIES/SEASONS_Table',
#  '/TIMESERIES/SUMMARY',
#  '/TIMESERIES/Saturated_Vapor_Pressure_Table',
#  '/TIMESERIES/TS049',
#  '/TIMESERIES/TS1000',
#  '/TIMESERIES/TS1169',
#  '/TIMESERIES/TS1171',
#  '/TIMESERIES/TS1239',
#  '/TIMESERIES/TS1311',
#  '/TIMESERIES/TS141',
#  '/TIMESERIES/TS154',
#  '/TIMESERIES/TS168',
#  '/TIMESERIES/TS169',
#  '/TIMESERIES/TS175',
#  '/TIMESERIES/TS177',
#  '/TIMESERIES/TS1776',
#  '/TIMESERIES/TS1780',
#  '/TIMESERIES/TS1800',
#  '/TIMESERIES/TS1802',
#  '/TIMESERIES/TS1805',
#  '/TIMESERIES/TS1806',
#  '/TIMESERIES/TS1841',
#  '/TIMESERIES/TS187',
#  '/TIMESERIES/TS188',
#  '/TIMESERIES/TS190',
#  '/TIMESERIES/TS193',
#  '/TIMESERIES/TS194',
#  '/TIMESERIES/TS196',
#  '/TIMESERIES/TS2239',
#  '/TIMESERIES/TS227',
#  '/TIMESERIES/TS234',
#  '/TIMESERIES/TS238',
#  '/TIMESERIES/TS242',
#  '/TIMESERIES/TS249',
#  '/TIMESERIES/TS250',
#  '/TIMESERIES/TS259',
#  '/TIMESERIES/TS301',
#  '/TIMESERIES/TS302',
#  '/TIMESERIES/TS303',
#  '/TIMESERIES/TS304',
#  '/TIMESERIES/TS305',
#  '/TIMESERIES/TS306',
#  '/TIMESERIES/TS307',
#  '/TIMESERIES/TS311',
#  '/TIMESERIES/TS312',
#  '/TIMESERIES/TS313',
#  '/TIMESERIES/TS321',
#  '/TIMESERIES/TS322',
#  '/TIMESERIES/TS323',
#  '/TIMESERIES/TS324',
#  '/TIMESERIES/TS325',
#  '/TIMESERIES/TS335',
#  '/TIMESERIES/TS401',
#  '/TIMESERIES/TS402',
#  '/TIMESERIES/TS403',
#  '/TIMESERIES/TS404',
#  '/TIMESERIES/TS405',
#  '/TIMESERIES/TS406',
#  '/TIMESERIES/TS407',
#  '/TIMESERIES/TS408',
#  '/TIMESERIES/TS5803',
#  '/TIMESERIES/TS6001',
#  '/TIMESERIES/TS6049',
#  '/TIMESERIES/TS6141',
#  '/TIMESERIES/TS6175',
#  '/TIMESERIES/TS6177',
#  '/TIMESERIES/TS6190',
#  '/TIMESERIES/TS6194',
#  '/TIMESERIES/TS6238',
#  '/TIMESERIES/TS6250',
#  '/TIMESERIES/TS6259',
#  '/TIMESERIES/TS7001',
#  '/TIMESERIES/TS7002',
#  '/TIMESERIES/TS7003',
#  '/TIMESERIES/TS7004',
#  '/TIMESERIES/TS7011',
#  '/TIMESERIES/TS7012',
#  '/TIMESERIES/TS7013',
#  '/TIMESERIES/TS7014',
#  '/TIMESERIES/TS7015',
#  '/TIMESERIES/TS7016',
#  '/TIMESERIES/TS7017',
#  '/TIMESERIES/TS7018',
#  '/TIMESERIES/TS7019',
#  '/TIMESERIES/TS7020',
#  '/TIMESERIES/TS7021',
#  '/TIMESERIES/TS7022',
#  '/TIMESERIES/TS7023',
#  '/TIMESERIES/TS7024',
#  '/TIMESERIES/TS7025',
#  '/TIMESERIES/TS7026',
#  '/TIMESERIES/TS7027',
#  '/TIMESERIES/TS7028',
#  '/TIMESERIES/TS7029',
#  '/TIMESERIES/TS7030',
#  '/TIMESERIES/TS7031',
#  '/TIMESERIES/TS7032',
#  '/TIMESERIES/TS7033',
#  '/TIMESERIES/TS7034',
#  '/TIMESERIES/TS7051',
#  '/TIMESERIES/TS7052',
#  '/TIMESERIES/TS7053',
#  '/TIMESERIES/TS7054',
#  '/TIMESERIES/TS7055',
#  '/TIMESERIES/TS7056',
#  '/TIMESERIES/TS7057',
#  '/TIMESERIES/TS7058',
#  '/TIMESERIES/TS7059',
#  '/TIMESERIES/TS7060',
#  '/TIMESERIES/TS7061',
#  '/TIMESERIES/TS7062',
#  '/TIMESERIES/TS7063',
#  '/TIMESERIES/TS7064',
#  '/TIMESERIES/TS7065',
#  '/TIMESERIES/TS776',
#  '/TIMESERIES/TS778',
#  '/TIMESERIES/TS780',
#  '/TIMESERIES/TS781',
#  '/TIMESERIES/TS782',
#  '/TIMESERIES/TS800',
#  '/TIMESERIES/TS802',
#  '/TIMESERIES/TS803',
#  '/TIMESERIES/TS805',
#  '/TIMESERIES/TS806',
#  '/TIMESERIES/TS8100',
#  '/TIMESERIES/TS8200',
#  '/TIMESERIES/TS830',
#  '/TIMESERIES/TS8300',
#  '/TIMESERIES/TS831',
#  '/TIMESERIES/TS832',
#  '/TIMESERIES/TS833',
#  '/TIMESERIES/TS834',
#  '/TIMESERIES/TS836',
#  '/TIMESERIES/TS838',
#  '/TIMESERIES/TS839',
#  '/TIMESERIES/TS8400',
#  '/TIMESERIES/TS841',
#  '/TIMESERIES/TS8500',
#  '/TIMESERIES/TS8600',
#  '/TIMESERIES/TS8700',
#  '/TIMESERIES/TS8800',
#  '/TIMESERIES/TS9100',
#  '/TIMESERIES/TS9101',
#  '/TIMESERIES/TS9102',
#  '/TIMESERIES/TS9103',
#  '/TIMESERIES/TS9104',
#  '/TIMESERIES/TS9105',
#  '/TIMESERIES/TS9106',
#  '/TIMESERIES/TS9107',
#  '/TIMESERIES/TS9108',
#  '/TIMESERIES/TS9109',
#  '/TIMESERIES/TS9200',
#  '/TIMESERIES/TS9201',
#  '/TIMESERIES/TS9202',
#  '/TIMESERIES/TS9203',
#  '/TIMESERIES/TS9204',
#  '/TIMESERIES/TS9205',
#  '/TIMESERIES/TS9206',
#  '/TIMESERIES/TS9207',
#  '/TIMESERIES/TS9208',
#  '/TIMESERIES/TS9209',
#  '/TIMESERIES/TS9300',
#  '/TIMESERIES/TS9301',
#  '/TIMESERIES/TS9302',
#  '/TIMESERIES/TS9303',
#  '/TIMESERIES/TS9304',
#  '/TIMESERIES/TS9305',
#  '/TIMESERIES/TS9306',
#  '/TIMESERIES/TS9307',
#  '/TIMESERIES/TS9308',
#  '/TIMESERIES/TS9309',
#  '/TIMESERIES/TS9400',
#  '/TIMESERIES/TS9401',
#  '/TIMESERIES/TS9402',
#  '/TIMESERIES/TS9403',
#  '/TIMESERIES/TS9404',
#  '/TIMESERIES/TS9405',
#  '/TIMESERIES/TS9406',
#  '/TIMESERIES/TS9407',
#  '/TIMESERIES/TS9408',
#  '/TIMESERIES/TS9409',
#  '/TIMESERIES/TS9500',
#  '/TIMESERIES/TS9501',
#  '/TIMESERIES/TS9502',
#  '/TIMESERIES/TS9503',
#  '/TIMESERIES/TS9504',
#  '/TIMESERIES/TS9505',
#  '/TIMESERIES/TS9506',
#  '/TIMESERIES/TS9507',
#  '/TIMESERIES/TS9508',
#  '/TIMESERIES/TS9509',
#  '/TIMESERIES/TS9600',
#  '/TIMESERIES/TS9601',
#  '/TIMESERIES/TS9602',
#  '/TIMESERIES/TS9603',
#  '/TIMESERIES/TS9604',
#  '/TIMESERIES/TS9605',
#  '/TIMESERIES/TS9606',
#  '/TIMESERIES/TS9607',
#  '/TIMESERIES/TS9608',
#  '/TIMESERIES/TS9609',
#  '/TIMESERIES/TS9701',
#  '/TIMESERIES/TS9702',
#  '/TIMESERIES/TS9703',
#  '/TIMESERIES/TS9704',
#  '/TIMESERIES/TS9705',
#  '/TIMESERIES/TS9706',
#  '/TIMESERIES/TS9707',
#  '/TIMESERIES/TS9708',
#  '/TIMESERIES/TS9709',
#  '/TIMESERIES/TS9801',
#  '/TIMESERIES/TS9802',
#  '/TIMESERIES/TS9803',
#  '/TIMESERIES/TS9804',
#  '/TIMESERIES/TS9805',
#  '/TIMESERIES/TS9806',
#  '/TIMESERIES/TS9807',
#  '/TIMESERIES/TS9808',
#  '/TIMESERIES/TS9809',
#  '/TIMESERIES/TS9901',
#  '/TIMESERIES/TS9902',
#  '/TIMESERIES/TS9903',
#  '/TIMESERIES/TS9904',
#  '/TIMESERIES/TS9905',
#  '/TIMESERIES/TS9906',
#  '/TIMESERIES/TS9907',
#  '/TIMESERIES/TS9908',
#  '/TIMESERIES/TS9909',
#  '/TIMESERIES/TS9910',
#  '/TIMESERIES/TS9911',
#  '/TIMESERIES/TS9912',
#  '/TIMESERIES/TS9913',
#  '/TIMESERIES/TS9914',
#  '/TIMESERIES/TS9915',
#  '/TIMESERIES/TS9916',
#  '/TIMESERIES/TS9917',
#  '/TIMESERIES/TS9918',
#  '/TIMESERIES/TS9919',
#  '/RCHRES/HYDR/PARAMETERS',
#  '/RCHRES/HYDR/SAVE',
#  '/RCHRES/HYDR/STATES',
#  '/RCHRES/GENERAL/ACTIVITY',
#  '/RCHRES/GENERAL/INFO',
#  '/PERLND/PWATER/PARAMETERS',
#  '/PERLND/PWATER/SAVE',
#  '/PERLND/PWATER/STATES',
#  '/PERLND/PWATER/MONTHLY/CEPSC',
#  '/PERLND/PWATER/MONTHLY/LZETP',
#  '/PERLND/PWATER/MONTHLY/UZSN',
#  '/PERLND/GENERAL/ACTIVITY',
#  '/PERLND/GENERAL/INFO',
#  '/IMPLND/IWATER/PARAMETERS',
#  '/IMPLND/IWATER/SAVE',
#  '/IMPLND/IWATER/STATES',
#  '/IMPLND/GENERAL/ACTIVITY',
#  '/IMPLND/GENERAL/INFO',
#  '/FTABLES/FT001',
#  '/FTABLES/FT002',
#  '/FTABLES/FT003',
#  '/FTABLES/FT004',
#  '/FTABLES/FT005',
#  '/FTABLES/FT006',
#  '/FTABLES/FT007',
#  '/FTABLES/FT008',
#  '/FTABLES/FT009',
#  '/FTABLES/FT010',
#  '/FTABLES/FT011',
#  '/FTABLES/FT021',
#  '/FTABLES/FT022',
#  '/FTABLES/FT023',
#  '/FTABLES/FT024',
#  '/FTABLES/FT025',
#  '/FTABLES/FT031',
#  '/FTABLES/FT041',
#  '/FTABLES/FT042',
#  '/FTABLES/FT043',
#  '/FTABLES/FT044',
#  '/FTABLES/FT045',
#  '/FTABLES/FT046',
#  '/FTABLES/FT051',
#  '/FTABLES/FT052',
#  '/FTABLES/FT061',
#  '/FTABLES/FT062',
#  '/FTABLES/FT063',
#  '/FTABLES/FT064',
#  '/FTABLES/FT065',
#  '/FTABLES/FT071',
#  '/FTABLES/FT072',
#  '/FTABLES/FT081',
#  '/FTABLES/FT082',
#  '/FTABLES/FT091',
#  '/FTABLES/FT092',
#  '/FTABLES/FT101',
#  '/FTABLES/FT102',
#  '/FTABLES/FT103',
#  '/FTABLES/FT104',
#  '/FTABLES/FT105',
#  '/FTABLES/FT106',
#  '/FTABLES/FT107',
#  '/FTABLES/FT108',
#  '/FTABLES/FT109',
#  '/FTABLES/FT190',
#  '/FTABLES/FT191',
#  '/FTABLES/FT192',
#  '/FTABLES/FT193',
#  '/FTABLES/FT194',
#  '/FTABLES/FT195',
#  '/FTABLES/FT201',
#  '/FTABLES/FT202',
#  '/FTABLES/FT203',
#  '/FTABLES/FT204',
#  '/FTABLES/FT205',
#  '/FTABLES/FT206',
#  '/FTABLES/FT207',
#  '/FTABLES/FT211',
#  '/FTABLES/FT212',
#  '/FTABLES/FT221',
#  '/FTABLES/FT222',
#  '/FTABLES/FT223',
#  '/FTABLES/FT225',
#  '/FTABLES/FT227',
#  '/FTABLES/FT231',
#  '/FTABLES/FT232',
#  '/FTABLES/FT233',
#  '/FTABLES/FT241',
#  '/FTABLES/FT242',
#  '/FTABLES/FT243',
#  '/FTABLES/FT301',
#  '/FTABLES/FT302',
#  '/FTABLES/FT303',
#  '/FTABLES/FT304',
#  '/FTABLES/FT305',
#  '/FTABLES/FT306',
#  '/FTABLES/FT307',
#  '/FTABLES/FT311',
#  '/FTABLES/FT401',
#  '/FTABLES/FT402',
#  '/FTABLES/FT403',
#  '/FTABLES/FT404',
#  '/FTABLES/FT405',
#  '/FTABLES/FT406',
#  '/FTABLES/FT407',
#  '/FTABLES/FT408',
#  '/FTABLES/FT411',
#  '/FTABLES/FT420',
#  '/FTABLES/FT421',
#  '/FTABLES/FT422',
#  '/FTABLES/FT423',
#  '/FTABLES/FT431',
#  '/FTABLES/FT441',
#  '/FTABLES/FT442',
#  '/FTABLES/FT443',
#  '/FTABLES/FT500',
#  '/FTABLES/FT501',
#  '/FTABLES/FT502',
#  '/FTABLES/FT503',
#  '/FTABLES/FT504',
#  '/FTABLES/FT505',
#  '/FTABLES/FT506',
#  '/FTABLES/FT510',
#  '/FTABLES/FT511',
#  '/FTABLES/FT512',
#  '/FTABLES/FT513',
#  '/FTABLES/FT514',
#  '/FTABLES/FT521',
#  '/FTABLES/FT522',
#  '/FTABLES/FT523',
#  '/FTABLES/FT524',
#  '/FTABLES/FT525',
#  '/FTABLES/FT526',
#  '/FTABLES/FT531',
#  '/FTABLES/FT541',
#  '/FTABLES/FT542',
#  '/FTABLES/FT904',
#  '/FTABLES/FT952',
#  '/FTABLES/FT964',
#  '/CONTROL/EXT_SOURCES',
#  '/CONTROL/GLOBAL',
#  '/CONTROL/LINKS',
#  '/CONTROL/MASS_LINKS',
#  '/CONTROL/OP_SEQUENCE']

# %%
ds0 = store0.select('/TIMESERIES/SUMMARY')
ds0
# Out:
#                       Start                 Stop Freq  Length TSTYPE  TFILL  \
# TS401   1987-01-01 00:00:00  2004-01-01 00:00:00  1MS     204   PUMP -999.0
# TS402   1987-01-01 00:00:00  2004-01-01 00:00:00  1MS     204   PUMP -999.0
# TS403   1987-01-01 00:00:00  2004-01-01 00:00:00  1MS     204   PUMP -999.0
# TS404   1987-01-01 00:00:00  2004-01-01 00:00:00  1MS     204   PUMP -999.0
# TS405   1987-01-01 00:00:00  2004-01-01 00:00:00  1MS     204   PUMP -999.0
# ...                     ...                  ...  ...     ...    ...    ...
# TS9204  1987-01-01 00:00:00  2003-01-01 00:00:00   1D    5844   AGWO -999.0
# TS9911  1987-01-01 00:00:00  2003-01-01 00:00:00   1D    5844   FLOW -999.0
# TS9403  1987-01-01 00:00:00  2003-01-01 00:00:00   1D    5844   IFWO -999.0
# TS9409  1987-01-01 00:00:00  2003-01-01 00:00:00   1H  140256   WPPT -999.0
# TS9802  1987-01-01 00:00:00  2003-01-01 00:00:00   1D    5844   SURO -999.0
#
#                                                    STNAM  SCENARIO  \
# TS401             Cumulative Flow of 6 Downtown GW Wells  OBSERVED
# TS402   Flow of GW pumped into storm drain by Pump #31 i  OBSERVED
# TS403    Flow of GW pumped into storm drain @ 2020 First  OBSERVED
# TS404   Flow of GW pumped into storm drain @ Chain Dr in  OBSERVED
# TS405   Flow of GW pumped into storm drain @ Madera in S  OBSERVED
# ...                                                  ...       ...
# TS9204                                                      CALLEG
# TS9911                                                      CALLEG
# TS9403                                                      CALLEG
# TS9409                                                      CALLEG
# TS9802                                                      CALLEG
#
#        CONSTITUENT  LOCATION
# TS401      PUMPOUT  DOWNTOWN
# TS402      PUMPOUT  PUMP_#31
# TS403       PUMPIN  2020_1ST
# TS404       PUMPIN  CHAIN_DR
# TS405       PUMPIN    MADERA
# ...            ...       ...
# TS9204        AGWO    MADERA
# TS9911        FLOW  ARROY838
# TS9403        IFWO   REVOLON
# TS9409        WPPT   REVOLON
# TS9802        SURO  BEARDSLY
#
# [235 rows x 10 columns]

# %%
ds0.loc['TS9906']
# Out:
# Start          1987-01-01 00:00:00
# Stop           2003-01-01 00:00:00
# Freq                            1D
# Length                        5844
# TSTYPE                        FLOW
# TFILL                       -999.0
# STNAM
# SCENARIO                    CALLEG
# CONSTITUENT                   FLOW
# LOCATION                  ARROY831
# Name: TS9906, dtype: object

# %%
ds0ts = store0.select('/TIMESERIES/TS9906')
ds0ts
# Out:
# 1987-01-01    0.0
# 1987-01-02    0.0
# 1987-01-03    0.0
# 1987-01-04    0.0
# 1987-01-05    0.0
#              ...
# 2002-12-27    0.0
# 2002-12-28    0.0
# 2002-12-29    0.0
# 2002-12-30    0.0
# 2002-12-31    0.0
# Freq: D, Length: 5844, dtype: float32

# %%
store1.keys()
# Out:
# ['/TIMESERIES/LAPSE_Table',
#  '/TIMESERIES/SEASONS_Table',
#  '/TIMESERIES/Saturated_Vapor_Pressure_Table',
#  '/TIMESERIES/TS049',
#  '/TIMESERIES/TS1000',
#  '/TIMESERIES/TS1169',
#  '/TIMESERIES/TS1171',
#  '/TIMESERIES/TS1239',
#  '/TIMESERIES/TS141',
#  '/TIMESERIES/TS154',
#  '/TIMESERIES/TS168',
#  '/TIMESERIES/TS169',
#  '/TIMESERIES/TS175',
#  '/TIMESERIES/TS177',
#  '/TIMESERIES/TS1802',
#  '/TIMESERIES/TS187',
#  '/TIMESERIES/TS188',
#  '/TIMESERIES/TS190',
#  '/TIMESERIES/TS193',
#  '/TIMESERIES/TS194',
#  '/TIMESERIES/TS196',
#  '/TIMESERIES/TS227',
#  '/TIMESERIES/TS234',
#  '/TIMESERIES/TS238',
#  '/TIMESERIES/TS242',
#  '/TIMESERIES/TS249',
#  '/TIMESERIES/TS250',
#  '/TIMESERIES/TS259',
#  '/TIMESERIES/TS301',
#  '/TIMESERIES/TS302',
#  '/TIMESERIES/TS303',
#  '/TIMESERIES/TS304',
#  '/TIMESERIES/TS305',
#  '/TIMESERIES/TS306',
#  '/TIMESERIES/TS307',
#  '/TIMESERIES/TS311',
#  '/TIMESERIES/TS312',
#  '/TIMESERIES/TS313',
#  '/TIMESERIES/TS321',
#  '/TIMESERIES/TS322',
#  '/TIMESERIES/TS323',
#  '/TIMESERIES/TS324',
#  '/TIMESERIES/TS325',
#  '/TIMESERIES/TS335',
#  '/TIMESERIES/TS401',
#  '/TIMESERIES/TS402',
#  '/TIMESERIES/TS403',
#  '/TIMESERIES/TS404',
#  '/TIMESERIES/TS405',
#  '/TIMESERIES/TS406',
#  '/TIMESERIES/TS407',
#  '/TIMESERIES/TS408',
#  '/TIMESERIES/TS6001',
#  '/TIMESERIES/TS6049',
#  '/TIMESERIES/TS6141',
#  '/TIMESERIES/TS6175',
#  '/TIMESERIES/TS6177',
#  '/TIMESERIES/TS6190',
#  '/TIMESERIES/TS6194',
#  '/TIMESERIES/TS6238',
#  '/TIMESERIES/TS6250',
#  '/TIMESERIES/TS6259',
#  '/TIMESERIES/TS7001',
#  '/TIMESERIES/TS7011',
#  '/TIMESERIES/TS7017',
#  '/TIMESERIES/TS7020',
#  '/TIMESERIES/TS7021',
#  '/TIMESERIES/TS7029',
#  '/TIMESERIES/TS7034',
#  '/TIMESERIES/TS7053',
#  '/TIMESERIES/TS7057',
#  '/TIMESERIES/TS7065',
#  '/TIMESERIES/TS776',
#  '/TIMESERIES/TS778',
#  '/TIMESERIES/TS780',
#  '/TIMESERIES/TS781',
#  '/TIMESERIES/TS782',
#  '/TIMESERIES/TS800',
#  '/TIMESERIES/TS802',
#  '/TIMESERIES/TS803',
#  '/TIMESERIES/TS805',
#  '/TIMESERIES/TS806',
#  '/TIMESERIES/TS8100',
#  '/TIMESERIES/TS830',
#  '/TIMESERIES/TS8300',
#  '/TIMESERIES/TS831',
#  '/TIMESERIES/TS832',
#  '/TIMESERIES/TS833',
#  '/TIMESERIES/TS834',
#  '/TIMESERIES/TS836',
#  '/TIMESERIES/TS838',
#  '/TIMESERIES/TS839',
#  '/TIMESERIES/TS841',
#  '/TIMESERIES/TS8700',
#  '/TIMESERIES/TS9101',
#  '/TIMESERIES/TS9109',
#  '/TIMESERIES/TS9202',
#  '/TIMESERIES/TS9207',
#  '/TIMESERIES/TS9306',
#  '/TIMESERIES/TS9402',
#  '/TIMESERIES/TS9501',
#  '/TIMESERIES/TS9502',
#  '/TIMESERIES/TS9504',
#  '/TIMESERIES/TS9701',
#  '/TIMESERIES/TS9702',
#  '/TIMESERIES/TS9804',
#  '/TIMESERIES/TS9809',
#  '/TIMESERIES/TS9909',
#  '/TIMESERIES/TS9913',
#  '/TIMESERIES/TS9916',
#  '/RCHRES/HYDR/PARAMETERS',
#  '/RCHRES/HYDR/SAVE',
#  '/RCHRES/HYDR/STATES',
#  '/RCHRES/GENERAL/ACTIVITY',
#  '/RCHRES/GENERAL/INFO',
#  '/PERLND/PWATER/PARAMETERS',
#  '/PERLND/PWATER/SAVE',
#  '/PERLND/PWATER/STATES',
#  '/PERLND/PWATER/MONTHLY/CEPSC',
#  '/PERLND/PWATER/MONTHLY/LZETP',
#  '/PERLND/PWATER/MONTHLY/UZSN',
#  '/PERLND/GENERAL/ACTIVITY',
#  '/PERLND/GENERAL/INFO',
#  '/IMPLND/IWATER/PARAMETERS',
#  '/IMPLND/IWATER/SAVE',
#  '/IMPLND/IWATER/STATES',
#  '/IMPLND/GENERAL/ACTIVITY',
#  '/IMPLND/GENERAL/INFO',
#  '/FTABLES/FT001',
#  '/FTABLES/FT002',
#  '/FTABLES/FT003',
#  '/FTABLES/FT004',
#  '/FTABLES/FT005',
#  '/FTABLES/FT006',
#  '/FTABLES/FT007',
#  '/FTABLES/FT008',
#  '/FTABLES/FT009',
#  '/FTABLES/FT010',
#  '/FTABLES/FT011',
#  '/FTABLES/FT021',
#  '/FTABLES/FT022',
#  '/FTABLES/FT023',
#  '/FTABLES/FT024',
#  '/FTABLES/FT025',
#  '/FTABLES/FT031',
#  '/FTABLES/FT041',
#  '/FTABLES/FT042',
#  '/FTABLES/FT043',
#  '/FTABLES/FT044',
#  '/FTABLES/FT045',
#  '/FTABLES/FT046',
#  '/FTABLES/FT051',
#  '/FTABLES/FT052',
#  '/FTABLES/FT061',
#  '/FTABLES/FT062',
#  '/FTABLES/FT063',
#  '/FTABLES/FT064',
#  '/FTABLES/FT065',
#  '/FTABLES/FT071',
#  '/FTABLES/FT072',
#  '/FTABLES/FT081',
#  '/FTABLES/FT082',
#  '/FTABLES/FT091',
#  '/FTABLES/FT092',
#  '/FTABLES/FT101',
#  '/FTABLES/FT102',
#  '/FTABLES/FT103',
#  '/FTABLES/FT104',
#  '/FTABLES/FT105',
#  '/FTABLES/FT106',
#  '/FTABLES/FT107',
#  '/FTABLES/FT108',
#  '/FTABLES/FT109',
#  '/FTABLES/FT190',
#  '/FTABLES/FT191',
#  '/FTABLES/FT192',
#  '/FTABLES/FT193',
#  '/FTABLES/FT194',
#  '/FTABLES/FT195',
#  '/FTABLES/FT201',
#  '/FTABLES/FT202',
#  '/FTABLES/FT203',
#  '/FTABLES/FT204',
#  '/FTABLES/FT205',
#  '/FTABLES/FT206',
#  '/FTABLES/FT207',
#  '/FTABLES/FT211',
#  '/FTABLES/FT212',
#  '/FTABLES/FT221',
#  '/FTABLES/FT222',
#  '/FTABLES/FT223',
#  '/FTABLES/FT225',
#  '/FTABLES/FT227',
#  '/FTABLES/FT231',
#  '/FTABLES/FT232',
#  '/FTABLES/FT233',
#  '/FTABLES/FT241',
#  '/FTABLES/FT242',
#  '/FTABLES/FT243',
#  '/FTABLES/FT301',
#  '/FTABLES/FT302',
#  '/FTABLES/FT303',
#  '/FTABLES/FT304',
#  '/FTABLES/FT305',
#  '/FTABLES/FT306',
#  '/FTABLES/FT307',
#  '/FTABLES/FT311',
#  '/FTABLES/FT401',
#  '/FTABLES/FT402',
#  '/FTABLES/FT403',
#  '/FTABLES/FT404',
#  '/FTABLES/FT405',
#  '/FTABLES/FT406',
#  '/FTABLES/FT407',
#  '/FTABLES/FT408',
#  '/FTABLES/FT411',
#  '/FTABLES/FT420',
#  '/FTABLES/FT421',
#  '/FTABLES/FT422',
#  '/FTABLES/FT423',
#  '/FTABLES/FT431',
#  '/FTABLES/FT441',
#  '/FTABLES/FT442',
#  '/FTABLES/FT443',
#  '/FTABLES/FT500',
#  '/FTABLES/FT501',
#  '/FTABLES/FT502',
#  '/FTABLES/FT503',
#  '/FTABLES/FT504',
#  '/FTABLES/FT505',
#  '/FTABLES/FT506',
#  '/FTABLES/FT510',
#  '/FTABLES/FT511',
#  '/FTABLES/FT512',
#  '/FTABLES/FT513',
#  '/FTABLES/FT514',
#  '/FTABLES/FT521',
#  '/FTABLES/FT522',
#  '/FTABLES/FT523',
#  '/FTABLES/FT524',
#  '/FTABLES/FT525',
#  '/FTABLES/FT526',
#  '/FTABLES/FT531',
#  '/FTABLES/FT541',
#  '/FTABLES/FT542',
#  '/FTABLES/FT904',
#  '/FTABLES/FT952',
#  '/FTABLES/FT964',
#  '/CONTROL/EXT_SOURCES',
#  '/CONTROL/GLOBAL',
#  '/CONTROL/LINKS',
#  '/CONTROL/MASS_LINKS',
#  '/CONTROL/OP_SEQUENCE']

# %%
ds1 = store1.select('/TIMESERIES/SUMMARY')
ds1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-b86cd7dda88d> in <module>
# ----> 1 ds1 = store1.select('/TIMESERIES/SUMMARY')
#       2 ds1
#
# ~/opt/anaconda3/envs/hsp2_py38_dev/lib/python3.8/site-packages/pandas/io/pytables.py in select(self, key, where, start, stop, columns, iterator, chunksize, auto_close)
#     848         group = self.get_node(key)
#     849         if group is None:
# --> 850             raise KeyError(f"No object named {key} in the file")
#     851
#     852         # create the storer and axes
#
# KeyError: 'No object named /TIMESERIES/SUMMARY in the file'

# %%
ds1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-38484e273258> in <module>
# ----> 1 ds1
#
# NameError: name 'ds1' is not defined

# %%
compare = ds0 == ds1
# compare = store0.select('/TIMESERIES/SUMMARY') == store1.select('/TIMESERIES/SUMMARY')
compare
# Out:
# 1976-01-01 00:00:00    True
# 1976-01-01 01:00:00    True
# 1976-01-01 02:00:00    True
# 1976-01-01 03:00:00    True
# 1976-01-01 04:00:00    True
#                        ...
# 1976-12-31 19:00:00    True
# 1976-12-31 20:00:00    True
# 1976-12-31 21:00:00    True
# 1976-12-31 22:00:00    True
# 1976-12-31 23:00:00    True
# Freq: H, Length: 8784, dtype: bool

# %%
ds0.info() == ds1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19 entries, TS039 to TS140
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Start   19 non-null     object
#  1   Stop    19 non-null     object
#  2   Freq    19 non-null     object
#  3   Length  19 non-null     int64
#  4   TSTYPE  19 non-null     object
#  5   TFILL   19 non-null     float64
#  6   STAID   19 non-null     object
#  7   STNAM   19 non-null     object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 19 entries, TS039 to TS140
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Start   19 non-null     object
#  1   Stop    19 non-null     object
#  2   Freq    19 non-null     object
#  3   Length  19 non-null     int64
#  4   TSTYPE  19 non-null     object
#  5   TFILL   19 non-null     float64
#  6   STAID   19 non-null     object
#  7   STNAM   19 non-null     object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.3+ KB
# True

# %%
key = store1.keys()[105]
key
# Out:
# '/CONTROL/GLOBAL'

# %%
store0.select(key).info() == store1.select(key).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, Comment to Stop
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Info    3 non-null      object
# dtypes: object(1)
# memory usage: 48.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, Comment to Stop
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Info    3 non-null      object
# dtypes: object(1)
# memory usage: 48.0+ bytes
# True

# %%
store1.select(key)
# Out:
#                                                       Info
# Comment  Version 11 test run: PERLND and IMPLND w/ RCHR...
# Start                                     1976-01-01 00:00
# Stop                                      1977-01-01 00:00

# %%
store0.select(key).index
# Out:
# Index(['Comment', 'Start', 'Stop'], dtype='object')

# %%
store1.select(key).index
# Out:
# Index(['Comment', 'Start', 'Stop'], dtype='object')

# %%
store0.select(key).index == store1.select(key).index
# Out:
# array([ True,  True,  True])

# %%
compares = []  # initialize empty list

for key in store0.keys()[100:]:
    ds0_ = store0.select(key)
#     print(ds0_)
    ds1_ = store1.select(key)
#     print(ds1_)
    compare = ds0_ == ds1_
#     compare_info = ds0_.info() == ds1_.info()

    compares.append([key, compare_info, compare])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-c998a0029df7> in <module>
#       9 #     compare_info = ds0_.info() == ds1_.info()
#      10
# ---> 11     compares.append([key, compare_info, compare])
#
# NameError: name 'compare_info' is not defined

# %%
compares
# Out:
# [['/TIMESERIES/TS041',
#   True,
#   1976-01-01    True
#   1976-01-02    True
#   1976-01-03    True
#   1976-01-04    True
#   1976-01-05    True
#                 ...
#   1976-12-27    True
#   1976-12-28    True
#   1976-12-29    True
#   1976-12-30    True
#   1976-12-31    True
#   Freq: D, Length: 366, dtype: bool],
#  ['/TIMESERIES/TS042',
#   True,
#   1976-01-01    True
#   1976-01-02    True
#   1976-01-03    True
#   1976-01-04    True
#   1976-01-05    True
#                 ...
#   1976-12-27    True
#   1976-12-28    True
#   1976-12-29    True
#   1976-12-30    True
#   1976-12-31    True
#   Freq: D, Length: 366, dtype: bool],
#  ['/TIMESERIES/TS046',
#   True,
#   1976-01-01 00:00:00    True
#   1976-01-01 02:00:00    True
#   1976-01-01 04:00:00    True
#   1976-01-01 06:00:00    True
#   1976-01-01 08:00:00    True
#                          ...
#   1976-12-31 14:00:00    True
#   1976-12-31 16:00:00    True
#   1976-12-31 18:00:00    True
#   1976-12-31 20:00:00    True
#   1976-12-31 22:00:00    True
#   Freq: 2H, Length: 4392, dtype: bool],
#  ['/TIMESERIES/TS113',
#   True,
#   1976-01-01    True
#   1976-01-02    True
#   1976-01-03    True
#   1976-01-04    True
#   1976-01-05    True
#                 ...
#   1976-12-27    True
#   1976-12-28    True
#   1976-12-29    True
#   1976-12-30    True
#   1976-12-31    True
#   Freq: D, Length: 366, dtype: bool],
#  ['/TIMESERIES/TS119',
#   True,
#   1976-01-01    True
#   1976-01-02    True
#   1976-01-03    True
#   1976-01-04    True
#   1976-01-05    True
#                 ...
#   1976-12-27    True
#   1976-12-28    True
#   1976-12-29    True
#   1976-12-30    True
#   1976-12-31    True
#   Freq: D, Length: 366, dtype: bool]]

# %%
store1.select('/CONTROL/GLOBAL')
# Out:
#                                                       Info
# Comment  Version 11 test run: PERLND and IMPLND w/ RCHR...
# Start                                     1976-01-01 00:00
# Stop                                      1977-01-01 00:00

# %%
from HSP2 import get_uci

# %%
uci_tuple = get_uci(store1)

# %%
uci_tuple
# Out:
# (  OPERATION SEGMENT  INDELT_minutes
#  0    PERLND    P001              60
#  1    RCHRES    R001              60
#  2    RCHRES    R002              60
#  3    RCHRES    R003              60
#  4    RCHRES    R004              60
#  5    IMPLND    I001              60
#  6    RCHRES    R005              60,
#  defaultdict(list,
#              {'R001': [Pandas(Index=0, AFACTR=6000.0, MLNO='ML001', SVOL='PERLND', SVOLNO='P001', TMEMSB1='', TMEMSB2='', TVOL='RCHRES', TVOLNO='R001', MFACTOR='', SGRPN='', SMEMN='', SMEMSB='', TGRPN='', TMEMN='', TMEMSB='', TRAN='', COMMENTS='')],
#               'R002': [Pandas(Index=2, AFACTR=1.0, MLNO='ML003', SVOL='RCHRES', SVOLNO='R001', TMEMSB1='', TMEMSB2='', TVOL='RCHRES', TVOLNO='R002', MFACTOR='', SGRPN='', SMEMN='', SMEMSB='', TGRPN='', TMEMN='', TMEMSB='', TRAN='', COMMENTS='')],
#               'R003': [Pandas(Index=3, AFACTR=1.0, MLNO='ML004', SVOL='RCHRES', SVOLNO='R001', TMEMSB1='', TMEMSB2='', TVOL='RCHRES', TVOLNO='R003', MFACTOR='', SGRPN='', SMEMN='', SMEMSB='', TGRPN='', TMEMN='', TMEMSB='', TRAN='', COMMENTS='')],
#               'R004': [Pandas(Index=4, AFACTR=1.0, MLNO='ML005', SVOL='RCHRES', SVOLNO='R002', TMEMSB1='', TMEMSB2='', TVOL='RCHRES', TVOLNO='R004', MFACTOR='', SGRPN='', SMEMN='', SMEMSB='', TGRPN='', TMEMN='', TMEMSB='', TRAN='', COMMENTS=''),
#                Pandas(Index=5, AFACTR=1.0, MLNO='ML005', SVOL='RCHRES', SVOLNO='R003', TMEMSB1='', TMEMSB2='', TVOL='RCHRES', TVOLNO='R004', MFACTOR='', SGRPN='', SMEMN='', SMEMSB='', TGRPN='', TMEMN='', TMEMSB='', TRAN='', COMMENTS='')],
#               'R005': [Pandas(Index=1, AFACTR=3000.0, MLNO='ML002', SVOL='IMPLND', SVOLNO='I001', TMEMSB1='', TMEMSB2='', TVOL='RCHRES', TVOLNO='R005', MFACTOR='', SGRPN='', SMEMN='', SMEMSB='', TGRPN='', TMEMN='', TMEMSB='', TRAN='', COMMENTS=''),
#                Pandas(Index=6, AFACTR=1.0, MLNO='ML005', SVOL='RCHRES', SVOLNO='R004', TMEMSB1='', TMEMSB2='', TVOL='RCHRES', TVOLNO='R005', MFACTOR='', SGRPN='', SMEMN='', SMEMSB='', TGRPN='', TMEMN='', TMEMSB='', TRAN='', COMMENTS='')]}),
#  defaultdict(list,
#              {'ML001': [Pandas(Index=0, SVOL='PERLND', SGRPN='PWATER', SMEMN='PERO', SMEMSB1='', SMEMSB2='', MFACTOR=0.0833333, TVOL='RCHRES', TMEMN='IVOL', TMEMSB1='', TMEMSB2='', MLNO='ML001', COMMENTS=''),
#                Pandas(Index=1, SVOL='PERLND', SGRPN='PWTGAS', SMEMN='POHT', SMEMSB1='', SMEMSB2='', MFACTOR=1.0, TVOL='RCHRES', TMEMN='IHEAT', TMEMSB1='', TMEMSB2='', MLNO='ML001', COMMENTS=''),
#                Pandas(Index=2, SVOL='PERLND', SGRPN='PWTGAS', SMEMN='PODOXM', SMEMSB1='', SMEMSB2='', MFACTOR=1.0, TVOL='RCHRES', TMEMN='OXIF', TMEMSB1='1', TMEMSB2='', MLNO='ML001', COMMENTS=''),
#                Pandas(Index=3, SVOL='PERLND', SGRPN='PWTGAS', SMEMN='POCO2M', SMEMSB1='', SMEMSB2='', MFACTOR=1.0, TVOL='RCHRES', TMEMN='PHIF', TMEMSB1='2', TMEMSB2='', MLNO='ML001', COMMENTS='')],
#               'ML002': [Pandas(Index=4, SVOL='IMPLND', SGRPN='IWATER', SMEMN='SURO', SMEMSB1='', SMEMSB2='', MFACTOR=0.0833333, TVOL='RCHRES', TMEMN='IVOL', TMEMSB1='', TMEMSB2='', MLNO='ML002', COMMENTS=''),
#                Pandas(Index=5, SVOL='IMPLND', SGRPN='SOLIDS', SMEMN='SOSLD', SMEMSB1='', SMEMSB2='', MFACTOR=0.1, TVOL='RCHRES', TMEMN='ISED', TMEMSB1='1', TMEMSB2='', MLNO='ML002', COMMENTS=''),
#                Pandas(Index=6, SVOL='IMPLND', SGRPN='SOLIDS', SMEMN='SOSLD', SMEMSB1='', SMEMSB2='', MFACTOR=0.46, TVOL='RCHRES', TMEMN='ISED', TMEMSB1='2', TMEMSB2='', MLNO='ML002', COMMENTS=''),
#                Pandas(Index=7, SVOL='IMPLND', SGRPN='SOLIDS', SMEMN='SOSLD', SMEMSB1='', SMEMSB2='', MFACTOR=0.44, TVOL='RCHRES', TMEMN='ISED', TMEMSB1='3', TMEMSB2='', MLNO='ML002', COMMENTS=''),
#                Pandas(Index=8, SVOL='IMPLND', SGRPN='IWTGAS', SMEMN='SOHT', SMEMSB1='', SMEMSB2='', MFACTOR=1.0, TVOL='RCHRES', TMEMN='IHEAT', TMEMSB1='', TMEMSB2='', MLNO='ML002', COMMENTS=''),
#                Pandas(Index=9, SVOL='IMPLND', SGRPN='IWTGAS', SMEMN='SODOXM', SMEMSB1='', SMEMSB2='', MFACTOR=1.0, TVOL='RCHRES', TMEMN='OXIF', TMEMSB1='1', TMEMSB2='', MLNO='ML002', COMMENTS=''),
#                Pandas(Index=10, SVOL='IMPLND', SGRPN='IWTGAS', SMEMN='SOCO2M', SMEMSB1='', SMEMSB2='', MFACTOR=1.0, TVOL='RCHRES', TMEMN='PHIF', TMEMSB1='2', TMEMSB2='', MLNO='ML002', COMMENTS=''),
#                Pandas(Index=11, SVOL='IMPLND', SGRPN='IQUAL', SMEMN='SOQUAL', SMEMSB1='', SMEMSB2='', MFACTOR=1.0, TVOL='RCHRES', TMEMN='OXIF', TMEMSB1='2', TMEMSB2='', MLNO='ML002', COMMENTS='')],
#               'ML003': [Pandas(Index=12, SVOL='RCHRES', SGRPN='OFLOW', SMEMN='', SMEMSB1='1', SMEMSB2='', MFACTOR=1.0, TVOL='RCHRES', TMEMN='', TMEMSB1='', TMEMSB2='', MLNO='ML003', COMMENTS='')],
#               'ML004': [Pandas(Index=13, SVOL='RCHRES', SGRPN='OFLOW', SMEMN='', SMEMSB1='2', SMEMSB2='', MFACTOR=1.0, TVOL='RCHRES', TMEMN='', TMEMSB1='', TMEMSB2='', MLNO='ML004', COMMENTS='')],
#               'ML005': [Pandas(Index=14, SVOL='RCHRES', SGRPN='ROFLOW', SMEMN='', SMEMSB1='', SMEMSB2='', MFACTOR=1.0, TVOL='RCHRES', TMEMN='', TMEMSB1='', TMEMSB2='', MLNO='ML005', COMMENTS='')]}),
#  defaultdict(list,
#              {('IMPLND',
#                'I001'): [Pandas(Index=1, SVOL='*', SVOLNO='TS131', SMEMN='PREC', SMEMSB='31', SSYST='ENGL', SGAPST='ZERO', MFACTOR=1.0, TRAN='SAME', TVOL='IMPLND', TGRPN='', TMEMN='PREC', TMEMSB='', TVOLNO='I001', COMMENT=''), Pandas(Index=22, SVOL='*', SVOLNO='TS042', SMEMN='WIND', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='DIV', TVOL='IMPLND', TGRPN='', TMEMN='WINMOV', TMEMSB='', TVOLNO='I001', COMMENT=''), Pandas(Index=29, SVOL='*', SVOLNO='TS046', SMEMN='SOLR', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='DIV', TVOL='IMPLND', TGRPN='', TMEMN='SOLRAD', TMEMSB='', TVOLNO='I001', COMMENT=''), Pandas(Index=44, SVOL='*', SVOLNO='TS135', SMEMN='CLDC', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='SAME', TVOL='IMPLND', TGRPN='', TMEMN='CLOUD', TMEMSB='', TVOLNO='I001', COMMENT=''), Pandas(Index=15, SVOL='*', SVOLNO='TS041', SMEMN='EVAP', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=0.7, TRAN='DIV', TVOL='IMPLND', TGRPN='', TMEMN='PETINP', TMEMSB='', TVOLNO='I001', COMMENT=''), Pandas(Index=8, SVOL='*', SVOLNO='TS122', SMEMN='ATMP', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='SAME', TVOL='IMPLND', TGRPN='ATEMP', TMEMN='AIRTMP', TMEMSB='', TVOLNO='I001', COMMENT=''), Pandas(Index=36, SVOL='*', SVOLNO='TS125', SMEMN='DEWP', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='SAME', TVOL='IMPLND', TGRPN='', TMEMN='DTMPG', TMEMSB='', TVOLNO='I001', COMMENT='')],
#               ('PERLND',
#                'P001'): [Pandas(Index=0, SVOL='*', SVOLNO='TS039', SMEMN='PREC', SMEMSB='31', SSYST='ENGL', SGAPST='ZERO', MFACTOR=1.0, TRAN='SAME', TVOL='PERLND', TGRPN='', TMEMN='PREC', TMEMSB='', TVOLNO='P001', COMMENT=''), Pandas(Index=21, SVOL='*', SVOLNO='TS042', SMEMN='WIND', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='DIV', TVOL='PERLND', TGRPN='', TMEMN='WINMOV', TMEMSB='', TVOLNO='P001', COMMENT=''), Pandas(Index=35, SVOL='*', SVOLNO='TS126', SMEMN='DEWP', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='SAME', TVOL='PERLND', TGRPN='', TMEMN='DTMPG', TMEMSB='', TVOLNO='P001', COMMENT=''), Pandas(Index=14, SVOL='*', SVOLNO='TS041', SMEMN='EVAP', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=0.7, TRAN='DIV', TVOL='PERLND', TGRPN='', TMEMN='PETINP', TMEMSB='', TVOLNO='P001', COMMENT=''), Pandas(Index=28, SVOL='*', SVOLNO='TS046', SMEMN='SOLR', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='DIV', TVOL='PERLND', TGRPN='', TMEMN='SOLRAD', TMEMSB='', TVOLNO='P001', COMMENT=''), Pandas(Index=7, SVOL='*', SVOLNO='TS123', SMEMN='ATMP', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='SAME', TVOL='PERLND', TGRPN='ATEMP', TMEMN='AIRTMP', TMEMSB='', TVOLNO='P001', COMMENT=''), Pandas(Index=43, SVOL='*', SVOLNO='TS135', SMEMN='CLDC', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='SAME', TVOL='PERLND', TGRPN='', TMEMN='CLOUD', TMEMSB='', TVOLNO='P001', COMMENT='')],
#               ('RCHRES',
#                'R001'): [Pandas(Index=23, SVOL='*', SVOLNO='TS042', SMEMN='WIND', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='DIV', TVOL='RCHRES', TGRPN='', TMEMN='WIND', TMEMSB='', TVOLNO='R001', COMMENT=''), Pandas(Index=42, SVOL='*', SVOLNO='TS140', SMEMN='CLND', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='SAME', TVOL='RCHRES', TGRPN='', TMEMN='COLIND', TMEMSB='', TVOLNO='R001', COMMENT=''), Pandas(Index=9, SVOL='*', SVOLNO='TS123', SMEMN='ATMP', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='SAME', TVOL='RCHRES', TGRPN='', TMEMN='GATMP', TMEMSB='', TVOLNO='R001', COMMENT=''), Pandas(Index=16, SVOL='*', SVOLNO='TS041', SMEMN='EVAP', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=0.7, TRAN='DIV', TVOL='RCHRES', TGRPN='', TMEMN='POTEV', TMEMSB='', TVOLNO='R001', COMMENT=''), Pandas(Index=30, SVOL='*', SVOLNO='TS046', SMEMN='SOLR', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='DIV', TVOL='RCHRES', TGRPN='', TMEMN='SOLRAD', TMEMSB='', TVOLNO='R001', COMMENT=''), Pandas(Index=45, SVOL='*', SVOLNO='TS135', SMEMN='CLDC', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='SAME', TVOL='RCHRES', TGRPN='', TMEMN='CLOUD', TMEMSB='', TVOLNO='R001', COMMENT=''), Pandas(Index=2, SVOL='*', SVOLNO='TS039', SMEMN='PREC', SMEMSB='31', SSYST='ENGL', SGAPST='ZERO', MFACTOR=1.0, TRAN='SAME', TVOL='RCHRES', TGRPN='', TMEMN='PREC', TMEMSB='', TVOLNO='R001', COMMENT=''), Pandas(Index=37, SVOL='*', SVOLNO='TS126', SMEMN='DEWP', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='SAME', TVOL='RCHRES', TGRPN='', TMEMN='DEWTMP', TMEMSB='', TVOLNO='R001', COMMENT='')],
#               ('RCHRES',
#                'R002'): [Pandas(Index=31, SVOL='*', SVOLNO='TS046', SMEMN='SOLR', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='DIV', TVOL='RCHRES', TGRPN='', TMEMN='SOLRAD', TMEMSB='', TVOLNO='R002', COMMENT=''), Pandas(Index=46, SVOL='*', SVOLNO='TS135', SMEMN='CLDC', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='SAME', TVOL='RCHRES', TGRPN='', TMEMN='CLOUD', TMEMSB='', TVOLNO='R002', COMMENT=''), Pandas(Index=38, SVOL='*', SVOLNO='TS126', SMEMN='DEWP', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='SAME', TVOL='RCHRES', TGRPN='', TMEMN='DEWTMP', TMEMSB='', TVOLNO='R002', COMMENT=''), Pandas(Index=24, SVOL='*', SVOLNO='TS042', SMEMN='WIND', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='DIV', TVOL='RCHRES', TGRPN='', TMEMN='WIND', TMEMSB='', TVOLNO='R002', COMMENT=''), Pandas(Index=3, SVOL='*', SVOLNO='TS039', SMEMN='PREC', SMEMSB='31', SSYST='ENGL', SGAPST='ZERO', MFACTOR=1.0, TRAN='SAME', TVOL='RCHRES', TGRPN='', TMEMN='PREC', TMEMSB='', TVOLNO='R002', COMMENT=''), Pandas(Index=10, SVOL='*', SVOLNO='TS123', SMEMN='ATMP', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='SAME', TVOL='RCHRES', TGRPN='', TMEMN='GATMP', TMEMSB='', TVOLNO='R002', COMMENT=''), Pandas(Index=17, SVOL='*', SVOLNO='TS041', SMEMN='EVAP', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=0.7, TRAN='DIV', TVOL='RCHRES', TGRPN='', TMEMN='POTEV', TMEMSB='', TVOLNO='R002', COMMENT='')],
#               ('RCHRES',
#                'R003'): [Pandas(Index=47, SVOL='*', SVOLNO='TS135', SMEMN='CLDC', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='SAME', TVOL='RCHRES', TGRPN='', TMEMN='CLOUD', TMEMSB='', TVOLNO='R003', COMMENT=''), Pandas(Index=4, SVOL='*', SVOLNO='TS039', SMEMN='PREC', SMEMSB='31', SSYST='ENGL', SGAPST='ZERO', MFACTOR=1.0, TRAN='SAME', TVOL='RCHRES', TGRPN='', TMEMN='PREC', TMEMSB='', TVOLNO='R003', COMMENT=''), Pandas(Index=18, SVOL='*', SVOLNO='TS041', SMEMN='EVAP', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=0.7, TRAN='DIV', TVOL='RCHRES', TGRPN='', TMEMN='POTEV', TMEMSB='', TVOLNO='R003', COMMENT=''), Pandas(Index=32, SVOL='*', SVOLNO='TS046', SMEMN='SOLR', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='DIV', TVOL='RCHRES', TGRPN='', TMEMN='SOLRAD', TMEMSB='', TVOLNO='R003', COMMENT=''), Pandas(Index=39, SVOL='*', SVOLNO='TS126', SMEMN='DEWP', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='SAME', TVOL='RCHRES', TGRPN='', TMEMN='DEWTMP', TMEMSB='', TVOLNO='R003', COMMENT=''), Pandas(Index=25, SVOL='*', SVOLNO='TS042', SMEMN='WIND', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='DIV', TVOL='RCHRES', TGRPN='', TMEMN='WIND', TMEMSB='', TVOLNO='R003', COMMENT=''), Pandas(Index=11, SVOL='*', SVOLNO='TS123', SMEMN='ATMP', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='SAME', TVOL='RCHRES', TGRPN='', TMEMN='GATMP', TMEMSB='', TVOLNO='R003', COMMENT='')],
#               ('RCHRES',
#                'R004'): [Pandas(Index=26, SVOL='*', SVOLNO='TS042', SMEMN='WIND', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='DIV', TVOL='RCHRES', TGRPN='', TMEMN='WIND', TMEMSB='', TVOLNO='R004', COMMENT=''), Pandas(Index=5, SVOL='*', SVOLNO='TS131', SMEMN='PREC', SMEMSB='31', SSYST='ENGL', SGAPST='ZERO', MFACTOR=1.0, TRAN='SAME', TVOL='RCHRES', TGRPN='', TMEMN='PREC', TMEMSB='', TVOLNO='R004', COMMENT=''), Pandas(Index=40, SVOL='*', SVOLNO='TS125', SMEMN='DEWP', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='SAME', TVOL='RCHRES', TGRPN='', TMEMN='DEWTMP', TMEMSB='', TVOLNO='R004', COMMENT=''), Pandas(Index=12, SVOL='*', SVOLNO='TS122', SMEMN='ATMP', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='SAME', TVOL='RCHRES', TGRPN='', TMEMN='GATMP', TMEMSB='', TVOLNO='R004', COMMENT=''), Pandas(Index=33, SVOL='*', SVOLNO='TS046', SMEMN='SOLR', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='DIV', TVOL='RCHRES', TGRPN='', TMEMN='SOLRAD', TMEMSB='', TVOLNO='R004', COMMENT=''), Pandas(Index=19, SVOL='*', SVOLNO='TS041', SMEMN='EVAP', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=0.7, TRAN='DIV', TVOL='RCHRES', TGRPN='', TMEMN='POTEV', TMEMSB='', TVOLNO='R004', COMMENT=''), Pandas(Index=48, SVOL='*', SVOLNO='TS135', SMEMN='CLDC', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='SAME', TVOL='RCHRES', TGRPN='', TMEMN='CLOUD', TMEMSB='', TVOLNO='R004', COMMENT='')],
#               ('RCHRES',
#                'R005'): [Pandas(Index=34, SVOL='*', SVOLNO='TS046', SMEMN='SOLR', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='DIV', TVOL='RCHRES', TGRPN='', TMEMN='SOLRAD', TMEMSB='', TVOLNO='R005', COMMENT=''), Pandas(Index=41, SVOL='*', SVOLNO='TS125', SMEMN='DEWP', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='SAME', TVOL='RCHRES', TGRPN='', TMEMN='DEWTMP', TMEMSB='', TVOLNO='R005', COMMENT=''), Pandas(Index=6, SVOL='*', SVOLNO='TS131', SMEMN='PREC', SMEMSB='31', SSYST='ENGL', SGAPST='ZERO', MFACTOR=1.0, TRAN='SAME', TVOL='RCHRES', TGRPN='', TMEMN='PREC', TMEMSB='', TVOLNO='R005', COMMENT=''), Pandas(Index=20, SVOL='*', SVOLNO='TS041', SMEMN='EVAP', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=0.7, TRAN='DIV', TVOL='RCHRES', TGRPN='', TMEMN='POTEV', TMEMSB='', TVOLNO='R005', COMMENT=''), Pandas(Index=27, SVOL='*', SVOLNO='TS042', SMEMN='WIND', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='DIV', TVOL='RCHRES', TGRPN='', TMEMN='WIND', TMEMSB='', TVOLNO='R005', COMMENT=''), Pandas(Index=13, SVOL='*', SVOLNO='TS122', SMEMN='ATMP', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='SAME', TVOL='RCHRES', TGRPN='', TMEMN='GATMP', TMEMSB='', TVOLNO='R005', COMMENT=''), Pandas(Index=49, SVOL='*', SVOLNO='TS135', SMEMN='CLDC', SMEMSB='31', SSYST='ENGL', SGAPST='', MFACTOR=1.0, TRAN='SAME', TVOL='RCHRES', TGRPN='', TMEMN='CLOUD', TMEMSB='', TVOLNO='R005', COMMENT='')]}),
#  defaultdict(dict,
#              {('RCHRES',
#                'SEDTRN',
#                'R001'): {'CLAY': {'D': 5.5e-05,
#                 'W': 3.4e-05,
#                 'RHO': 2.0,
#                 'TAUCD': 0.15,
#                 'TAUCS': 0.3,
#                 'M': 0.75}, 'FLAGS': {'SANDFG': 1}, 'PARAMETERS': {'BEDWID': 200.0,
#                 'BEDWRN': 4.0,
#                 'POR': 0.5,
#                 'D': 0.014,
#                 'W': 2.5,
#                 'RHO': 2.65,
#                 'KSAND': 1.5,
#                 'EXPSND': 1.2}, 'SAVE': {'BEDDEP': 0,
#                 'DEPSCR1': 0,
#                 'DEPSCR2': 0,
#                 'DEPSCR3': 0,
#                 'DEPSCR4': 0,
#                 'ISED1': 0,
#                 'ISED2': 0,
#                 'ISED3': 0,
#                 'OSED1': 0,
#                 'OSED2': 0,
#                 'OSED3': 0,
#                 'OSED4': 0,
#                 'ROSED1': 0,
#                 'ROSED2': 0,
#                 'ROSED3': 0,
#                 'ROSED4': 0,
#                 'RSED1': 0,
#                 'RSED2': 0,
#                 'RSED3': 0,
#                 'RSED4': 0,
#                 'RSED5': 0,
#                 'RSED6': 0,
#                 'RSED7': 0,
#                 'RSED8': 0,
#                 'RSED9': 0,
#                 'RSED10': 0,
#                 'SSED1': 0,
#                 'SSED2': 0,
#                 'SSED3': 0,
#                 'SSED4': 0,
#                 'TSED1': 0,
#                 'TSED2': 0,
#                 'TSED3': 0}, 'SILT': {'D': 0.00063,
#                 'W': 0.0066,
#                 'RHO': 2.2,
#                 'TAUCD': 0.2,
#                 'TAUCS': 0.4,
#                 'M': 0.5}, 'STATES': {'SSED1': 5.0,
#                 'SSED2': 20.0,
#                 'SSED3': 30.0,
#                 'BEDDEP': 2.0,
#                 'SANDFR': 0.8,
#                 'SILTFR': 0.1,
#                 'CLAYFR': 0.1}},
#               ('RCHRES',
#                'SEDTRN',
#                'R002'): {'CLAY': {'D': 5.5e-05,
#                 'W': 3.4e-05,
#                 'RHO': 2.0,
#                 'TAUCD': 1e-10,
#                 'TAUCS': 500.0,
#                 'M': 0.75}, 'FLAGS': {'SANDFG': 1}, 'PARAMETERS': {'BEDWID': 1.33,
#                 'BEDWRN': 3.0,
#                 'POR': 0.5,
#                 'D': 0.014,
#                 'W': 2.5,
#                 'RHO': 2.65,
#                 'KSAND': 1.5,
#                 'EXPSND': 1.2}, 'SAVE': {'BEDDEP': 0,
#                 'DEPSCR1': 0,
#                 'DEPSCR2': 0,
#                 'DEPSCR3': 0,
#                 'DEPSCR4': 0,
#                 'ISED1': 0,
#                 'ISED2': 0,
#                 'ISED3': 0,
#                 'OSED1': 0,
#                 'OSED2': 0,
#                 'OSED3': 0,
#                 'OSED4': 0,
#                 'ROSED1': 0,
#                 'ROSED2': 0,
#                 'ROSED3': 0,
#                 'ROSED4': 0,
#                 'RSED1': 0,
#                 'RSED2': 0,
#                 'RSED3': 0,
#                 'RSED4': 0,
#                 'RSED5': 0,
#                 'RSED6': 0,
#                 'RSED7': 0,
#                 'RSED8': 0,
#                 'RSED9': 0,
#                 'RSED10': 0,
#                 'SSED1': 0,
#                 'SSED2': 0,
#                 'SSED3': 0,
#                 'SSED4': 0,
#                 'TSED1': 0,
#                 'TSED2': 0,
#                 'TSED3': 0}, 'SILT': {'D': 0.00063,
#                 'W': 0.0066,
#                 'RHO': 2.2,
#                 'TAUCD': 1e-10,
#                 'TAUCS': 500.0,
#                 'M': 0.5}, 'STATES': {'SSED1': 5.0,
#                 'SSED2': 20.0,
#                 'SSED3': 30.0,
#                 'BEDDEP': 2.0,
#                 'SANDFR': 0.8,
#                 'SILTFR': 0.1,
#                 'CLAYFR': 0.1}},
#               ('RCHRES',
#                'SEDTRN',
#                'R003'): {'CLAY': {'D': 5.5e-05,
#                 'W': 3.4e-05,
#                 'RHO': 2.0,
#                 'TAUCD': 1e-10,
#                 'TAUCS': 500.0,
#                 'M': 0.75}, 'FLAGS': {'SANDFG': 2}, 'PARAMETERS': {'BEDWID': 1.33,
#                 'BEDWRN': 3.0,
#                 'POR': 0.5,
#                 'D': 0.014,
#                 'W': 2.5,
#                 'RHO': 2.65,
#                 'KSAND': 1.5,
#                 'EXPSND': 1.2}, 'SAVE': {'BEDDEP': 0,
#                 'DEPSCR1': 0,
#                 'DEPSCR2': 0,
#                 'DEPSCR3': 0,
#                 'DEPSCR4': 0,
#                 'ISED1': 0,
#                 'ISED2': 0,
#                 'ISED3': 0,
#                 'OSED1': 0,
#                 'OSED2': 0,
#                 'OSED3': 0,
#                 'OSED4': 0,
#                 'ROSED1': 0,
#                 'ROSED2': 0,
#                 'ROSED3': 0,
#                 'ROSED4': 0,
#                 'RSED1': 0,
#                 'RSED2': 0,
#                 'RSED3': 0,
#                 'RSED4': 0,
#                 'RSED5': 0,
#                 'RSED6': 0,
#                 'RSED7': 0,
#                 'RSED8': 0,
#                 'RSED9': 0,
#                 'RSED10': 0,
#                 'SSED1': 0,
#                 'SSED2': 0,
#                 'SSED3': 0,
#                 'SSED4': 0,
#                 'TSED1': 0,
#                 'TSED2': 0,
#                 'TSED3': 0}, 'SILT': {'D': 0.00063,
#                 'W': 0.0066,
#                 'RHO': 2.2,
#                 'TAUCD': 1e-10,
#                 'TAUCS': 500.0,
#                 'M': 0.5}, 'STATES': {'SSED1': 5.0,
#                 'SSED2': 20.0,
#                 'SSED3': 30.0,
#                 'BEDDEP': 2.0,
#                 'SANDFR': 0.8,
#                 'SILTFR': 0.1,
#                 'CLAYFR': 0.1}},
#               ('RCHRES',
#                'SEDTRN',
#                'R004'): {'CLAY': {'D': 5.5e-05,
#                 'W': 3.4e-05,
#                 'RHO': 2.0,
#                 'TAUCD': 0.15,
#                 'TAUCS': 0.3,
#                 'M': 0.75}, 'FLAGS': {'SANDFG': 2}, 'PARAMETERS': {'BEDWID': 2.0,
#                 'BEDWRN': 2.0,
#                 'POR': 0.5,
#                 'D': 0.014,
#                 'W': 2.5,
#                 'RHO': 2.65,
#                 'KSAND': 1.5,
#                 'EXPSND': 1.2}, 'SAVE': {'BEDDEP': 0,
#                 'DEPSCR1': 0,
#                 'DEPSCR2': 0,
#                 'DEPSCR3': 0,
#                 'DEPSCR4': 0,
#                 'ISED1': 0,
#                 'ISED2': 0,
#                 'ISED3': 0,
#                 'OSED1': 0,
#                 'OSED2': 0,
#                 'OSED3': 0,
#                 'OSED4': 0,
#                 'ROSED1': 0,
#                 'ROSED2': 0,
#                 'ROSED3': 0,
#                 'ROSED4': 0,
#                 'RSED1': 0,
#                 'RSED2': 0,
#                 'RSED3': 0,
#                 'RSED4': 0,
#                 'RSED5': 0,
#                 'RSED6': 0,
#                 'RSED7': 0,
#                 'RSED8': 0,
#                 'RSED9': 0,
#                 'RSED10': 0,
#                 'SSED1': 0,
#                 'SSED2': 0,
#                 'SSED3': 0,
#                 'SSED4': 0,
#                 'TSED1': 0,
#                 'TSED2': 0,
#                 'TSED3': 0}, 'SILT': {'D': 0.00063,
#                 'W': 0.0066,
#                 'RHO': 2.2,
#                 'TAUCD': 0.2,
#                 'TAUCS': 0.4,
#                 'M': 0.5}, 'STATES': {'SSED1': 5.0,
#                 'SSED2': 20.0,
#                 'SSED3': 30.0,
#                 'BEDDEP': 1.0,
#                 'SANDFR': 0.8,
#                 'SILTFR': 0.1,
#                 'CLAYFR': 0.1}},
#               ('RCHRES',
#                'SEDTRN',
#                'R005'): {'CLAY': {'D': 5.5e-05,
#                 'W': 3.4e-05,
#                 'RHO': 2.0,
#                 'TAUCD': 0.15,
#                 'TAUCS': 0.3,
#                 'M': 0.75}, 'FLAGS': {'SANDFG': 3}, 'PARAMETERS': {'BEDWID': 2.66,
#                 'BEDWRN': 2.0,
#                 'POR': 0.5,
#                 'D': 0.014,
#                 'W': 2.5,
#                 'RHO': 2.65,
#                 'KSAND': 1.5,
#                 'EXPSND': 1.2}, 'SAVE': {'BEDDEP': 0,
#                 'DEPSCR1': 0,
#                 'DEPSCR2': 0,
#                 'DEPSCR3': 0,
#                 'DEPSCR4': 0,
#                 'ISED1': 0,
#                 'ISED2': 0,
#                 'ISED3': 0,
#                 'OSED1': 0,
#                 'OSED2': 0,
#                 'OSED3': 0,
#                 'OSED4': 0,
#                 'ROSED1': 0,
#                 'ROSED2': 0,
#                 'ROSED3': 0,
#                 'ROSED4': 0,
#                 'RSED1': 0,
#                 'RSED2': 0,
#                 'RSED3': 0,
#                 'RSED4': 0,
#                 'RSED5': 0,
#                 'RSED6': 0,
#                 'RSED7': 0,
#                 'RSED8': 0,
#                 'RSED9': 0,
#                 'RSED10': 0,
#                 'SSED1': 0,
#                 'SSED2': 0,
#                 'SSED3': 0,
#                 'SSED4': 0,
#                 'TSED1': 0,
#                 'TSED2': 0,
#                 'TSED3': 0}, 'SILT': {'D': 0.00063,
#                 'W': 0.0066,
#                 'RHO': 2.2,
#                 'TAUCD': 0.2,
#                 'TAUCS': 0.4,
#                 'M': 0.5}, 'STATES': {'SSED1': 5.0,
#                 'SSED2': 20.0,
#                 'SSED3': 30.0,
#                 'BEDDEP': 1.0,
#                 'SANDFR': 0.8,
#                 'SILTFR': 0.1,
#                 'CLAYFR': 0.1}},
#               ('RCHRES', 'RQUAL', 'R001'): {'FLAGS': {'BENRFG': 1.0},
#                'PARAMETERS': {'SCRVEL': 3.0, 'SCRMUL': 2.0}},
#               ('RCHRES', 'RQUAL', 'R004'): {'FLAGS': {'BENRFG': 1.0},
#                'PARAMETERS': {'SCRVEL': 3.0, 'SCRMUL': 2.0}},
#               ('RCHRES', 'RQUAL', 'R005'): {'FLAGS': {'BENRFG': 1.0},
#                'PARAMETERS': {'SCRVEL': 3.0, 'SCRMUL': 2.0}},
#               ('RCHRES', 'RQUAL', 'R003'): {'FLAGS': {'BENRFG': 0.0},
#                'PARAMETERS': {'SCRVEL': 3.0, 'SCRMUL': 2.0}},
#               ('RCHRES', 'RQUAL', 'R002'): {'FLAGS': {'BENRFG': 0.0},
#                'PARAMETERS': {'SCRVEL': 3.0, 'SCRMUL': 2.0}},
#               ('RCHRES',
#                'PLANK',
#                'R001'): {'FLAGS': {'PHYFG': 1,
#                 'ZOOFG': 1,
#                 'BALFG': 1,
#                 'SDLTFG': 1,
#                 'AMRFG': 1,
#                 'DECFG': 0,
#                 'NSFG': 1,
#                 'ZFOOD': 2,
#                 'BNPFG': 0}, 'PARAMETERS': {'RATCLP': 0.6,
#                 'NONREF': 0.5,
#                 'LITSED': 0.0,
#                 'ALNPR': 1.0,
#                 'EXTB': 4.5,
#                 'MALGR': 0.3,
#                 'PARADF': 1.0,
#                 'SEED': 0.1,
#                 'MXSTAY': 0.1,
#                 'O': 0.0001,
#                 'CLALDH': 50.0,
#                 'PHYSET': 0.5,
#                 'REFSET': 0.5,
#                 'MZOEAT': 0.055,
#                 'ZFIL20': 0.2,
#                 'ZRES20': 0.0015,
#                 'ZD': 0.0001,
#                 'OXZD': 0.03}, 'SAVE': {'PHYTO': 0,
#                 'ZOO': 0,
#                 'BENAL': 0,
#                 'TBENAL': 0,
#                 'PHYCLA': 0,
#                 'BALCLA': 0,
#                 'PKST3': 0,
#                 'PKST4': 0,
#                 'PKIF': 0,
#                 'TPKIF': 0,
#                 'PKCF1': 0,
#                 'TPKCF1': 0,
#                 'PKCF2': 0,
#                 'TPKCF2': 0,
#                 'PLADDR': 0,
#                 'PLADWT': 0,
#                 'PLADEP': 0,
#                 'PKCF5': 0,
#                 'PKCF6': 0,
#                 'PKCF7': 0,
#                 'TPKCF7': 0,
#                 'PKCF8': 0,
#                 'PKCF9': 0,
#                 'PKCF10': 0}, 'STATES': {'PHYTO': 40.0,
#                 'ZOO': 200.0,
#                 'BENAL': 5.0,
#                 'ORN': 20.0,
#                 'ORP': 20.0,
#                 'ORC': 20.0}},
#               ('RCHRES',
#                'PLANK',
#                'R002'): {'FLAGS': {'PHYFG': 1,
#                 'ZOOFG': 1,
#                 'BALFG': 1,
#                 'SDLTFG': 1,
#                 'AMRFG': 1,
#                 'DECFG': 0,
#                 'NSFG': 1,
#                 'ZFOOD': 2,
#                 'BNPFG': 0}, 'PARAMETERS': {'RATCLP': 0.6,
#                 'NONREF': 0.5,
#                 'LITSED': 0.0,
#                 'ALNPR': 1.0,
#                 'EXTB': 4.5,
#                 'MALGR': 0.3,
#                 'PARADF': 1.0,
#                 'SEED': 0.1,
#                 'MXSTAY': 0.1,
#                 'O': 0.0001,
#                 'CLALDH': 50.0,
#                 'PHYSET': 0.5,
#                 'REFSET': 0.5,
#                 'MZOEAT': 0.055,
#                 'ZFIL20': 0.2,
#                 'ZRES20': 0.0015,
#                 'ZD': 0.0001,
#                 'OXZD': 0.03}, 'SAVE': {'PHYTO': 0,
#                 'ZOO': 0,
#                 'BENAL': 0,
#                 'TBENAL': 0,
#                 'PHYCLA': 0,
#                 'BALCLA': 0,
#                 'PKST3': 0,
#                 'PKST4': 0,
#                 'PKIF': 0,
#                 'TPKIF': 0,
#                 'PKCF1': 0,
#                 'TPKCF1': 0,
#                 'PKCF2': 0,
#                 'TPKCF2': 0,
#                 'PLADDR': 0,
#                 'PLADWT': 0,
#                 'PLADEP': 0,
#                 'PKCF5': 0,
#                 'PKCF6': 0,
#                 'PKCF7': 0,
#                 'TPKCF7': 0,
#                 'PKCF8': 0,
#                 'PKCF9': 0,
#                 'PKCF10': 0}, 'STATES': {'PHYTO': 40.0,
#                 'ZOO': 200.0,
#                 'BENAL': 5.0,
#                 'ORN': 20.0,
#                 'ORP': 20.0,
#                 'ORC': 20.0}},
#               ('RCHRES',
#                'PLANK',
#                'R003'): {'FLAGS': {'PHYFG': 1,
#                 'ZOOFG': 1,
#                 'BALFG': 1,
#                 'SDLTFG': 1,
#                 'AMRFG': 1,
#                 'DECFG': 0,
#                 'NSFG': 1,
#                 'ZFOOD': 2,
#                 'BNPFG': 0}, 'PARAMETERS': {'RATCLP': 0.6,
#                 'NONREF': 0.5,
#                 'LITSED': 0.0,
#                 'ALNPR': 1.0,
#                 'EXTB': 4.5,
#                 'MALGR': 0.3,
#                 'PARADF': 1.0,
#                 'SEED': 0.1,
#                 'MXSTAY': 0.1,
#                 'O': 0.0001,
#                 'CLALDH': 50.0,
#                 'PHYSET': 0.5,
#                 'REFSET': 0.5,
#                 'MZOEAT': 0.055,
#                 'ZFIL20': 0.2,
#                 'ZRES20': 0.0015,
#                 'ZD': 0.0001,
#                 'OXZD': 0.03}, 'SAVE': {'PHYTO': 0,
#                 'ZOO': 0,
#                 'BENAL': 0,
#                 'TBENAL': 0,
#                 'PHYCLA': 0,
#                 'BALCLA': 0,
#                 'PKST3': 0,
#                 'PKST4': 0,
#                 'PKIF': 0,
#                 'TPKIF': 0,
#                 'PKCF1': 0,
#                 'TPKCF1': 0,
#                 'PKCF2': 0,
#                 'TPKCF2': 0,
#                 'PLADDR': 0,
#                 'PLADWT': 0,
#                 'PLADEP': 0,
#                 'PKCF5': 0,
#                 'PKCF6': 0,
#                 'PKCF7': 0,
#                 'TPKCF7': 0,
#                 'PKCF8': 0,
#                 'PKCF9': 0,
#                 'PKCF10': 0}, 'STATES': {'PHYTO': 40.0,
#                 'ZOO': 200.0,
#                 'BENAL': 5.0,
#                 'ORN': 20.0,
#                 'ORP': 20.0,
#                 'ORC': 20.0}},
#               ('RCHRES',
#                'PLANK',
#                'R004'): {'FLAGS': {'PHYFG': 1,
#                 'ZOOFG': 1,
#                 'BALFG': 1,
#                 'SDLTFG': 1,
#                 'AMRFG': 1,
#                 'DECFG': 0,
#                 'NSFG': 1,
#                 'ZFOOD': 2,
#                 'BNPFG': 0}, 'PARAMETERS': {'RATCLP': 0.6,
#                 'NONREF': 0.5,
#                 'LITSED': 0.0,
#                 'ALNPR': 1.0,
#                 'EXTB': 4.5,
#                 'MALGR': 0.3,
#                 'PARADF': 1.0,
#                 'SEED': 0.1,
#                 'MXSTAY': 0.1,
#                 'O': 0.0001,
#                 'CLALDH': 50.0,
#                 'PHYSET': 0.5,
#                 'REFSET': 0.5,
#                 'MZOEAT': 0.055,
#                 'ZFIL20': 0.2,
#                 'ZRES20': 0.0015,
#                 'ZD': 0.0001,
#                 'OXZD': 0.03}, 'SAVE': {'PHYTO': 0,
#                 'ZOO': 0,
#                 'BENAL': 0,
#                 'TBENAL': 0,
#                 'PHYCLA': 0,
#                 'BALCLA': 0,
#                 'PKST3': 0,
#                 'PKST4': 0,
#                 'PKIF': 0,
#                 'TPKIF': 0,
#                 'PKCF1': 0,
#                 'TPKCF1': 0,
#                 'PKCF2': 0,
#                 'TPKCF2': 0,
#                 'PLADDR': 0,
#                 'PLADWT': 0,
#                 'PLADEP': 0,
#                 'PKCF5': 0,
#                 'PKCF6': 0,
#                 'PKCF7': 0,
#                 'TPKCF7': 0,
#                 'PKCF8': 0,
#                 'PKCF9': 0,
#                 'PKCF10': 0}, 'STATES': {'PHYTO': 40.0,
#                 'ZOO': 200.0,
#                 'BENAL': 5.0,
#                 'ORN': 20.0,
#                 'ORP': 20.0,
#                 'ORC': 20.0}},
#               ('RCHRES',
#                'PLANK',
#                'R005'): {'FLAGS': {'PHYFG': 1,
#                 'ZOOFG': 1,
#                 'BALFG': 1,
#                 'SDLTFG': 1,
#                 'AMRFG': 1,
#                 'DECFG': 0,
#                 'NSFG': 1,
#                 'ZFOOD': 2,
#                 'BNPFG': 0}, 'PARAMETERS': {'RATCLP': 0.6,
#                 'NONREF': 0.5,
#                 'LITSED': 0.0,
#                 'ALNPR': 1.0,
#                 'EXTB': 4.5,
#                 'MALGR': 0.3,
#                 'PARADF': 1.0,
#                 'SEED': 0.1,
#                 'MXSTAY': 0.1,
#                 'O': 0.0001,
#                 'CLALDH': 50.0,
#                 'PHYSET': 0.5,
#                 'REFSET': 0.5,
#                 'MZOEAT': 0.055,
#                 'ZFIL20': 0.2,
#                 'ZRES20': 0.0015,
#                 'ZD': 0.0001,
#                 'OXZD': 0.03}, 'SAVE': {'PHYTO': 0,
#                 'ZOO': 0,
#                 'BENAL': 0,
#                 'TBENAL': 0,
#                 'PHYCLA': 0,
#                 'BALCLA': 0,
#                 'PKST3': 0,
#                 'PKST4': 0,
#                 'PKIF': 0,
#                 'TPKIF': 0,
#                 'PKCF1': 0,
#                 'TPKCF1': 0,
#                 'PKCF2': 0,
#                 'TPKCF2': 0,
#                 'PLADDR': 0,
#                 'PLADWT': 0,
#                 'PLADEP': 0,
#                 'PKCF5': 0,
#                 'PKCF6': 0,
#                 'PKCF7': 0,
#                 'TPKCF7': 0,
#                 'PKCF8': 0,
#                 'PKCF9': 0,
#                 'PKCF10': 0}, 'STATES': {'PHYTO': 40.0,
#                 'ZOO': 200.0,
#                 'BENAL': 5.0,
#                 'ORN': 20.0,
#                 'ORP': 20.0,
#                 'ORC': 20.0}},
#               ('RCHRES',
#                'PHCARB',
#                'R001'): {'PARAMETERS': {'PHCNT': 50,
#                 'ALKCON': 1}, 'SAVE': {'PHCF1': 0, 'PHCF2': 0, 'PHCF3': 0, 'PHIF': 0, 'PHST': 0, 'SATCO2': 0}, 'STATES': {'TIC': 20.0,
#                 'CO2': 5.0,
#                 'PH': 8.5}},
#               ('RCHRES',
#                'PHCARB',
#                'R002'): {'PARAMETERS': {'PHCNT': 50,
#                 'ALKCON': 1}, 'SAVE': {'PHCF1': 0, 'PHCF2': 0, 'PHCF3': 0, 'PHIF': 0, 'PHST': 0, 'SATCO2': 0}, 'STATES': {'TIC': 20.0,
#                 'CO2': 5.0,
#                 'PH': 8.5}},
#               ('RCHRES',
#                'PHCARB',
#                'R003'): {'PARAMETERS': {'PHCNT': 50,
#                 'ALKCON': 1}, 'SAVE': {'PHCF1': 0, 'PHCF2': 0, 'PHCF3': 0, 'PHIF': 0, 'PHST': 0, 'SATCO2': 0}, 'STATES': {'TIC': 20.0,
#                 'CO2': 5.0,
#                 'PH': 8.5}},
#               ('RCHRES',
#                'PHCARB',
#                'R004'): {'PARAMETERS': {'PHCNT': 50,
#                 'ALKCON': 1}, 'SAVE': {'PHCF1': 0, 'PHCF2': 0, 'PHCF3': 0, 'PHIF': 0, 'PHST': 0, 'SATCO2': 0}, 'STATES': {'TIC': 20.0,
#                 'CO2': 5.0,
#                 'PH': 8.5}},
#               ('RCHRES',
#                'PHCARB',
#                'R005'): {'PARAMETERS': {'PHCNT': 50,
#                 'ALKCON': 1}, 'SAVE': {'PHCF1': 0, 'PHCF2': 0, 'PHCF3': 0, 'PHIF': 0, 'PHST': 0, 'SATCO2': 0}, 'STATES': {'TIC': 20.0,
#                 'CO2': 5.0,
#                 'PH': 8.5}},
#               ('RCHRES', 'OXRX', 'R002'): {'FLAGS': {'REAMFG': 1.0},
#                'PARAMETERS': {'KBOD20': 0.1,
#                 'TCBOD': 1.075,
#                 'KODSET': 8.0,
#                 'SUPSAT': 1.15,
#                 'BENOD': 10.0,
#                 'TCBEN': 1.1,
#                 'EXPOD': 1.2,
#                 'BRBOD1': 20.0,
#                 'BRBOD2': 25.0,
#                 'EXPREL': 1.3,
#                 'CFOREA': 1.0,
#                 'TCGINV': 1.047,
#                 'REAK': -999.0,
#                 'EXPRED': 0.0,
#                 'EXPREV': 0.0},
#                'SAVE': {'BOD': 0,
#                 'DOX': 0,
#                 'OXCF1': 0,
#                 'OXCF2': 0,
#                 'OXCF3': 0,
#                 'OXCF4': 0,
#                 'OXIF': 0,
#                 'SATDO': 0},
#                'STATES': {'DOX': 8.0, 'BOD': 100.0, 'SATDO': 10.0}},
#               ('RCHRES', 'OXRX', 'R003'): {'FLAGS': {'REAMFG': 1.0},
#                'PARAMETERS': {'KBOD20': 0.1,
#                 'TCBOD': 1.075,
#                 'KODSET': 8.0,
#                 'SUPSAT': 1.15,
#                 'BENOD': 10.0,
#                 'TCBEN': 1.1,
#                 'EXPOD': 1.2,
#                 'BRBOD1': 20.0,
#                 'BRBOD2': 25.0,
#                 'EXPREL': 1.3,
#                 'CFOREA': 1.0,
#                 'TCGINV': 1.047,
#                 'REAK': -999.0,
#                 'EXPRED': 0.0,
#                 'EXPREV': 0.0},
#                'SAVE': {'BOD': 0,
#                 'DOX': 0,
#                 'OXCF1': 0,
#                 'OXCF2': 0,
#                 'OXCF3': 0,
#                 'OXCF4': 0,
#                 'OXIF': 0,
#                 'SATDO': 0},
#                'STATES': {'DOX': 8.0, 'BOD': 100.0, 'SATDO': 10.0}},
#               ('RCHRES', 'OXRX', 'R004'): {'FLAGS': {'REAMFG': 3.0},
#                'PARAMETERS': {'KBOD20': 0.1,
#                 'TCBOD': 1.075,
#                 'KODSET': 8.0,
#                 'SUPSAT': 1.15,
#                 'BENOD': 10.0,
#                 'TCBEN': 1.1,
#                 'EXPOD': 1.2,
#                 'BRBOD1': 20.0,
#                 'BRBOD2': 25.0,
#                 'EXPREL': 1.3,
#                 'CFOREA': 1.0,
#                 'TCGINV': 1.047,
#                 'REAK': 2.0,
#                 'EXPRED': -1.1,
#                 'EXPREV': 1.1},
#                'SAVE': {'BOD': 0,
#                 'DOX': 0,
#                 'OXCF1': 0,
#                 'OXCF2': 0,
#                 'OXCF3': 0,
#                 'OXCF4': 0,
#                 'OXIF': 0,
#                 'SATDO': 0},
#                'STATES': {'DOX': 8.0, 'BOD': 100.0, 'SATDO': 10.0}},
#               ('RCHRES', 'OXRX', 'R005'): {'FLAGS': {'REAMFG': 2.0},
#                'PARAMETERS': {'KBOD20': 0.1,
#                 'TCBOD': 1.075,
#                 'KODSET': 8.0,
#                 'SUPSAT': 1.15,
#                 'BENOD': 10.0,
#                 'TCBEN': 1.1,
#                 'EXPOD': 1.2,
#                 'BRBOD1': 20.0,
#                 'BRBOD2': 25.0,
#                 'EXPREL': 1.3,
#                 'CFOREA': 1.0,
#                 'TCGINV': 1.047,
#                 'REAK': -999.0,
#                 'EXPRED': 0.0,
#                 'EXPREV': 0.0},
#                'SAVE': {'BOD': 0,
#                 'DOX': 0,
#                 'OXCF1': 0,
#                 'OXCF2': 0,
#                 'OXCF3': 0,
#                 'OXCF4': 0,
#                 'OXIF': 0,
#                 'SATDO': 0},
#                'STATES': {'DOX': 8.0, 'BOD': 100.0, 'SATDO': 10.0}},
#               ('RCHRES', 'OXRX', 'R001'): {'FLAGS': {'REAMFG': 2.0},
#                'PARAMETERS': {'KBOD20': 0.1,
#                 'TCBOD': 1.075,
#                 'KODSET': 8.0,
#                 'SUPSAT': 1.15,
#                 'BENOD': 10.0,
#                 'TCBEN': 1.1,
#                 'EXPOD': 1.2,
#                 'BRBOD1': 20.0,
#                 'BRBOD2': 25.0,
#                 'EXPREL': 1.3,
#                 'CFOREA': 5.0,
#                 'TCGINV': 1.047,
#                 'REAK': -999.0,
#                 'EXPRED': 0.0,
#                 'EXPREV': 0.0},
#                'SAVE': {'BOD': 0,
#                 'DOX': 0,
#                 'OXCF1': 0,
#                 'OXCF2': 0,
#                 'OXCF3': 0,
#                 'OXCF4': 0,
#                 'OXIF': 0,
#                 'SATDO': 0},
#                'STATES': {'DOX': 8.0, 'BOD': 100.0, 'SATDO': 10.0}},
#               ('RCHRES',
#                'NUTRX',
#                'R001'): {'FLAGS': {'NH3FG': 1,
#                 'NO2FG': 1,
#                 'PO4FG': 1,
#                 'AMVFG': 1,
#                 'DENFG': 1,
#                 'ADNHFG': 0,
#                 'ADPOFG': 0,
#                 'PHFLAG': 2}, 'PARAMETERS': {'BRNIT1': 11.0,
#                 'BRNIT2': 33.0,
#                 'BRPO41': 1.1,
#                 'BRPO42': 2.2,
#                 'ANAER': 0.0005,
#                 'KTAM20': 0.002,
#                 'KNO220': 0.004,
#                 'TCNIT': 1.07,
#                 'KNO320': 0.001,
#                 'TCDEN': 1.04,
#                 'DENOXT': 0.2,
#                 'EXPNVG': 0.5,
#                 'EXPNVL': 0.6667,
#                 'BNH41': 1e-05,
#                 'BNH42': 1e-05,
#                 'BNH43': 1e-05,
#                 'BPO41': 1e-05,
#                 'BPO42': 1e-05,
#                 'BPO43': 1e-05,
#                 'ADNHPM1': 0.0001,
#                 'ADNHPM2': 0.0001,
#                 'ADNHPM3': 0.0001,
#                 'ADPOPM1': 10.0,
#                 'ADPOPM2': 10.0,
#                 'ADPOPM3': 10.0}, 'SAVE': {'DNUST': 0,
#                 'DNUST2': 0,
#                 'NUADDR': 0,
#                 'NUADEP': 0,
#                 'NUADWT': 0,
#                 'NUCF1': 0,
#                 'NUCF2': 0,
#                 'NUCF3': 0,
#                 'NUCF4': 0,
#                 'NUCF5': 0,
#                 'NUCF6': 0,
#                 'NUCF7': 0,
#                 'NUCF8': 0,
#                 'NUCF9': 0,
#                 'NUIF1': 0,
#                 'NUIF2': 0,
#                 'NUST': 0,
#                 'OSNH4': 0,
#                 'OSPO4': 0,
#                 'RSNH4': 0,
#                 'RSPO4': 0,
#                 'SNH4': 0,
#                 'SPO4': 0,
#                 'TNUCF1': 0,
#                 'TNUCF2': 0,
#                 'TNUIF': 0}, 'STATES': {'NO3': 40.0,
#                 'TAM': 10.0,
#                 'NO2': 1.0,
#                 'PO4': 50.0,
#                 'PHVAL': 7.0,
#                 'SNH41': 0.0,
#                 'SNH42': 0.0,
#                 'SNH43': 0.0,
#                 'SPO41': 0.0,
#                 'SPO42': 0.0,
#                 'SPO43': 0.0}},
#               ('RCHRES',
#                'NUTRX',
#                'R002'): {'FLAGS': {'NH3FG': 1,
#                 'NO2FG': 1,
#                 'PO4FG': 1,
#                 'AMVFG': 1,
#                 'DENFG': 1,
#                 'ADNHFG': 0,
#                 'ADPOFG': 0,
#                 'PHFLAG': 2}, 'PARAMETERS': {'BRNIT1': 11.0,
#                 'BRNIT2': 33.0,
#                 'BRPO41': 1.1,
#                 'BRPO42': 2.2,
#                 'ANAER': 0.0005,
#                 'KTAM20': 0.002,
#                 'KNO220': 0.004,
#                 'TCNIT': 1.07,
#                 'KNO320': 0.001,
#                 'TCDEN': 1.04,
#                 'DENOXT': 0.2,
#                 'EXPNVG': 0.5,
#                 'EXPNVL': 0.6667,
#                 'BNH41': 1e-05,
#                 'BNH42': 1e-05,
#                 'BNH43': 1e-05,
#                 'BPO41': 1e-05,
#                 'BPO42': 1e-05,
#                 'BPO43': 1e-05,
#                 'ADNHPM1': 0.0001,
#                 'ADNHPM2': 0.0001,
#                 'ADNHPM3': 0.0001,
#                 'ADPOPM1': 10.0,
#                 'ADPOPM2': 10.0,
#                 'ADPOPM3': 10.0}, 'SAVE': {'DNUST': 0,
#                 'DNUST2': 0,
#                 'NUADDR': 0,
#                 'NUADEP': 0,
#                 'NUADWT': 0,
#                 'NUCF1': 0,
#                 'NUCF2': 0,
#                 'NUCF3': 0,
#                 'NUCF4': 0,
#                 'NUCF5': 0,
#                 'NUCF6': 0,
#                 'NUCF7': 0,
#                 'NUCF8': 0,
#                 'NUCF9': 0,
#                 'NUIF1': 0,
#                 'NUIF2': 0,
#                 'NUST': 0,
#                 'OSNH4': 0,
#                 'OSPO4': 0,
#                 'RSNH4': 0,
#                 'RSPO4': 0,
#                 'SNH4': 0,
#                 'SPO4': 0,
#                 'TNUCF1': 0,
#                 'TNUCF2': 0,
#                 'TNUIF': 0}, 'STATES': {'NO3': 40.0,
#                 'TAM': 10.0,
#                 'NO2': 1.0,
#                 'PO4': 50.0,
#                 'PHVAL': 7.0,
#                 'SNH41': 0.0,
#                 'SNH42': 0.0,
#                 'SNH43': 0.0,
#                 'SPO41': 0.0,
#                 'SPO42': 0.0,
#                 'SPO43': 0.0}},
#               ('RCHRES',
#                'NUTRX',
#                'R003'): {'FLAGS': {'NH3FG': 1,
#                 'NO2FG': 1,
#                 'PO4FG': 1,
#                 'AMVFG': 1,
#                 'DENFG': 1,
#                 'ADNHFG': 0,
#                 'ADPOFG': 0,
#                 'PHFLAG': 2}, 'PARAMETERS': {'BRNIT1': 11.0,
#                 'BRNIT2': 33.0,
#                 'BRPO41': 1.1,
#                 'BRPO42': 2.2,
#                 'ANAER': 0.0005,
#                 'KTAM20': 0.002,
#                 'KNO220': 0.004,
#                 'TCNIT': 1.07,
#                 'KNO320': 0.001,
#                 'TCDEN': 1.04,
#                 'DENOXT': 0.2,
#                 'EXPNVG': 0.5,
#                 'EXPNVL': 0.6667,
#                 'BNH41': 1e-05,
#                 'BNH42': 1e-05,
#                 'BNH43': 1e-05,
#                 'BPO41': 1e-05,
#                 'BPO42': 1e-05,
#                 'BPO43': 1e-05,
#                 'ADNHPM1': 0.0001,
#                 'ADNHPM2': 0.0001,
#                 'ADNHPM3': 0.0001,
#                 'ADPOPM1': 10.0,
#                 'ADPOPM2': 10.0,
#                 'ADPOPM3': 10.0}, 'SAVE': {'DNUST': 0,
#                 'DNUST2': 0,
#                 'NUADDR': 0,
#                 'NUADEP': 0,
#                 'NUADWT': 0,
#                 'NUCF1': 0,
#                 'NUCF2': 0,
#                 'NUCF3': 0,
#                 'NUCF4': 0,
#                 'NUCF5': 0,
#                 'NUCF6': 0,
#                 'NUCF7': 0,
#                 'NUCF8': 0,
#                 'NUCF9': 0,
#                 'NUIF1': 0,
#                 'NUIF2': 0,
#                 'NUST': 0,
#                 'OSNH4': 0,
#                 'OSPO4': 0,
#                 'RSNH4': 0,
#                 'RSPO4': 0,
#                 'SNH4': 0,
#                 'SPO4': 0,
#                 'TNUCF1': 0,
#                 'TNUCF2': 0,
#                 'TNUIF': 0}, 'STATES': {'NO3': 40.0,
#                 'TAM': 10.0,
#                 'NO2': 1.0,
#                 'PO4': 50.0,
#                 'PHVAL': 7.0,
#                 'SNH41': 0.0,
#                 'SNH42': 0.0,
#                 'SNH43': 0.0,
#                 'SPO41': 0.0,
#                 'SPO42': 0.0,
#                 'SPO43': 0.0}},
#               ('RCHRES',
#                'NUTRX',
#                'R004'): {'FLAGS': {'NH3FG': 1,
#                 'NO2FG': 1,
#                 'PO4FG': 1,
#                 'AMVFG': 1,
#                 'DENFG': 1,
#                 'ADNHFG': 0,
#                 'ADPOFG': 0,
#                 'PHFLAG': 2}, 'PARAMETERS': {'BRNIT1': 11.0,
#                 'BRNIT2': 33.0,
#                 'BRPO41': 1.1,
#                 'BRPO42': 2.2,
#                 'ANAER': 0.0005,
#                 'KTAM20': 0.002,
#                 'KNO220': 0.004,
#                 'TCNIT': 1.07,
#                 'KNO320': 0.001,
#                 'TCDEN': 1.04,
#                 'DENOXT': 0.2,
#                 'EXPNVG': 0.5,
#                 'EXPNVL': 0.6667,
#                 'BNH41': 1e-05,
#                 'BNH42': 1e-05,
#                 'BNH43': 1e-05,
#                 'BPO41': 1e-05,
#                 'BPO42': 1e-05,
#                 'BPO43': 1e-05,
#                 'ADNHPM1': 0.0001,
#                 'ADNHPM2': 0.0001,
#                 'ADNHPM3': 0.0001,
#                 'ADPOPM1': 10.0,
#                 'ADPOPM2': 10.0,
#                 'ADPOPM3': 10.0}, 'SAVE': {'DNUST': 0,
#                 'DNUST2': 0,
#                 'NUADDR': 0,
#                 'NUADEP': 0,
#                 'NUADWT': 0,
#                 'NUCF1': 0,
#                 'NUCF2': 0,
#                 'NUCF3': 0,
#                 'NUCF4': 0,
#                 'NUCF5': 0,
#                 'NUCF6': 0,
#                 'NUCF7': 0,
#                 'NUCF8': 0,
#                 'NUCF9': 0,
#                 'NUIF1': 0,
#                 'NUIF2': 0,
#                 'NUST': 0,
#                 'OSNH4': 0,
#                 'OSPO4': 0,
#                 'RSNH4': 0,
#                 'RSPO4': 0,
#                 'SNH4': 0,
#                 'SPO4': 0,
#                 'TNUCF1': 0,
#                 'TNUCF2': 0,
#                 'TNUIF': 0}, 'STATES': {'NO3': 40.0,
#                 'TAM': 10.0,
#                 'NO2': 1.0,
#                 'PO4': 50.0,
#                 'PHVAL': 7.0,
# ...
#                 'HTRCH': 1,
#                 'SEDTRN': 1,
#                 'GQUAL': 1,
#                 'OXRX': 1,
#                 'NUTRX': 1,
#                 'PLANK': 1,
#                 'PHCARB': 1}, 'INFO': {'RCHID': 'OUTLET',
#                 'IUNITS': 1,
#                 'OUNITS': 1,
#                 'PUNITE': 1,
#                 'PUNITM': 0,
#                 'BUNITE': 0,
#                 'BUNITM': 0}},
#               ('RCHRES',
#                'GENERAL',
#                'R003'): {'ACTIVITY': {'HYDR': 1,
#                 'ADCALC': 1,
#                 'CONS': 1,
#                 'HTRCH': 1,
#                 'SEDTRN': 1,
#                 'GQUAL': 1,
#                 'OXRX': 1,
#                 'NUTRX': 1,
#                 'PLANK': 1,
#                 'PHCARB': 1}, 'INFO': {'RCHID': 'SPILLWAY',
#                 'IUNITS': 1,
#                 'OUNITS': 1,
#                 'PUNITE': 1,
#                 'PUNITM': 0,
#                 'BUNITE': 0,
#                 'BUNITM': 0}},
#               ('RCHRES',
#                'GENERAL',
#                'R004'): {'ACTIVITY': {'HYDR': 1,
#                 'ADCALC': 1,
#                 'CONS': 1,
#                 'HTRCH': 1,
#                 'SEDTRN': 1,
#                 'GQUAL': 1,
#                 'OXRX': 1,
#                 'NUTRX': 1,
#                 'PLANK': 1,
#                 'PHCARB': 1}, 'INFO': {'RCHID': 'UPPER KITTLE CREEK',
#                 'IUNITS': 1,
#                 'OUNITS': 1,
#                 'PUNITE': 1,
#                 'PUNITM': 0,
#                 'BUNITE': 0,
#                 'BUNITM': 0}},
#               ('RCHRES',
#                'GENERAL',
#                'R005'): {'ACTIVITY': {'HYDR': 1,
#                 'ADCALC': 1,
#                 'CONS': 1,
#                 'HTRCH': 1,
#                 'SEDTRN': 1,
#                 'GQUAL': 1,
#                 'OXRX': 1,
#                 'NUTRX': 1,
#                 'PLANK': 1,
#                 'PHCARB': 1}, 'INFO': {'RCHID': 'LOWER KITTLE CREEK',
#                 'IUNITS': 1,
#                 'OUNITS': 1,
#                 'PUNITE': 1,
#                 'PUNITM': 0,
#                 'BUNITE': 0,
#                 'BUNITM': 0}},
#               ('RCHRES',
#                'CONS',
#                'R001'): {'CONS1': {'CONID': 'ALKALINITY',
#                 'CON': 1000.0,
#                 'CONCID': 'MG/L',
#                 'CONV': 35.31,
#                 'QTYID': 'KG'}, 'PARAMETERS': {'NCONS': 1}, 'SAVE': {'COADDR': 0,
#                 'COADEP': 0,
#                 'COADWT': 0,
#                 'CON': 0,
#                 'ICON': 0,
#                 'OCON': 0,
#                 'ROCON': 0}},
#               ('RCHRES',
#                'CONS',
#                'R002'): {'CONS1': {'CONID': 'ALKALINITY',
#                 'CON': 1000.0,
#                 'CONCID': 'MG/L',
#                 'CONV': 35.31,
#                 'QTYID': 'KG'}, 'PARAMETERS': {'NCONS': 1}, 'SAVE': {'COADDR': 0,
#                 'COADEP': 0,
#                 'COADWT': 0,
#                 'CON': 0,
#                 'ICON': 0,
#                 'OCON': 0,
#                 'ROCON': 0}},
#               ('RCHRES',
#                'CONS',
#                'R003'): {'CONS1': {'CONID': 'ALKALINITY',
#                 'CON': 1000.0,
#                 'CONCID': 'MG/L',
#                 'CONV': 35.31,
#                 'QTYID': 'KG'}, 'PARAMETERS': {'NCONS': 1}, 'SAVE': {'COADDR': 0,
#                 'COADEP': 0,
#                 'COADWT': 0,
#                 'CON': 0,
#                 'ICON': 0,
#                 'OCON': 0,
#                 'ROCON': 0}},
#               ('RCHRES',
#                'CONS',
#                'R004'): {'CONS1': {'CONID': 'ALKALINITY',
#                 'CON': 1000.0,
#                 'CONCID': 'MG/L',
#                 'CONV': 35.31,
#                 'QTYID': 'KG'}, 'PARAMETERS': {'NCONS': 1}, 'SAVE': {'COADDR': 0,
#                 'COADEP': 0,
#                 'COADWT': 0,
#                 'CON': 0,
#                 'ICON': 0,
#                 'OCON': 0,
#                 'ROCON': 0}},
#               ('RCHRES',
#                'CONS',
#                'R005'): {'CONS1': {'CONID': 'ALKALINITY',
#                 'CON': 1000.0,
#                 'CONCID': 'MG/L',
#                 'CONV': 35.31,
#                 'QTYID': 'KG'}, 'PARAMETERS': {'NCONS': 1}, 'SAVE': {'COADDR': 0,
#                 'COADEP': 0,
#                 'COADWT': 0,
#                 'CON': 0,
#                 'ICON': 0,
#                 'OCON': 0,
#                 'ROCON': 0}},
#               ('PERLND', 'SNOW', 'P001'): {'FLAGS': {'ICEFG': 1, 'SNOPFG': 0},
#                'PARAMETERS': {'LAT': 42.0,
#                 'MELEV': 520.0,
#                 'SHADE': 0.0,
#                 'SNOWCF': 1.45,
#                 'COVIND': 0.5,
#                 'KMELT': 0.0,
#                 'TBASE': 32.0,
#                 'RDCSN': 0.12,
#                 'TSNOW': 32.0,
#                 'SNOEVP': 0.05,
#                 'CCFACT': 0.5,
#                 'MWATER': 0.08,
#                 'MGMELT': 0.0001},
#                'SAVE': {'ALBEDO': 0,
#                 'COVINX': 1,
#                 'DEWTMP': 0,
#                 'DULL': 1,
#                 'MELT': 0,
#                 'NEGHTS': 0,
#                 'PACKF': 1,
#                 'PACKI': 1,
#                 'PACKW': 1,
#                 'PACK': 1,
#                 'PAKTMP': 1,
#                 'PDEPTH': 0,
#                 'PRAIN': 0,
#                 'RAINF': 1,
#                 'RDENPF': 1,
#                 'SKYCLR': 1,
#                 'SNOCOV': 1,
#                 'SNOTMP': 0,
#                 'SNOWE': 0,
#                 'SNOWF': 0,
#                 'WYIELD': 1,
#                 'XLNMLT': 1},
#                'STATES': {'PACKF': 1.4,
#                 'PACKI': 0.2,
#                 'PACKW': 0.1,
#                 'RDENPF': 0.2,
#                 'DULL': 375.0,
#                 'PAKTMP': 27.5,
#                 'COVINX': 0.5,
#                 'XLNMLT': 0.0,
#                 'SKYCLR': 1.0}},
#               ('PERLND',
#                'PWTGAS',
#                'P001'): {'PARAMETERS': {'ELEV': 500.0,
#                 'IDOXP': 6.0,
#                 'ICO2P': 0.05,
#                 'ADOXP': 5.0,
#                 'ACO2P': 0.05,
#                 'SDLFAC': 0.0,
#                 'SLIFAC': 0.0,
#                 'ILIFAC': 0.0,
#                 'ALIFAC': 0.0,
#                 'SOTMP': 60.0,
#                 'IOTMP': 60.0,
#                 'AOTMP': 60.0,
#                 'SODOX': 0.0,
#                 'SOCO2': 0.0,
#                 'IODOX': 0.0,
#                 'IOCO2': 0.0,
#                 'AODOX': 0.0,
#                 'AOCO2': 0.0}, 'SAVE': {'AOCO2': 0,
#                 'AOCO2M': 0,
#                 'AODOX': 0,
#                 'AODOXM': 0,
#                 'AOHT': 0,
#                 'AOTMP': 0,
#                 'IOCO2': 0,
#                 'IOCO2M': 0,
#                 'IODOX': 0,
#                 'IODOXM': 0,
#                 'IOHT': 0,
#                 'IOTMP': 0,
#                 'POCO2M': 0,
#                 'PODOXM': 0,
#                 'POHT': 0,
#                 'SOCO2': 0,
#                 'SOCO2M': 0,
#                 'SODOX': 0,
#                 'SODOXM': 0,
#                 'SOHT': 0,
#                 'SOTMP': 0}},
#               ('PERLND',
#                'PWATER',
#                'P001'): {'PARAMETERS': {'CSNOFG': 1,
#                 'RTOPFG': 0,
#                 'UZFG': 0,
#                 'VCSFG': 1,
#                 'VUZFG': 1,
#                 'VNNFG': 1,
#                 'VIFWFG': 0,
#                 'VIRCFG': 0,
#                 'VLEFG': 1,
#                 'IFFCFG': 1,
#                 'HWTFG': 0,
#                 'IRRGFG': 0,
#                 'IFRDFG': 0,
#                 'FOREST': 0.01,
#                 'LZSN': 8.0,
#                 'INFILT': 0.15,
#                 'LSUR': 250.0,
#                 'SLSUR': 0.05,
#                 'KVARY': 0.5,
#                 'AGWRC': 0.98,
#                 'PETMAX': 40.0,
#                 'PETMIN': 35.0,
#                 'INFEXP': 2.0,
#                 'INFILD': 2.0,
#                 'DEEPFR': 0.1,
#                 'BASETP': 0.0,
#                 'AGWETP': 0.08,
#                 'CEPSC': 0.0,
#                 'UZSN': 0.01,
#                 'NSUR': 0.1,
#                 'INTFW': 1.0,
#                 'IRC': 0.6,
#                 'LZETP': 0.0,
#                 'FZG': 1.0,
#                 'FZGL': 0.1}, 'SAVE': {'AGWET': 0,
#                 'AGWLI': 0,
#                 'AGWI': 0,
#                 'AGWO': 1,
#                 'AGWS': 1,
#                 'BASET': 0,
#                 'CEPE': 0,
#                 'CEPS': 1,
#                 'GWVS': 1,
#                 'IFWI': 0,
#                 'IFWLI': 0,
#                 'IFWO': 1,
#                 'IFWS': 1,
#                 'IGWI': 0,
#                 'INFIL': 0,
#                 'IRDRAW': 0,
#                 'IRRAPP': 0,
#                 'IRRDEM': 0,
#                 'IRSHRT': 0,
#                 'LZET': 0,
#                 'LZI': 0,
#                 'LZLI': 0,
#                 'LZS': 1,
#                 'RPARM': 0,
#                 'PERC': 0,
#                 'PERO': 1,
#                 'PERS': 0,
#                 'PET': 0,
#                 'PETADJ': 0,
#                 'RZWS': 0,
#                 'SUPY': 0,
#                 'SURET': 0,
#                 'SURLI': 0,
#                 'SURI': 0,
#                 'SURO': 1,
#                 'SURS': 1,
#                 'TAET': 0,
#                 'TGWS': 0,
#                 'UZET': 0,
#                 'UZI': 0,
#                 'UZLI': 0,
#                 'UZS': 1,
#                 'INFFAC': 0}, 'STATES': {'CEPS': 0.05,
#                 'SURS': 0.0,
#                 'UZS': 0.15,
#                 'IFWS': 0.0,
#                 'LZS': 4.0,
#                 'AGWS': 0.05,
#                 'GWVS': 0.05}, 'MONTHLY_CEPSC': {'JAN': 0.04,
#                 'FEB': 0.04,
#                 'MAR': 0.03,
#                 'APR': 0.03,
#                 'MAY': 0.03,
#                 'JUN': 0.03,
#                 'JUL': 0.1,
#                 'AUG': 0.17,
#                 'SEP': 0.19,
#                 'OCT': 0.14,
#                 'NOV': 0.05,
#                 'DEC': 0.04}, 'MONTHLY_LZETP': {'JAN': 0.2,
#                 'FEB': 0.2,
#                 'MAR': 0.2,
#                 'APR': 0.23,
#                 'MAY': 0.23,
#                 'JUN': 0.25,
#                 'JUL': 0.6,
#                 'AUG': 0.8,
#                 'SEP': 0.75,
#                 'OCT': 0.5,
#                 'NOV': 0.3,
#                 'DEC': 0.2}, 'MONTHLY_NSUR': {'JAN': 0.3,
#                 'FEB': 0.3,
#                 'MAR': 0.3,
#                 'APR': 0.3,
#                 'MAY': 0.27,
#                 'JUN': 0.25,
#                 'JUL': 0.25,
#                 'AUG': 0.25,
#                 'SEP': 0.25,
#                 'OCT': 0.25,
#                 'NOV': 0.35,
#                 'DEC': 0.33}, 'MONTHLY_UZSN': {'JAN': 0.4,
#                 'FEB': 0.4,
#                 'MAR': 0.4,
#                 'APR': 0.4,
#                 'MAY': 1.6,
#                 'JUN': 1.1,
#                 'JUL': 1.1,
#                 'AUG': 1.3,
#                 'SEP': 1.3,
#                 'OCT': 1.3,
#                 'NOV': 1.1,
#                 'DEC': 0.9}},
#               ('PERLND',
#                'PSTEMP',
#                'P001'): {'PARAMETERS': {'ASLT': 14.5,
#                 'BSLT': 0.365,
#                 'ULTP1': 1.2,
#                 'ULTP2': 4.0,
#                 'LGTP1': 1.2,
#                 'LGTP2': 6.0}, 'SAVE': {'AIRTC': 0,
#                 'LGTMP': 0,
#                 'SLTMP': 0,
#                 'ULTMP': 0}},
#               ('PERLND',
#                'GENERAL',
#                'P001'): {'ACTIVITY': {'ATEMP': 0,
#                 'SNOW': 1,
#                 'PWATER': 1,
#                 'SEDMNT': 0,
#                 'PSTEMP': 1,
#                 'PWTGAS': 1,
#                 'PQUAL': 0,
#                 'MSTLAY': 0,
#                 'PEST': 0,
#                 'NITR': 0,
#                 'PHOS': 0,
#                 'TRACER': 0}, 'INFO': {'LSID': 'BICKNELL FARM',
#                 'IUNITS': 1,
#                 'OUNITS': 1,
#                 'PUNIT1': 1,
#                 'PUNIT2': 0,
#                 'BUNIT1': 0,
#                 'BUNIT2': 0}},
#               ('IMPLND',
#                'SOLIDS',
#                'I001'): {'PARAMETERS': {'KEIM': 0.08,
#                 'JEIM': 1.9,
#                 'ACCSDP': 0.01,
#                 'REMSDP': 0.5,
#                 'SLDS': 0.2}, 'SAVE': {'SLDS': 0, 'SOSLD': 0}},
#               ('IMPLND', 'SNOW', 'I001'): {'FLAGS': {'ICEFG': 1, 'SNOPFG': 0},
#                'PARAMETERS': {'LAT': 42.0,
#                 'MELEV': 450.0,
#                 'SHADE': 0.0,
#                 'SNOWCF': 1.45,
#                 'COVIND': 0.5,
#                 'KMELT': 0.0,
#                 'TBASE': 32.0,
#                 'RDCSN': 0.12,
#                 'TSNOW': 32.0,
#                 'SNOEVP': 0.05,
#                 'CCFACT': 0.5,
#                 'MWATER': 0.08,
#                 'MGMELT': 0.0001},
#                'SAVE': {'ALBEDO': 0,
#                 'COVINX': 1,
#                 'DEWTMP': 0,
#                 'DULL': 1,
#                 'MELT': 0,
#                 'NEGHTS': 0,
#                 'PACKF': 1,
#                 'PACKI': 1,
#                 'PACKW': 1,
#                 'PACK': 1,
#                 'PAKTMP': 1,
#                 'PDEPTH': 0,
#                 'PRAIN': 0,
#                 'RAINF': 1,
#                 'RDENPF': 1,
#                 'SKYCLR': 1,
#                 'SNOCOV': 1,
#                 'SNOTMP': 0,
#                 'SNOWE': 0,
#                 'SNOWF': 0,
#                 'WYIELD': 1,
#                 'XLNMLT': 1},
#                'STATES': {'PACKF': 1.4,
#                 'PACKI': 0.2,
#                 'PACKW': 0.1,
#                 'RDENPF': 0.2,
#                 'DULL': 375.0,
#                 'PAKTMP': 27.5,
#                 'COVINX': 0.5,
#                 'XLNMLT': 0.0,
#                 'SKYCLR': 1.0}},
#               ('IMPLND',
#                'IWTGAS',
#                'I001'): {'PARAMETERS': {'ELEV': 410.0,
#                 'AWTF': 40.0,
#                 'BWTF': 0.8,
#                 'SDLFAC': 0.0,
#                 'SLIFAC': 0.0,
#                 'SOTMP': 60.0,
#                 'SODOX': 0.0,
#                 'SOCO2': 0.0}, 'SAVE': {'SOTMP': 0,
#                 'SODOX': 0,
#                 'SOCO2': 0,
#                 'SOHT': 0,
#                 'SODOXM': 0,
#                 'SOCO2M': 0}},
#               ('IMPLND',
#                'IWATER',
#                'I001'): {'PARAMETERS': {'CSNOFG': 1,
#                 'RTOPFG': 0,
#                 'VRSFG': 0,
#                 'VNNFG': 0,
#                 'RTLIFG': 1,
#                 'LSUR': 200.0,
#                 'SLSUR': 0.01,
#                 'NSUR': 0.01,
#                 'RETSC': 0.01,
#                 'PETMAX': 40.0,
#                 'PETMIN': 35.0}, 'SAVE': {'IMPEV': 0,
#                 'PET': 0,
#                 'PETADJ': 0,
#                 'RETS': 1,
#                 'SUPY': 0,
#                 'SURI': 0,
#                 'SURO': 1,
#                 'SURS': 1}, 'STATES': {'RETS': 0.01, 'SURS': 0.01}},
#               ('IMPLND',
#                'IQUAL',
#                'I001'): {'PARAMETERS': {'NQUAL': 1,
#                 'SDLFAC': 0.0,
#                 'SLIFAC': 0.0}, 'SAVE': {'SQO': 0,
#                 'SOQSP': 0,
#                 'SOQS': 0,
#                 'SOQO': 0,
#                 'SOQOC': 0,
#                 'SOQUAL': 0,
#                 'SOQC': 0,
#                 'IQADDR': 0,
#                 'IQADWT': 0,
#                 'IQADEP': 0}, 'IQUAL1_FLAGS': {'QUALID': 'COD',
#                 'QTYID': 'LB',
#                 'QSDFG': 1,
#                 'VPFWFG': 0,
#                 'QSOFG': 1,
#                 'VQOFG': 0}, 'IQUAL1_PARAMETERS': {'SQO': 1.2,
#                 'POTFW': 0.175,
#                 'ACQOP': 0.02,
#                 'SQOLIM': 2.0,
#                 'WSQOP': 1.7}},
#               ('IMPLND',
#                'GENERAL',
#                'I001'): {'ACTIVITY': {'ATEMP': 0,
#                 'SNOW': 1,
#                 'IWATER': 1,
#                 'SOLIDS': 1,
#                 'IWTGAS': 1,
#                 'IQUAL': 1}, 'INFO': {'LSID': 'DONIGIAN INDUSTRY',
#                 'IUNITS': 1,
#                 'OUNITS': 1,
#                 'PUNIT1': 1,
#                 'PUNIT2': 0,
#                 'BUNIT1': 0,
#                 'BUNIT2': 0}}}),
#  {'start': Timestamp('1976-01-01 00:00:00'),
#   'stop': Timestamp('1977-01-01 00:00:00')})

# %% [markdown]
# # Open an HSP2-created HDF5 file with PyTables
#
# Docs: https://www.pytables.org
# Demo: https://nbviewer.jupyter.org/github/jackdbd/hdf5-pydata-munich/blob/master/hdf5_in_python.ipynb
#
# Key points:
# - PyTables files have different parameters,attributes and methods than those created with H5py.
# - After processing data,
#   - "flushing a table (i.e. `table.flush()`) is a very important step as it will not only help to maintain the integrity of your file, but also will free valuable memory resources (i.e. internal buffers)". See https://www.pytables.org/usersguide/tutorials.html#creating-a-new-table
# - After opening a file,
#   - It is important to close it (i.e. `h5file.close()`), otherwise it will be corrupted to other programs. See https://www.pytables.org/usersguide/tutorials.html#closing-the-file-and-looking-at-its-content

# %%
# Open HSP2 HDF5 file with PyTables
h5file0 = tables.open_file(
   paths[0],
)
# For a PyTables file, a dump of the object tree can be easily displayed
# Warning: Output is quite verbose!

# h5file0  # Comment out to avoid display

# %% [markdown]
# Copy/Paste output into a YAML file for split diff comparisons

# %%
h5file0.isopen
# Out:
# 0

# %%
# Always close an HDF5 file!
h5file0.close()

# %%
h5file1 = tables.open_file(
   paths[1],
)
# h5file1

# %%
h5file1.close()

# %% [markdown]
# ## PyTables Browsing the Object Tree
# https://www.pytables.org/usersguide/tutorials.html#browsing-the-object-tree

# %%
# Use file iterator

for node in h5file:
    print(node)

# %%
for group in h5file.walk_groups():
    print(group)

# %%
# From https://www.pytables.org/usersguide/tutorials.html#setting-and-getting-user-attributes

h5file.root

# %%
h5file.root.CONTROL

# %%
h5file.root.CONTROL.EXT_SOURCES.table

# %% [markdown]
# ## Always close an HDF5 file!
#
# It is important to close the HDF5 file, using `h5file.close()`). Otherwise it will be corrupted to other programs. See https://www.pytables.org/usersguide/tutorials.html#closing-the-file-and-looking-at-its-content

# %%
# Check if open (1 = True)
h5file.isopen

# %%
h5file.close()

# %%
h5file

# %% [markdown]
# ## PyTables `ptdump` command line utility
#
# The command line “ptdump” PyTables utility (located in utils/ directory)
# https://www.pytables.org/usersguide/tutorials.html#closing-the-file-and-looking-at-its-content

# %%
# get path, as pathlib only works within Python and not at the operating system command prompt.
file_to_open

# %%
# This uses the `!` ipython magic command to run from the console
# !ptdump '/Users/aaufdenkampe/Documents/Python/limno.HSPsquared/HSP2notebooks/Data/hsp2.h5'

# You can pass the -v or -d options to ptdump if you want more verbosity

# %% [markdown]
# # Open with h5py library
#
# Docs: https://docs.h5py.org
# Demo: https://nbviewer.jupyter.org/github/jackdbd/hdf5-pydata-munich/blob/master/hdf5_in_python.ipynb

# %%
# https://docs.h5py.org/en/stable/high/file.html#opening-creating-files

h5py_file = h5py.File(paths[0])

# NOTE: if the file was left open, you might get this error: `OSError: Unable to open file (File signature not found)`
# https://stackoverflow.com/questions/38089950/error-opening-file-in-h5py-file-signature-not-found/43607837

# %%
h5py_file?

# %%
h5py_file.attrs

# %%
h5py_file.keys()

# %%
for key in h5py_file.keys():
  print(key)

# %%
h5py_file['CONTROL'].keys()

# %%
h5py_file['CONTROL']['GLOBAL'].keys()

# %%
key_list = [k for k in h5py_file.keys()]
key_list

# %%
for name in h5py_file:
    for subname in h5py_file[name]:
        print(name+r'\ '+subname)
#         print(r'')
#         for subsubname in h5py_file[name][subname]:
#             print(name+r'\ '+subname+r'\ '+subsubname)

# %%
h5py_file.close()

# %%
h5py_file

# %% [markdown]
# ### h5py `h5dump` command line utility
#
# The command line “h5dump” utility can also be useful, but it is very verbose!
# https://nbviewer.jupyter.org/github/jackdbd/hdf5-pydata-munich/blob/master/hdf5_in_python.ipynb

# %%
# get path, as pathlib only works within Python and not at the operating system command prompt.
paths[0]

# %%
# !h5dump '/Users/aaufdenkampe/Documents/Python/limno.HSPsquared/HSP2notebooks/Data/hsp2.h5'

# WARNING: This is extremely verbose!!!!

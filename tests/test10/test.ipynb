# %% [markdown]
# # TEST10

# %%
from HSP2 import versions, main
from HSP2tools import readUCI, readWDM

versions()
# Out:
#                                                      version
# Python     3.8.2 | packaged by conda-forge | (default, Ma...
# HSP2                                                   1.0.0
# numpy                                                 1.18.1
# numba                                                 0.48.0
# pandas                                                 1.0.3
# os                                 Windows-10-10.0.18362-SP0
# processor  Intel64 Family 6 Model 94 Stepping 3, GenuineI...
# Date/Time                                2020-04-11 16:30:09

# %% [markdown]
# ## Build HDF5 file from UCI and WDM files, then run test10

# %%
readUCI('test10.uci', 'test10.h5')

# %%
readWDM('test10.wdm', 'test10.h5')
# Out:
#                      start                 stop Freq  length TSTYPE  TFILL  \
# TS039  1976-01-01 00:00:00  1977-01-01 00:00:00   1H    8784   PREC -999.0
# TS041  1976-01-01 00:00:00  1977-01-01 00:00:00   1D     366   EVAP -999.0
# TS042  1976-01-01 00:00:00  1977-01-01 00:00:00   1D     366   WIND -999.0
# TS046  1976-01-01 00:00:00  1977-01-01 00:00:00   2H    4392   SOLR -999.0
# TS113  1976-01-01 00:00:00  1977-01-01 00:00:00   1D     366   FLOW -999.0
# TS119  1976-01-01 00:00:00  1977-01-01 00:00:00   1D     366   FLOW -999.0
# TS121  1976-01-01 00:00:00  1977-01-01 00:00:00   2H    4392   ATMP -999.0
# TS122  1976-01-01 00:00:00  1977-01-01 00:00:00   2H    4392   ATMP -999.0
# TS123  1976-01-01 00:00:00  1977-01-01 00:00:00   2H    4392   ATMP -999.0
# TS124  1976-01-01 00:00:00  1977-01-01 00:00:00   1D     366   DEWP -999.0
# TS125  1976-01-01 00:00:00  1977-01-01 00:00:00   1D     366   DEWP -999.0
# ...

# %%
main('test10.h5')
# Out:
# 2020-04-11 16:30:32.40   Processing started for file test10.h5
# 2020-04-11 16:30:35.34   Simulation Start: 1976-01-01 00:00:00, Stop: 1977-01-01 00:00:00
# 2020-04-11 16:30:35.34      PERLND P001 DELT(minutes): 60
# 2020-04-11 16:30:35.41         SNOW
# 2020-04-11 16:30:35.62         PWATER
# 2020-04-11 16:30:35.83      RCHRES R001 DELT(minutes): 60
# 2020-04-11 16:30:35.90         HYDR
# 2020-04-11 16:30:36.07      RCHRES R002 DELT(minutes): 60
# 2020-04-11 16:30:36.13         HYDR
# 2020-04-11 16:30:36.24      RCHRES R003 DELT(minutes): 60
# 2020-04-11 16:30:36.31         HYDR
# 2020-04-11 16:30:36.40      RCHRES R004 DELT(minutes): 60
# 2020-04-11 16:30:36.46         HYDR
# 2020-04-11 16:30:36.57      IMPLND I001 DELT(minutes): 60
# 2020-04-11 16:30:36.64         SNOW
# 2020-04-11 16:30:36.84         IWATER
# 2020-04-11 16:30:36.92      RCHRES R005 DELT(minutes): 60
# 2020-04-11 16:30:36.98         HYDR
# 2020-04-11 16:30:37.10   Done; Run time is about 00:04.6 (mm:ss)
#
#
# ...

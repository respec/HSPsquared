# %% [markdown]
# HDF5 for HSP2 Input & Output Storage
# ===
#
# [HDF5](https://www.hdfgroup.org/solutions/hdf5/) (Hierarchical Data Format v5) was chosen as a primary data storage file format for HSP2 model inputs and outputs. It is a high-performance, open binary format that has a long [history](https://en.wikipedia.org/wiki/Hierarchical_Data_Format) of use by academia, federal agencies, and industry. For more information on its selection, read [Why HSP2?: The Solution](https://github.com/respec/HSPsquared/wiki/Why-HSP2%3F#the-solution---hsp2).
#
# HDF5 has many benefits, but can nevertheless present challenges to new users.
#
# **This notebook demonstrates different approaches for opening and interacting with HDF5 files within the Python environment for HSP2** (i.e. the conda environment created by `environment_hsp2_py38.yml`).
#
# The [HDFView](https://www.hdfgroup.org/downloads/hdfview/) desktop utility software provides a visual HDF5 file browser that can support exploration of HDF5 files. We recommend downloading and using it.

# %% [markdown]
# ## Import Dependencies
#
# HSP2 interacts with HDF5 files primarily via the [PyTables](https://www.pytables.org) library, which offers some high-level capabilities and is tightly integrated with Pandas.
#
# The [h5py](http://www.h5py.org) library offers a full Pythonic interface to the HDF5 format and technology suite.
#
# Note: The [jupyterlab-hdf5](https://github.com/jupyterlab/jupyterlab-hdf5) extension is very promising, but not yet compatible with jupyterlab>=3.
# https://github.com/jupyterlab/jupyterlab-hdf5/issues/42

# %%
import tables  # PyTables
import h5py

# %% [markdown]
# ## Set Paths to HDF5 Files with `pathlib`
#
# Use the [pathlib](https://docs.python.org/3/library/pathlib.html) library (built-in to Python 3) to manage paths indpendentely of OS or environment.
#
# This blog post describes `pathlib`'s benefits relative to using the `os` library or manual approaches.
# - https://medium.com/@ageitgey/python-3-quick-tip-the-easy-way-to-deal-with-file-paths-on-windows-mac-and-linux-11a072b58d5f

# %%
from pathlib import Path

# %%
# get home directory
Path.home()
# Out:
# PosixPath('/Users/aaufdenkampe')

# %%
# get current working directory
Path.cwd()
# Out:
# PosixPath('/Users/aaufdenkampe/Documents/Python/limno.HSPsquared/HSP2notebooks')

# %%
# use the Path module to construct file paths
project_folder = Path('Documents/Python/limno.HSPsquared/')
data_folder    = Path('Data/')

file_to_open = Path.cwd() / data_folder / "hsp2.h5"
file_to_open
# Out:
# PosixPath('/Users/aaufdenkampe/Documents/Python/limno.HSPsquared/HSP2notebooks/Data/hsp2.h5')

# %%
# list test files 
paths = [
    file_to_open,
    Path.home() / project_folder / 'tests/test10b/HSP2results/hsp2.h5',
    Path.home() / project_folder / 'tests/test10b/HSP2results/hspf.h5',
]
paths
# Out:
# [PosixPath('/Users/aaufdenkampe/Documents/Python/limno.HSPsquared/HSP2notebooks/Data/hsp2.h5'),
#  PosixPath('/Users/aaufdenkampe/Documents/Python/limno.HSPsquared/tests/test10b/HSP2results/hsp2.h5'),
#  PosixPath('/Users/aaufdenkampe/Documents/Python/limno.HSPsquared/tests/test10b/HSP2results/hspf.h5')]

# %%
# test if your path points to a valid file
file_to_open.exists()
# Out:
# True

# %%
paths[2].exists()
# Out:
# True

# %% [markdown]
# # Open an HSP2-created HDF5 file with PyTables
#
# Docs: https://www.pytables.org
# Demo: https://nbviewer.jupyter.org/github/jackdbd/hdf5-pydata-munich/blob/master/hdf5_in_python.ipynb
#
# Key points:
# - PyTables files have different parameters,attributes and methods than those created with H5py.
# - After processing data,
#   - "flushing a table (i.e. `table.flush()`) is a very important step as it will not only help to maintain the integrity of your file, but also will free valuable memory resources (i.e. internal buffers)". See https://www.pytables.org/usersguide/tutorials.html#creating-a-new-table
# - After opening a file,
#   - It is important to close it (i.e. `h5file.close()`), otherwise it will be corrupted to other programs. See https://www.pytables.org/usersguide/tutorials.html#closing-the-file-and-looking-at-its-content

# %%
# Open HSP2 HDF5 file with PyTables
h5file = tables.open_file(
   paths[0],
)

# %%
# Inspect HSP2 HDF5 object using iPython magic command

h5file?
# Out:
# Type:      File
# File:      ~/opt/anaconda3/envs/hsp2_py38_dev/lib/python3.8/site-packages/tables/file.py
# Docstring:
# The in-memory representation of a PyTables file.
#
# An instance of this class is returned when a PyTables file is
# opened with the :func:`tables.open_file` function. It offers methods
# to manipulate (create, rename, delete...) nodes and handle their
# attributes, as well as methods to traverse the object tree.
# The *user entry point* to the object tree attached to the HDF5 file
# is represented in the root_uep attribute.
# Other attributes are available.
#
# File objects support an *Undo/Redo mechanism* which can be enabled
# with the :meth:`File.enable_undo` method. Once the Undo/Redo
# mechanism is enabled, explicit *marks* (with an optional unique
# name) can be set on the state of the database using the
# :meth:`File.mark`
# method. There are two implicit marks which are always available:
# the initial mark (0) and the final mark (-1).  Both the identifier
# of a mark and its name can be used in *undo* and *redo* operations.
#
# Hierarchy manipulation operations (node creation, movement and
# removal) and attribute handling operations (setting and deleting)
# made after a mark can be undone by using the :meth:`File.undo`
# method, which returns the database to the state of a past mark.
# If undo() is not followed by operations that modify the hierarchy
# or attributes, the :meth:`File.redo` method can be used to return
# the database to the state of a future mark. Else, future states of
# the database are forgotten.
#
# Note that data handling operations can not be undone nor redone by
# now. Also, hierarchy manipulation operations on nodes that do not
# support the Undo/Redo mechanism issue an UndoRedoWarning *before*
# changing the database.
#
# The Undo/Redo mechanism is persistent between sessions and can
# only be disabled by calling the :meth:`File.disable_undo` method.
#
# File objects can also act as context managers when using the with
# statement introduced in Python 2.5.  When exiting a context, the
# file is automatically closed.
#
# Parameters
# ----------
# filename : str
#     The name of the file (supports environment variable expansion).
#     It is suggested that file names have any of the .h5, .hdf or
#     .hdf5 extensions, although this is not mandatory.
#
# mode : str
#     The mode to open the file. It can be one of the
#     following:
#
#         * *'r'*: Read-only; no data can be modified.
#         * *'w'*: Write; a new file is created (an existing file
#           with the same name would be deleted).
#         * *'a'*: Append; an existing file is opened for reading
#           and writing, and if the file does not exist it is created.
#         * *'r+'*: It is similar to 'a', but the file must already
#           exist.
#
# title : str
#     If the file is to be created, a TITLE string attribute will be
#     set on the root group with the given value. Otherwise, the
#     title will be read from disk, and this will not have any effect.
#
# root_uep : str
#     The root User Entry Point. This is a group in the HDF5 hierarchy
#     which will be taken as the starting point to create the object
#     tree. It can be whatever existing group in the file, named by
#     its HDF5 path. If it does not exist, an HDF5ExtError is issued.
#     Use this if you do not want to build the *entire* object tree,
#     but rather only a *subtree* of it.
#
#     .. versionchanged:: 3.0
#        The *rootUEP* parameter has been renamed into *root_uep*.
#
# filters : Filters
#     An instance of the Filters (see :ref:`FiltersClassDescr`) class that
#     provides information about the desired I/O filters applicable to the
#     leaves that hang directly from the *root group*, unless other filter
#     properties are specified for these leaves. Besides, if you do not
#     specify filter properties for child groups, they will inherit these
#     ones, which will in turn propagate to child nodes.
#
# Notes
# -----
# In addition, it recognizes the (lowercase) names of parameters
# present in :file:`tables/parameters.py` as additional keyword
# arguments.
# See :ref:`parameter_files` for a detailed info on the supported
# parameters.
#
#
# .. rubric:: File attributes
#
# .. attribute:: filename
#
#     The name of the opened file.
#
# .. attribute:: format_version
#
#     The PyTables version number of this file.
#
# .. attribute:: isopen
#
#     True if the underlying file is open, false otherwise.
#
# .. attribute:: mode
#
#     The mode in which the file was opened.
#
# .. attribute:: root
#
#     The *root* of the object tree hierarchy (a Group instance).
#
# .. attribute:: root_uep
#
#     The UEP (user entry point) group name in the file (see
#     the :func:`open_file` function).
#
#     .. versionchanged:: 3.0
#        The *rootUEP* attribute has been renamed into *root_uep*.

# %%
# For a PyTables file, a dump of the object tree can be easily displayed
h5file

# Warning: This is quite verbose!
# Out:
# File(filename=/Users/aaufdenkampe/Documents/Python/limno.HSPsquared/HSP2notebooks/Data/hsp2.h5, title='', mode='r', root_uep='/', filters=Filters(complevel=0, shuffle=False, bitshuffle=False, fletcher32=False, least_significant_digit=None))
# / (RootGroup) ''
# /CONTROL (Group) ''
# /FTABLES (Group) ''
# /IMPLND (Group) ''
# /PERLND (Group) ''
# /RCHRES (Group) ''
# /RESULTS (Group) ''
# /RUN_INFO (Group) ''
# /TIMESERIES (Group) ''
# /TIMESERIES/LAPSE_Table (Group) ''
# /TIMESERIES/LAPSE_Table/table (Table(24,)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "values": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /TIMESERIES/SEASONS_Table (Group) ''
# /TIMESERIES/SEASONS_Table/table (Table(12,)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values": BoolCol(shape=(), dflt=False, pos=1)}
#   byteorder := 'little'
#   chunkshape := (7281,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "values": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /TIMESERIES/SUMMARY (Group) ''
# /TIMESERIES/SUMMARY/table (Table(19,)) ''
#   description := {
#   "index": StringCol(itemsize=5, shape=(), dflt=b'', pos=0),
#   "Start": StringCol(itemsize=19, shape=(), dflt=b'', pos=1),
#   "Stop": StringCol(itemsize=19, shape=(), dflt=b'', pos=2),
#   "Freq": StringCol(itemsize=2, shape=(), dflt=b'', pos=3),
#   "Length": Int64Col(shape=(), dflt=0, pos=4),
#   "TSTYPE": StringCol(itemsize=4, shape=(), dflt=b'', pos=5),
#   "TFILL": Float64Col(shape=(), dflt=0.0, pos=6),
#   "STAID": StringCol(itemsize=15, shape=(), dflt=b'', pos=7),
#   "STNAM": StringCol(itemsize=48, shape=(), dflt=b'', pos=8)}
#   byteorder := 'little'
#   chunkshape := (512,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "Start": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "Stop": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "Freq": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "Length": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TSTYPE": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TFILL": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "STAID": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "STNAM": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /TIMESERIES/Saturated_Vapor_Pressure_Table (Group) ''
# /TIMESERIES/Saturated_Vapor_Pressure_Table/table (Table(40,)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "values": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /TIMESERIES/TS039 (Group) ''
# /TIMESERIES/TS039/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values": Float32Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (5461,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "values": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /TIMESERIES/TS041 (Group) ''
# /TIMESERIES/TS041/table (Table(366,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values": Float32Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (5461,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "values": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /TIMESERIES/TS042 (Group) ''
# /TIMESERIES/TS042/table (Table(366,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values": Float32Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (5461,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "values": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /TIMESERIES/TS046 (Group) ''
# /TIMESERIES/TS046/table (Table(4392,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values": Float32Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (5461,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "values": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /TIMESERIES/TS113 (Group) ''
# /TIMESERIES/TS113/table (Table(366,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values": Float32Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (5461,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "values": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /TIMESERIES/TS119 (Group) ''
# /TIMESERIES/TS119/table (Table(366,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values": Float32Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (5461,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "values": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /TIMESERIES/TS121 (Group) ''
# /TIMESERIES/TS121/table (Table(4392,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values": Float32Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (5461,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "values": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /TIMESERIES/TS122 (Group) ''
# /TIMESERIES/TS122/table (Table(4392,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values": Float32Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (5461,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "values": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /TIMESERIES/TS123 (Group) ''
# /TIMESERIES/TS123/table (Table(4392,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values": Float32Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (5461,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "values": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /TIMESERIES/TS124 (Group) ''
# /TIMESERIES/TS124/table (Table(366,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values": Float32Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (5461,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "values": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /TIMESERIES/TS125 (Group) ''
# /TIMESERIES/TS125/table (Table(366,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values": Float32Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (5461,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "values": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /TIMESERIES/TS126 (Group) ''
# /TIMESERIES/TS126/table (Table(366,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values": Float32Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (5461,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "values": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /TIMESERIES/TS127 (Group) ''
# /TIMESERIES/TS127/table (Table(366,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values": Float32Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (5461,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "values": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /TIMESERIES/TS131 (Group) ''
# /TIMESERIES/TS131/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values": Float32Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (5461,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "values": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /TIMESERIES/TS132 (Group) ''
# /TIMESERIES/TS132/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values": Float32Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (5461,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "values": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /TIMESERIES/TS134 (Group) ''
# /TIMESERIES/TS134/table (Table(366,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values": Float32Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (5461,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "values": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /TIMESERIES/TS135 (Group) ''
# /TIMESERIES/TS135/table (Table(366,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values": Float32Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (5461,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "values": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /TIMESERIES/TS136 (Group) ''
# /TIMESERIES/TS136/table (Table(366,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values": Float32Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (5461,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "values": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /TIMESERIES/TS140 (Group) ''
# /TIMESERIES/TS140/table (Table(366,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values": Float32Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (5461,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "values": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RUN_INFO/LOGFILE (Group) ''
# /RUN_INFO/LOGFILE/table (Table(49,)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "logfile": StringCol(itemsize=89, shape=(), dflt=b'', pos=1)}
#   byteorder := 'little'
#   chunkshape := (675,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "logfile": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RUN_INFO/VERSIONS (Group) ''
# /RUN_INFO/VERSIONS/table (Table(10,)) ''
#   description := {
#   "index": StringCol(itemsize=10, shape=(), dflt=b'', pos=0),
#   "version": StringCol(itemsize=55, shape=(), dflt=b'', pos=1)}
#   byteorder := 'irrelevant'
#   chunkshape := (1008,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "version": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/IMPLND_I001 (Group) ''
# /RESULTS/PERLND_P001 (Group) ''
# /RESULTS/RCHRES_R001 (Group) ''
# /RESULTS/RCHRES_R002 (Group) ''
# /RESULTS/RCHRES_R003 (Group) ''
# /RESULTS/RCHRES_R004 (Group) ''
# /RESULTS/RCHRES_R005 (Group) ''
# /RESULTS/RCHRES_R005/CONS (Group) ''
# /RESULTS/RCHRES_R005/CONS/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(6,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (2048,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/RCHRES_R005/GQUAL (Group) ''
# /RESULTS/RCHRES_R005/GQUAL/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(62,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (256,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/RCHRES_R005/HTRCH (Group) ''
# /RESULTS/RCHRES_R005/HTRCH/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(5,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (2340,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/RCHRES_R005/HYDR (Group) ''
# /RESULTS/RCHRES_R005/HYDR/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(10,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (1365,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/RCHRES_R005/SEDTRN (Group) ''
# /RESULTS/RCHRES_R005/SEDTRN/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(29,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (528,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/RCHRES_R004/CONS (Group) ''
# /RESULTS/RCHRES_R004/CONS/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(6,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (2048,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/RCHRES_R004/GQUAL (Group) ''
# /RESULTS/RCHRES_R004/GQUAL/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(62,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (256,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/RCHRES_R004/HTRCH (Group) ''
# /RESULTS/RCHRES_R004/HTRCH/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(5,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (2340,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/RCHRES_R004/HYDR (Group) ''
# /RESULTS/RCHRES_R004/HYDR/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(10,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (1365,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/RCHRES_R004/SEDTRN (Group) ''
# /RESULTS/RCHRES_R004/SEDTRN/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(29,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (528,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/RCHRES_R003/CONS (Group) ''
# /RESULTS/RCHRES_R003/CONS/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(6,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (2048,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/RCHRES_R003/GQUAL (Group) ''
# /RESULTS/RCHRES_R003/GQUAL/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(62,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (256,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/RCHRES_R003/HTRCH (Group) ''
# /RESULTS/RCHRES_R003/HTRCH/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(5,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (2340,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/RCHRES_R003/HYDR (Group) ''
# /RESULTS/RCHRES_R003/HYDR/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(10,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (1365,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/RCHRES_R003/SEDTRN (Group) ''
# /RESULTS/RCHRES_R003/SEDTRN/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(29,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (528,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/RCHRES_R002/CONS (Group) ''
# /RESULTS/RCHRES_R002/CONS/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(6,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (2048,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/RCHRES_R002/GQUAL (Group) ''
# /RESULTS/RCHRES_R002/GQUAL/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(62,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (256,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/RCHRES_R002/HTRCH (Group) ''
# /RESULTS/RCHRES_R002/HTRCH/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(5,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (2340,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/RCHRES_R002/HYDR (Group) ''
# /RESULTS/RCHRES_R002/HYDR/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(10,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (1365,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/RCHRES_R002/SEDTRN (Group) ''
# /RESULTS/RCHRES_R002/SEDTRN/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(29,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (528,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/RCHRES_R001/CONS (Group) ''
# /RESULTS/RCHRES_R001/CONS/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(8,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (1638,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/RCHRES_R001/GQUAL (Group) ''
# /RESULTS/RCHRES_R001/GQUAL/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(72,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (221,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/RCHRES_R001/HTRCH (Group) ''
# /RESULTS/RCHRES_R001/HTRCH/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(7,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (1820,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/RCHRES_R001/HYDR (Group) ''
# /RESULTS/RCHRES_R001/HYDR/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(14,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (1024,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/RCHRES_R001/SEDTRN (Group) ''
# /RESULTS/RCHRES_R001/SEDTRN/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(37,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (420,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/PERLND_P001/PSTEMP (Group) ''
# /RESULTS/PERLND_P001/PSTEMP/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(4,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (2730,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/PERLND_P001/PWATER (Group) ''
# /RESULTS/PERLND_P001/PWATER/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(36,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (431,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/PERLND_P001/PWTGAS (Group) ''
# /RESULTS/PERLND_P001/PWTGAS/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(21,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (712,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/PERLND_P001/SNOW (Group) ''
# /RESULTS/PERLND_P001/SNOW/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(22,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (682,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/IMPLND_I001/IQUAL (Group) ''
# /RESULTS/IMPLND_I001/IQUAL/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(10,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (1365,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/IMPLND_I001/IWATER (Group) ''
# /RESULTS/IMPLND_I001/IWATER/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(8,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (1638,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/IMPLND_I001/IWTGAS (Group) ''
# /RESULTS/IMPLND_I001/IWTGAS/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(6,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (2048,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/IMPLND_I001/SNOW (Group) ''
# /RESULTS/IMPLND_I001/SNOW/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(22,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (682,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RESULTS/IMPLND_I001/SOLIDS (Group) ''
# /RESULTS/IMPLND_I001/SOLIDS/table (Table(8784,), shuffle, blosc(9)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "values_block_0": Float32Col(shape=(2,), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (4096,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RCHRES/CONS (Group) ''
# /RCHRES/GENERAL (Group) ''
# /RCHRES/GQUAL (Group) ''
# /RCHRES/HTRCH (Group) ''
# /RCHRES/HYDR (Group) ''
# /RCHRES/NUTRX (Group) ''
# /RCHRES/OXRX (Group) ''
# /RCHRES/PHCARB (Group) ''
# /RCHRES/PLANK (Group) ''
# /RCHRES/RQUAL (Group) ''
# /RCHRES/SEDTRN (Group) ''
# /RCHRES/SEDTRN/CLAY (Group) ''
# /RCHRES/SEDTRN/CLAY/table (Table(5,)) ''
#   description := {
#   "index": StringCol(itemsize=4, shape=(), dflt=b'', pos=0),
#   "D": Float64Col(shape=(), dflt=0.0, pos=1),
#   "W": Float64Col(shape=(), dflt=0.0, pos=2),
#   "RHO": Float64Col(shape=(), dflt=0.0, pos=3),
#   "TAUCD": Float64Col(shape=(), dflt=0.0, pos=4),
#   "TAUCS": Float64Col(shape=(), dflt=0.0, pos=5),
#   "M": Float64Col(shape=(), dflt=0.0, pos=6)}
#   byteorder := 'little'
#   chunkshape := (1260,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "D": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "W": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "RHO": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TAUCD": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TAUCS": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "M": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RCHRES/SEDTRN/FLAGS (Group) ''
# /RCHRES/SEDTRN/FLAGS/table (Table(5,)) ''
#   description := {
#   "index": StringCol(itemsize=4, shape=(), dflt=b'', pos=0),
#   "SANDFG": Int64Col(shape=(), dflt=0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (5461,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SANDFG": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RCHRES/SEDTRN/PARAMETERS (Group) ''
# /RCHRES/SEDTRN/PARAMETERS/table (Table(5,)) ''
#   description := {
#   "index": StringCol(itemsize=4, shape=(), dflt=b'', pos=0),
#   "BEDWID": Float64Col(shape=(), dflt=0.0, pos=1),
#   "BEDWRN": Float64Col(shape=(), dflt=0.0, pos=2),
#   "POR": Float64Col(shape=(), dflt=0.0, pos=3),
#   "D": Float64Col(shape=(), dflt=0.0, pos=4),
#   "W": Float64Col(shape=(), dflt=0.0, pos=5),
#   "RHO": Float64Col(shape=(), dflt=0.0, pos=6),
#   "KSAND": Float64Col(shape=(), dflt=0.0, pos=7),
#   "EXPSND": Float64Col(shape=(), dflt=0.0, pos=8)}
#   byteorder := 'little'
#   chunkshape := (963,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "BEDWID": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "BEDWRN": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "POR": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "D": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "W": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "RHO": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "KSAND": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "EXPSND": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RCHRES/SEDTRN/SAVE (Group) ''
# /RCHRES/SEDTRN/SAVE/table (Table(5,)) ''
#   description := {
#   "index": StringCol(itemsize=4, shape=(), dflt=b'', pos=0),
#   "BEDDEP": Int64Col(shape=(), dflt=0, pos=1),
#   "DEPSCR1": Int64Col(shape=(), dflt=0, pos=2),
#   "DEPSCR2": Int64Col(shape=(), dflt=0, pos=3),
#   "DEPSCR3": Int64Col(shape=(), dflt=0, pos=4),
#   "DEPSCR4": Int64Col(shape=(), dflt=0, pos=5),
#   "ISED1": Int64Col(shape=(), dflt=0, pos=6),
#   "ISED2": Int64Col(shape=(), dflt=0, pos=7),
#   "ISED3": Int64Col(shape=(), dflt=0, pos=8),
#   "OSED1": Int64Col(shape=(), dflt=0, pos=9),
#   "OSED2": Int64Col(shape=(), dflt=0, pos=10),
#   "OSED3": Int64Col(shape=(), dflt=0, pos=11),
#   "OSED4": Int64Col(shape=(), dflt=0, pos=12),
#   "ROSED1": Int64Col(shape=(), dflt=0, pos=13),
#   "ROSED2": Int64Col(shape=(), dflt=0, pos=14),
#   "ROSED3": Int64Col(shape=(), dflt=0, pos=15),
#   "ROSED4": Int64Col(shape=(), dflt=0, pos=16),
#   "RSED1": Int64Col(shape=(), dflt=0, pos=17),
#   "RSED2": Int64Col(shape=(), dflt=0, pos=18),
#   "RSED3": Int64Col(shape=(), dflt=0, pos=19),
#   "RSED4": Int64Col(shape=(), dflt=0, pos=20),
#   "RSED5": Int64Col(shape=(), dflt=0, pos=21),
#   "RSED6": Int64Col(shape=(), dflt=0, pos=22),
#   "RSED7": Int64Col(shape=(), dflt=0, pos=23),
#   "RSED8": Int64Col(shape=(), dflt=0, pos=24),
#   "RSED9": Int64Col(shape=(), dflt=0, pos=25),
#   "RSED10": Int64Col(shape=(), dflt=0, pos=26),
#   "SSED1": Int64Col(shape=(), dflt=0, pos=27),
#   "SSED2": Int64Col(shape=(), dflt=0, pos=28),
#   "SSED3": Int64Col(shape=(), dflt=0, pos=29),
#   "SSED4": Int64Col(shape=(), dflt=0, pos=30),
#   "TSED1": Int64Col(shape=(), dflt=0, pos=31),
#   "TSED2": Int64Col(shape=(), dflt=0, pos=32),
#   "TSED3": Int64Col(shape=(), dflt=0, pos=33)}
#   byteorder := 'little'
#   chunkshape := (244,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "BEDDEP": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "DEPSCR1": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "DEPSCR2": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "DEPSCR3": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "DEPSCR4": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "ISED1": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "ISED2": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "ISED3": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "OSED1": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "OSED2": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "OSED3": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "OSED4": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "ROSED1": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "ROSED2": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "ROSED3": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "ROSED4": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "RSED1": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "RSED2": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "RSED3": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "RSED4": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "RSED5": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "RSED6": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "RSED7": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "RSED8": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "RSED9": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "RSED10": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SSED1": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SSED2": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SSED3": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SSED4": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TSED1": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TSED2": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TSED3": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RCHRES/SEDTRN/SILT (Group) ''
# /RCHRES/SEDTRN/SILT/table (Table(5,)) ''
#   description := {
#   "index": StringCol(itemsize=4, shape=(), dflt=b'', pos=0),
#   "D": Float64Col(shape=(), dflt=0.0, pos=1),
#   "W": Float64Col(shape=(), dflt=0.0, pos=2),
#   "RHO": Float64Col(shape=(), dflt=0.0, pos=3),
#   "TAUCD": Float64Col(shape=(), dflt=0.0, pos=4),
#   "TAUCS": Float64Col(shape=(), dflt=0.0, pos=5),
#   "M": Float64Col(shape=(), dflt=0.0, pos=6)}
#   byteorder := 'little'
#   chunkshape := (1260,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "D": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "W": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "RHO": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TAUCD": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TAUCS": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "M": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RCHRES/SEDTRN/STATES (Group) ''
# /RCHRES/SEDTRN/STATES/table (Table(5,)) ''
#   description := {
#   "index": StringCol(itemsize=4, shape=(), dflt=b'', pos=0),
#   "SSED1": Float64Col(shape=(), dflt=0.0, pos=1),
#   "SSED2": Float64Col(shape=(), dflt=0.0, pos=2),
#   "SSED3": Float64Col(shape=(), dflt=0.0, pos=3),
#   "BEDDEP": Float64Col(shape=(), dflt=0.0, pos=4),
#   "SANDFR": Float64Col(shape=(), dflt=0.0, pos=5),
#   "SILTFR": Float64Col(shape=(), dflt=0.0, pos=6),
#   "CLAYFR": Float64Col(shape=(), dflt=0.0, pos=7)}
#   byteorder := 'little'
#   chunkshape := (1092,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SSED1": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SSED2": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SSED3": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "BEDDEP": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SANDFR": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SILTFR": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "CLAYFR": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RCHRES/RQUAL/FLAGS (Group) ''
# /RCHRES/RQUAL/FLAGS/table (Table(5,)) ''
#   description := {
#   "index": StringCol(itemsize=4, shape=(), dflt=b'', pos=0),
#   "BENRFG": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (5461,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "BENRFG": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RCHRES/RQUAL/PARAMETERS (Group) ''
# /RCHRES/RQUAL/PARAMETERS/table (Table(5,)) ''
#   description := {
#   "index": StringCol(itemsize=4, shape=(), dflt=b'', pos=0),
#   "SCRVEL": Float64Col(shape=(), dflt=0.0, pos=1),
#   "SCRMUL": Float64Col(shape=(), dflt=0.0, pos=2)}
#   byteorder := 'little'
#   chunkshape := (3276,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SCRVEL": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SCRMUL": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RCHRES/PLANK/FLAGS (Group) ''
# /RCHRES/PLANK/FLAGS/table (Table(5,)) ''
#   description := {
#   "index": StringCol(itemsize=4, shape=(), dflt=b'', pos=0),
#   "PHYFG": Int64Col(shape=(), dflt=0, pos=1),
#   "ZOOFG": Int64Col(shape=(), dflt=0, pos=2),
#   "BALFG": Int64Col(shape=(), dflt=0, pos=3),
#   "SDLTFG": Int64Col(shape=(), dflt=0, pos=4),
#   "AMRFG": Int64Col(shape=(), dflt=0, pos=5),
#   "DECFG": Int64Col(shape=(), dflt=0, pos=6),
#   "NSFG": Int64Col(shape=(), dflt=0, pos=7),
#   "ZFOOD": Int64Col(shape=(), dflt=0, pos=8),
#   "BNPFG": Int64Col(shape=(), dflt=0, pos=9)}
#   byteorder := 'little'
#   chunkshape := (862,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PHYFG": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "ZOOFG": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "BALFG": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SDLTFG": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "AMRFG": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "DECFG": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "NSFG": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "ZFOOD": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "BNPFG": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RCHRES/PLANK/PARAMETERS (Group) ''
# /RCHRES/PLANK/PARAMETERS/table (Table(5,)) ''
#   description := {
#   "index": StringCol(itemsize=4, shape=(), dflt=b'', pos=0),
#   "RATCLP": Float64Col(shape=(), dflt=0.0, pos=1),
#   "NONREF": Float64Col(shape=(), dflt=0.0, pos=2),
#   "LITSED": Float64Col(shape=(), dflt=0.0, pos=3),
#   "ALNPR": Float64Col(shape=(), dflt=0.0, pos=4),
#   "EXTB": Float64Col(shape=(), dflt=0.0, pos=5),
#   "MALGR": Float64Col(shape=(), dflt=0.0, pos=6),
#   "PARADF": Float64Col(shape=(), dflt=0.0, pos=7),
#   "SEED": Float64Col(shape=(), dflt=0.0, pos=8),
#   "MXSTAY": Float64Col(shape=(), dflt=0.0, pos=9),
#   "O": Float64Col(shape=(), dflt=0.0, pos=10),
#   "CLALDH": Float64Col(shape=(), dflt=0.0, pos=11),
#   "PHYSET": Float64Col(shape=(), dflt=0.0, pos=12),
#   "REFSET": Float64Col(shape=(), dflt=0.0, pos=13),
#   "MZOEAT": Float64Col(shape=(), dflt=0.0, pos=14),
#   "ZFIL20": Float64Col(shape=(), dflt=0.0, pos=15),
#   "ZRES20": Float64Col(shape=(), dflt=0.0, pos=16),
#   "ZD": Float64Col(shape=(), dflt=0.0, pos=17),
#   "OXZD": Float64Col(shape=(), dflt=0.0, pos=18)}
#   byteorder := 'little'
#   chunkshape := (442,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "RATCLP": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "NONREF": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "LITSED": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "ALNPR": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "EXTB": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "MALGR": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PARADF": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SEED": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "MXSTAY": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "O": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "CLALDH": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PHYSET": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "REFSET": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "MZOEAT": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "ZFIL20": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "ZRES20": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "ZD": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "OXZD": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RCHRES/PLANK/SAVE (Group) ''
# /RCHRES/PLANK/SAVE/table (Table(5,)) ''
#   description := {
#   "index": StringCol(itemsize=4, shape=(), dflt=b'', pos=0),
#   "PHYTO": Int64Col(shape=(), dflt=0, pos=1),
#   "ZOO": Int64Col(shape=(), dflt=0, pos=2),
#   "BENAL": Int64Col(shape=(), dflt=0, pos=3),
#   "TBENAL": Int64Col(shape=(), dflt=0, pos=4),
#   "PHYCLA": Int64Col(shape=(), dflt=0, pos=5),
#   "BALCLA": Int64Col(shape=(), dflt=0, pos=6),
#   "PKST3": Int64Col(shape=(), dflt=0, pos=7),
#   "PKST4": Int64Col(shape=(), dflt=0, pos=8),
#   "PKIF": Int64Col(shape=(), dflt=0, pos=9),
#   "TPKIF": Int64Col(shape=(), dflt=0, pos=10),
#   "PKCF1": Int64Col(shape=(), dflt=0, pos=11),
#   "TPKCF1": Int64Col(shape=(), dflt=0, pos=12),
#   "PKCF2": Int64Col(shape=(), dflt=0, pos=13),
#   "TPKCF2": Int64Col(shape=(), dflt=0, pos=14),
#   "PLADDR": Int64Col(shape=(), dflt=0, pos=15),
#   "PLADWT": Int64Col(shape=(), dflt=0, pos=16),
#   "PLADEP": Int64Col(shape=(), dflt=0, pos=17),
#   "PKCF5": Int64Col(shape=(), dflt=0, pos=18),
#   "PKCF6": Int64Col(shape=(), dflt=0, pos=19),
#   "PKCF7": Int64Col(shape=(), dflt=0, pos=20),
#   "TPKCF7": Int64Col(shape=(), dflt=0, pos=21),
#   "PKCF8": Int64Col(shape=(), dflt=0, pos=22),
#   "PKCF9": Int64Col(shape=(), dflt=0, pos=23),
#   "PKCF10": Int64Col(shape=(), dflt=0, pos=24)}
#   byteorder := 'little'
#   chunkshape := (334,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PHYTO": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "ZOO": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "BENAL": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TBENAL": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PHYCLA": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "BALCLA": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PKST3": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PKST4": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PKIF": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TPKIF": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PKCF1": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TPKCF1": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PKCF2": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TPKCF2": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PLADDR": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PLADWT": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PLADEP": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PKCF5": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PKCF6": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PKCF7": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TPKCF7": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PKCF8": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PKCF9": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PKCF10": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RCHRES/PLANK/STATES (Group) ''
# /RCHRES/PLANK/STATES/table (Table(5,)) ''
#   description := {
#   "index": StringCol(itemsize=4, shape=(), dflt=b'', pos=0),
#   "PHYTO": Float64Col(shape=(), dflt=0.0, pos=1),
#   "ZOO": Float64Col(shape=(), dflt=0.0, pos=2),
#   "BENAL": Float64Col(shape=(), dflt=0.0, pos=3),
#   "ORN": Float64Col(shape=(), dflt=0.0, pos=4),
#   "ORP": Float64Col(shape=(), dflt=0.0, pos=5),
#   "ORC": Float64Col(shape=(), dflt=0.0, pos=6)}
#   byteorder := 'little'
#   chunkshape := (1260,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PHYTO": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "ZOO": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "BENAL": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "ORN": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "ORP": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "ORC": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RCHRES/PHCARB/PARAMETERS (Group) ''
# /RCHRES/PHCARB/PARAMETERS/table (Table(5,)) ''
#   description := {
#   "index": StringCol(itemsize=4, shape=(), dflt=b'', pos=0),
#   "PHCNT": Int64Col(shape=(), dflt=0, pos=1),
#   "ALKCON": Int64Col(shape=(), dflt=0, pos=2)}
#   byteorder := 'little'
#   chunkshape := (3276,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PHCNT": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "ALKCON": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RCHRES/PHCARB/SAVE (Group) ''
# /RCHRES/PHCARB/SAVE/table (Table(5,)) ''
#   description := {
#   "index": StringCol(itemsize=4, shape=(), dflt=b'', pos=0),
#   "PHCF1": Int64Col(shape=(), dflt=0, pos=1),
#   "PHCF2": Int64Col(shape=(), dflt=0, pos=2),
#   "PHCF3": Int64Col(shape=(), dflt=0, pos=3),
#   "PHIF": Int64Col(shape=(), dflt=0, pos=4),
#   "PHST": Int64Col(shape=(), dflt=0, pos=5),
#   "SATCO2": Int64Col(shape=(), dflt=0, pos=6)}
#   byteorder := 'little'
#   chunkshape := (1260,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PHCF1": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PHCF2": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PHCF3": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PHIF": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PHST": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SATCO2": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RCHRES/PHCARB/STATES (Group) ''
# /RCHRES/PHCARB/STATES/table (Table(5,)) ''
#   description := {
#   "index": StringCol(itemsize=4, shape=(), dflt=b'', pos=0),
#   "TIC": Float64Col(shape=(), dflt=0.0, pos=1),
#   "CO2": Float64Col(shape=(), dflt=0.0, pos=2),
#   "PH": Float64Col(shape=(), dflt=0.0, pos=3)}
#   byteorder := 'little'
#   chunkshape := (2340,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TIC": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "CO2": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PH": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RCHRES/OXRX/FLAGS (Group) ''
# /RCHRES/OXRX/FLAGS/table (Table(5,)) ''
#   description := {
#   "index": StringCol(itemsize=4, shape=(), dflt=b'', pos=0),
#   "REAMFG": Float64Col(shape=(), dflt=0.0, pos=1)}
#   byteorder := 'little'
#   chunkshape := (5461,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "REAMFG": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RCHRES/OXRX/PARAMETERS (Group) ''
# /RCHRES/OXRX/PARAMETERS/table (Table(5,)) ''
#   description := {
#   "index": StringCol(itemsize=4, shape=(), dflt=b'', pos=0),
#   "KBOD20": Float64Col(shape=(), dflt=0.0, pos=1),
#   "TCBOD": Float64Col(shape=(), dflt=0.0, pos=2),
#   "KODSET": Float64Col(shape=(), dflt=0.0, pos=3),
#   "SUPSAT": Float64Col(shape=(), dflt=0.0, pos=4),
#   "BENOD": Float64Col(shape=(), dflt=0.0, pos=5),
#   "TCBEN": Float64Col(shape=(), dflt=0.0, pos=6),
#   "EXPOD": Float64Col(shape=(), dflt=0.0, pos=7),
#   "BRBOD1": Float64Col(shape=(), dflt=0.0, pos=8),
#   "BRBOD2": Float64Col(shape=(), dflt=0.0, pos=9),
#   "EXPREL": Float64Col(shape=(), dflt=0.0, pos=10),
#   "CFOREA": Float64Col(shape=(), dflt=0.0, pos=11),
#   "TCGINV": Float64Col(shape=(), dflt=0.0, pos=12),
#   "REAK": Float64Col(shape=(), dflt=0.0, pos=13),
#   "EXPRED": Float64Col(shape=(), dflt=0.0, pos=14),
#   "EXPREV": Float64Col(shape=(), dflt=0.0, pos=15)}
#   byteorder := 'little'
#   chunkshape := (528,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "KBOD20": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TCBOD": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "KODSET": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SUPSAT": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "BENOD": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TCBEN": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "EXPOD": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "BRBOD1": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "BRBOD2": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "EXPREL": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "CFOREA": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TCGINV": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "REAK": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "EXPRED": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "EXPREV": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RCHRES/OXRX/SAVE (Group) ''
# /RCHRES/OXRX/SAVE/table (Table(5,)) ''
#   description := {
#   "index": StringCol(itemsize=4, shape=(), dflt=b'', pos=0),
#   "BOD": Int64Col(shape=(), dflt=0, pos=1),
#   "DOX": Int64Col(shape=(), dflt=0, pos=2),
#   "OXCF1": Int64Col(shape=(), dflt=0, pos=3),
#   "OXCF2": Int64Col(shape=(), dflt=0, pos=4),
#   "OXCF3": Int64Col(shape=(), dflt=0, pos=5),
#   "OXCF4": Int64Col(shape=(), dflt=0, pos=6),
#   "OXIF": Int64Col(shape=(), dflt=0, pos=7),
#   "SATDO": Int64Col(shape=(), dflt=0, pos=8)}
#   byteorder := 'little'
#   chunkshape := (963,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "BOD": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "DOX": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "OXCF1": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "OXCF2": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "OXCF3": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "OXCF4": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "OXIF": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SATDO": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /RCHRES/OXRX/STATES (Group) ''
# /RCHRES/OXRX/STATES/table (Table(5,)) ''
#   description := {
#   "index": StringCol(itemsize=4, shape=(), dflt=b'', pos=0),
#   "DOX": Float64Col(shape=(), dflt=0.0, pos=1),
# ...
#   "SOQC": Int64Col(shape=(), dflt=0, pos=7),
#   "IQADDR": Int64Col(shape=(), dflt=0, pos=8),
#   "IQADWT": Int64Col(shape=(), dflt=0, pos=9),
#   "IQADEP": Int64Col(shape=(), dflt=0, pos=10)}
#   byteorder := 'little'
#   chunkshape := (780,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SQO": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SOQSP": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SOQS": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SOQO": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SOQOC": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SOQUAL": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SOQC": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "IQADDR": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "IQADWT": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "IQADEP": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /IMPLND/IQUAL/IQUAL1/FLAGS (Group) ''
# /IMPLND/IQUAL/IQUAL1/FLAGS/table (Table(1,)) ''
#   description := {
#   "index": StringCol(itemsize=4, shape=(), dflt=b'', pos=0),
#   "QUALID": StringCol(itemsize=3, shape=(), dflt=b'', pos=1),
#   "QTYID": StringCol(itemsize=2, shape=(), dflt=b'', pos=2),
#   "QSDFG": Int64Col(shape=(), dflt=0, pos=3),
#   "VPFWFG": Int64Col(shape=(), dflt=0, pos=4),
#   "QSOFG": Int64Col(shape=(), dflt=0, pos=5),
#   "VQOFG": Int64Col(shape=(), dflt=0, pos=6)}
#   byteorder := 'little'
#   chunkshape := (1598,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "QUALID": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "QTYID": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "QSDFG": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "VPFWFG": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "QSOFG": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "VQOFG": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /IMPLND/IQUAL/IQUAL1/PARAMETERS (Group) ''
# /IMPLND/IQUAL/IQUAL1/PARAMETERS/table (Table(1,)) ''
#   description := {
#   "index": StringCol(itemsize=4, shape=(), dflt=b'', pos=0),
#   "SQO": Float64Col(shape=(), dflt=0.0, pos=1),
#   "POTFW": Float64Col(shape=(), dflt=0.0, pos=2),
#   "ACQOP": Float64Col(shape=(), dflt=0.0, pos=3),
#   "SQOLIM": Float64Col(shape=(), dflt=0.0, pos=4),
#   "WSQOP": Float64Col(shape=(), dflt=0.0, pos=5)}
#   byteorder := 'little'
#   chunkshape := (1489,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SQO": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "POTFW": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "ACQOP": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SQOLIM": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "WSQOP": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /IMPLND/GENERAL/ACTIVITY (Group) ''
# /IMPLND/GENERAL/ACTIVITY/table (Table(1,)) ''
#   description := {
#   "index": StringCol(itemsize=4, shape=(), dflt=b'', pos=0),
#   "ATEMP": Int64Col(shape=(), dflt=0, pos=1),
#   "SNOW": Int64Col(shape=(), dflt=0, pos=2),
#   "IWATER": Int64Col(shape=(), dflt=0, pos=3),
#   "SOLIDS": Int64Col(shape=(), dflt=0, pos=4),
#   "IWTGAS": Int64Col(shape=(), dflt=0, pos=5),
#   "IQUAL": Int64Col(shape=(), dflt=0, pos=6)}
#   byteorder := 'little'
#   chunkshape := (1260,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "ATEMP": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SNOW": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "IWATER": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SOLIDS": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "IWTGAS": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "IQUAL": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /IMPLND/GENERAL/INFO (Group) ''
# /IMPLND/GENERAL/INFO/table (Table(1,)) ''
#   description := {
#   "index": StringCol(itemsize=4, shape=(), dflt=b'', pos=0),
#   "LSID": StringCol(itemsize=17, shape=(), dflt=b'', pos=1),
#   "IUNITS": Int64Col(shape=(), dflt=0, pos=2),
#   "OUNITS": Int64Col(shape=(), dflt=0, pos=3),
#   "PUNIT1": Int64Col(shape=(), dflt=0, pos=4),
#   "PUNIT2": Int64Col(shape=(), dflt=0, pos=5),
#   "BUNIT1": Int64Col(shape=(), dflt=0, pos=6),
#   "BUNIT2": Int64Col(shape=(), dflt=0, pos=7)}
#   byteorder := 'little'
#   chunkshape := (949,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "LSID": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "IUNITS": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "OUNITS": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PUNIT1": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "PUNIT2": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "BUNIT1": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "BUNIT2": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /FTABLES/FT001 (Group) ''
# /FTABLES/FT001/table (Table(14,)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "Depth": Float64Col(shape=(), dflt=0.0, pos=1),
#   "Area": Float64Col(shape=(), dflt=0.0, pos=2),
#   "Volume": Float64Col(shape=(), dflt=0.0, pos=3),
#   "Disch1": Float64Col(shape=(), dflt=0.0, pos=4),
#   "Disch2": Float64Col(shape=(), dflt=0.0, pos=5),
#   "Disch3": Float64Col(shape=(), dflt=0.0, pos=6)}
#   byteorder := 'little'
#   chunkshape := (1170,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "Depth": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "Area": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "Volume": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "Disch1": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "Disch2": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "Disch3": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /FTABLES/FT002 (Group) ''
# /FTABLES/FT002/table (Table(13,)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "Depth": Float64Col(shape=(), dflt=0.0, pos=1),
#   "Area": Float64Col(shape=(), dflt=0.0, pos=2),
#   "Volume": Float64Col(shape=(), dflt=0.0, pos=3),
#   "Disch1": Float64Col(shape=(), dflt=0.0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (1638,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "Depth": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "Area": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "Volume": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "Disch1": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /FTABLES/FT003 (Group) ''
# /FTABLES/FT003/table (Table(13,)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "Depth": Float64Col(shape=(), dflt=0.0, pos=1),
#   "Area": Float64Col(shape=(), dflt=0.0, pos=2),
#   "Volume": Float64Col(shape=(), dflt=0.0, pos=3),
#   "Disch1": Float64Col(shape=(), dflt=0.0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (1638,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "Depth": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "Area": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "Volume": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "Disch1": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /FTABLES/FT004 (Group) ''
# /FTABLES/FT004/table (Table(13,)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "Depth": Float64Col(shape=(), dflt=0.0, pos=1),
#   "Area": Float64Col(shape=(), dflt=0.0, pos=2),
#   "Volume": Float64Col(shape=(), dflt=0.0, pos=3),
#   "Disch1": Float64Col(shape=(), dflt=0.0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (1638,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "Depth": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "Area": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "Volume": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "Disch1": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /FTABLES/FT005 (Group) ''
# /FTABLES/FT005/table (Table(13,)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "Depth": Float64Col(shape=(), dflt=0.0, pos=1),
#   "Area": Float64Col(shape=(), dflt=0.0, pos=2),
#   "Volume": Float64Col(shape=(), dflt=0.0, pos=3),
#   "Disch1": Float64Col(shape=(), dflt=0.0, pos=4)}
#   byteorder := 'little'
#   chunkshape := (1638,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "Depth": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "Area": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "Volume": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "Disch1": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /CONTROL/EXT_SOURCES (Group) ''
# /CONTROL/EXT_SOURCES/table (Table(50,)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "SVOL": StringCol(itemsize=1, shape=(), dflt=b'', pos=1),
#   "SVOLNO": StringCol(itemsize=5, shape=(), dflt=b'', pos=2),
#   "SMEMN": StringCol(itemsize=4, shape=(), dflt=b'', pos=3),
#   "SMEMSB": StringCol(itemsize=2, shape=(), dflt=b'', pos=4),
#   "SSYST": StringCol(itemsize=4, shape=(), dflt=b'', pos=5),
#   "SGAPST": StringCol(itemsize=4, shape=(), dflt=b'', pos=6),
#   "MFACTOR": Float64Col(shape=(), dflt=0.0, pos=7),
#   "TRAN": StringCol(itemsize=4, shape=(), dflt=b'', pos=8),
#   "TVOL": StringCol(itemsize=6, shape=(), dflt=b'', pos=9),
#   "TGRPN": StringCol(itemsize=5, shape=(), dflt=b'', pos=10),
#   "TMEMN": StringCol(itemsize=6, shape=(), dflt=b'', pos=11),
#   "TMEMSB": StringCol(itemsize=1, shape=(), dflt=b'', pos=12),
#   "TVOLNO": StringCol(itemsize=4, shape=(), dflt=b'', pos=13),
#   "COMMENT": StringCol(itemsize=1, shape=(), dflt=b'', pos=14)}
#   byteorder := 'little'
#   chunkshape := (1040,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SVOL": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SVOLNO": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SMEMN": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SMEMSB": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SSYST": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SGAPST": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "MFACTOR": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TRAN": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TVOL": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TGRPN": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TMEMN": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TMEMSB": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TVOLNO": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "COMMENT": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /CONTROL/GLOBAL (Group) ''
# /CONTROL/GLOBAL/table (Table(3,)) ''
#   description := {
#   "index": StringCol(itemsize=7, shape=(), dflt=b'', pos=0),
#   "Info": StringCol(itemsize=74, shape=(), dflt=b'', pos=1)}
#   byteorder := 'irrelevant'
#   chunkshape := (809,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "Info": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /CONTROL/LINKS (Group) ''
# /CONTROL/LINKS/table (Table(7,)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "AFACTR": Float64Col(shape=(), dflt=0.0, pos=1),
#   "MLNO": StringCol(itemsize=5, shape=(), dflt=b'', pos=2),
#   "SVOL": StringCol(itemsize=6, shape=(), dflt=b'', pos=3),
#   "SVOLNO": StringCol(itemsize=4, shape=(), dflt=b'', pos=4),
#   "TMEMSB1": StringCol(itemsize=1, shape=(), dflt=b'', pos=5),
#   "TMEMSB2": StringCol(itemsize=1, shape=(), dflt=b'', pos=6),
#   "TVOL": StringCol(itemsize=6, shape=(), dflt=b'', pos=7),
#   "TVOLNO": StringCol(itemsize=4, shape=(), dflt=b'', pos=8),
#   "MFACTOR": StringCol(itemsize=1, shape=(), dflt=b'', pos=9),
#   "SGRPN": StringCol(itemsize=1, shape=(), dflt=b'', pos=10),
#   "SMEMN": StringCol(itemsize=1, shape=(), dflt=b'', pos=11),
#   "SMEMSB": StringCol(itemsize=1, shape=(), dflt=b'', pos=12),
#   "TGRPN": StringCol(itemsize=1, shape=(), dflt=b'', pos=13),
#   "TMEMN": StringCol(itemsize=1, shape=(), dflt=b'', pos=14),
#   "TMEMSB": StringCol(itemsize=1, shape=(), dflt=b'', pos=15),
#   "TRAN": StringCol(itemsize=1, shape=(), dflt=b'', pos=16),
#   "COMMENTS": StringCol(itemsize=1, shape=(), dflt=b'', pos=17)}
#   byteorder := 'little'
#   chunkshape := (1260,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "AFACTR": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "MLNO": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SVOL": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SVOLNO": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TMEMSB1": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TMEMSB2": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TVOL": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TVOLNO": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "MFACTOR": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SGRPN": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SMEMN": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SMEMSB": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TGRPN": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TMEMN": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TMEMSB": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TRAN": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "COMMENTS": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /CONTROL/MASS_LINKS (Group) ''
# /CONTROL/MASS_LINKS/table (Table(15,)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "SVOL": StringCol(itemsize=6, shape=(), dflt=b'', pos=1),
#   "SGRPN": StringCol(itemsize=6, shape=(), dflt=b'', pos=2),
#   "SMEMN": StringCol(itemsize=6, shape=(), dflt=b'', pos=3),
#   "SMEMSB1": StringCol(itemsize=1, shape=(), dflt=b'', pos=4),
#   "SMEMSB2": StringCol(itemsize=1, shape=(), dflt=b'', pos=5),
#   "MFACTOR": Float64Col(shape=(), dflt=0.0, pos=6),
#   "TVOL": StringCol(itemsize=6, shape=(), dflt=b'', pos=7),
#   "TMEMN": StringCol(itemsize=5, shape=(), dflt=b'', pos=8),
#   "TMEMSB1": StringCol(itemsize=1, shape=(), dflt=b'', pos=9),
#   "TMEMSB2": StringCol(itemsize=1, shape=(), dflt=b'', pos=10),
#   "MLNO": StringCol(itemsize=5, shape=(), dflt=b'', pos=11),
#   "COMMENTS": StringCol(itemsize=1, shape=(), dflt=b'', pos=12)}
#   byteorder := 'little'
#   chunkshape := (1191,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SVOL": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SGRPN": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SMEMN": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SMEMSB1": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SMEMSB2": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "MFACTOR": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TVOL": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TMEMN": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TMEMSB1": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TMEMSB2": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "MLNO": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "COMMENTS": Index(6, medium, shuffle, zlib(1)).is_csi=False}
# /CONTROL/OP_SEQUENCE (Group) ''
# /CONTROL/OP_SEQUENCE/table (Table(7,)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "OPERATION": StringCol(itemsize=6, shape=(), dflt=b'', pos=1),
#   "SEGMENT": StringCol(itemsize=4, shape=(), dflt=b'', pos=2),
#   "INDELT_minutes": Int64Col(shape=(), dflt=0, pos=3)}
#   byteorder := 'little'
#   chunkshape := (2520,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "OPERATION": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SEGMENT": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "INDELT_minutes": Index(6, medium, shuffle, zlib(1)).is_csi=False}

# %% [markdown]
# ## PyTables Browsing the Object Tree
# https://www.pytables.org/usersguide/tutorials.html#browsing-the-object-tree

# %%
# Use file iterator

for node in h5file:
    print(node)
# Out:
# / (RootGroup) ''
# /CONTROL (Group) ''
# /FTABLES (Group) ''
# /IMPLND (Group) ''
# /PERLND (Group) ''
# /RCHRES (Group) ''
# /RESULTS (Group) ''
# /RUN_INFO (Group) ''
# /TIMESERIES (Group) ''
# /CONTROL/EXT_SOURCES (Group) ''
# /CONTROL/GLOBAL (Group) ''
# /CONTROL/LINKS (Group) ''
# /CONTROL/MASS_LINKS (Group) ''
# /CONTROL/OP_SEQUENCE (Group) ''
# /FTABLES/FT001 (Group) ''
# /FTABLES/FT002 (Group) ''
# /FTABLES/FT003 (Group) ''
# /FTABLES/FT004 (Group) ''
# /FTABLES/FT005 (Group) ''
# /IMPLND/GENERAL (Group) ''
# /IMPLND/IQUAL (Group) ''
# /IMPLND/IWATER (Group) ''
# /IMPLND/IWTGAS (Group) ''
# /IMPLND/SNOW (Group) ''
# /IMPLND/SOLIDS (Group) ''
# /PERLND/GENERAL (Group) ''
# /PERLND/PSTEMP (Group) ''
# /PERLND/PWATER (Group) ''
# /PERLND/PWTGAS (Group) ''
# /PERLND/SNOW (Group) ''
# /RCHRES/CONS (Group) ''
# /RCHRES/GENERAL (Group) ''
# /RCHRES/GQUAL (Group) ''
# /RCHRES/HTRCH (Group) ''
# /RCHRES/HYDR (Group) ''
# /RCHRES/NUTRX (Group) ''
# /RCHRES/OXRX (Group) ''
# /RCHRES/PHCARB (Group) ''
# /RCHRES/PLANK (Group) ''
# /RCHRES/RQUAL (Group) ''
# /RCHRES/SEDTRN (Group) ''
# /RESULTS/IMPLND_I001 (Group) ''
# /RESULTS/PERLND_P001 (Group) ''
# /RESULTS/RCHRES_R001 (Group) ''
# /RESULTS/RCHRES_R002 (Group) ''
# /RESULTS/RCHRES_R003 (Group) ''
# /RESULTS/RCHRES_R004 (Group) ''
# /RESULTS/RCHRES_R005 (Group) ''
# /RUN_INFO/LOGFILE (Group) ''
# /RUN_INFO/VERSIONS (Group) ''
# /TIMESERIES/LAPSE_Table (Group) ''
# /TIMESERIES/SEASONS_Table (Group) ''
# /TIMESERIES/SUMMARY (Group) ''
# /TIMESERIES/Saturated_Vapor_Pressure_Table (Group) ''
# /TIMESERIES/TS039 (Group) ''
# /TIMESERIES/TS041 (Group) ''
# /TIMESERIES/TS042 (Group) ''
# /TIMESERIES/TS046 (Group) ''
# /TIMESERIES/TS113 (Group) ''
# /TIMESERIES/TS119 (Group) ''
# /TIMESERIES/TS121 (Group) ''
# /TIMESERIES/TS122 (Group) ''
# /TIMESERIES/TS123 (Group) ''
# /TIMESERIES/TS124 (Group) ''
# /TIMESERIES/TS125 (Group) ''
# /TIMESERIES/TS126 (Group) ''
# /TIMESERIES/TS127 (Group) ''
# /TIMESERIES/TS131 (Group) ''
# /TIMESERIES/TS132 (Group) ''
# /TIMESERIES/TS134 (Group) ''
# /TIMESERIES/TS135 (Group) ''
# /TIMESERIES/TS136 (Group) ''
# /TIMESERIES/TS140 (Group) ''
# /TIMESERIES/LAPSE_Table/table (Table(24,)) ''
# /TIMESERIES/SEASONS_Table/table (Table(12,)) ''
# /TIMESERIES/SUMMARY/table (Table(19,)) ''
# /TIMESERIES/Saturated_Vapor_Pressure_Table/table (Table(40,)) ''
# /TIMESERIES/TS039/table (Table(8784,), shuffle, blosc(9)) ''
# /TIMESERIES/TS041/table (Table(366,), shuffle, blosc(9)) ''
# /TIMESERIES/TS042/table (Table(366,), shuffle, blosc(9)) ''
# /TIMESERIES/TS046/table (Table(4392,), shuffle, blosc(9)) ''
# /TIMESERIES/TS113/table (Table(366,), shuffle, blosc(9)) ''
# /TIMESERIES/TS119/table (Table(366,), shuffle, blosc(9)) ''
# /TIMESERIES/TS121/table (Table(4392,), shuffle, blosc(9)) ''
# /TIMESERIES/TS122/table (Table(4392,), shuffle, blosc(9)) ''
# /TIMESERIES/TS123/table (Table(4392,), shuffle, blosc(9)) ''
# /TIMESERIES/TS124/table (Table(366,), shuffle, blosc(9)) ''
# /TIMESERIES/TS125/table (Table(366,), shuffle, blosc(9)) ''
# /TIMESERIES/TS126/table (Table(366,), shuffle, blosc(9)) ''
# /TIMESERIES/TS127/table (Table(366,), shuffle, blosc(9)) ''
# /TIMESERIES/TS131/table (Table(8784,), shuffle, blosc(9)) ''
# /TIMESERIES/TS132/table (Table(8784,), shuffle, blosc(9)) ''
# /TIMESERIES/TS134/table (Table(366,), shuffle, blosc(9)) ''
# /TIMESERIES/TS135/table (Table(366,), shuffle, blosc(9)) ''
# /TIMESERIES/TS136/table (Table(366,), shuffle, blosc(9)) ''
# /TIMESERIES/TS140/table (Table(366,), shuffle, blosc(9)) ''
# /RUN_INFO/LOGFILE/table (Table(49,)) ''
# /RUN_INFO/VERSIONS/table (Table(10,)) ''
# /RESULTS/IMPLND_I001/IQUAL (Group) ''
# /RESULTS/IMPLND_I001/IWATER (Group) ''
# /RESULTS/IMPLND_I001/IWTGAS (Group) ''
# /RESULTS/IMPLND_I001/SNOW (Group) ''
# /RESULTS/IMPLND_I001/SOLIDS (Group) ''
# /RESULTS/PERLND_P001/PSTEMP (Group) ''
# /RESULTS/PERLND_P001/PWATER (Group) ''
# /RESULTS/PERLND_P001/PWTGAS (Group) ''
# /RESULTS/PERLND_P001/SNOW (Group) ''
# /RESULTS/RCHRES_R001/CONS (Group) ''
# /RESULTS/RCHRES_R001/GQUAL (Group) ''
# /RESULTS/RCHRES_R001/HTRCH (Group) ''
# /RESULTS/RCHRES_R001/HYDR (Group) ''
# /RESULTS/RCHRES_R001/SEDTRN (Group) ''
# /RESULTS/RCHRES_R002/CONS (Group) ''
# /RESULTS/RCHRES_R002/GQUAL (Group) ''
# /RESULTS/RCHRES_R002/HTRCH (Group) ''
# /RESULTS/RCHRES_R002/HYDR (Group) ''
# /RESULTS/RCHRES_R002/SEDTRN (Group) ''
# /RESULTS/RCHRES_R003/CONS (Group) ''
# /RESULTS/RCHRES_R003/GQUAL (Group) ''
# /RESULTS/RCHRES_R003/HTRCH (Group) ''
# /RESULTS/RCHRES_R003/HYDR (Group) ''
# /RESULTS/RCHRES_R003/SEDTRN (Group) ''
# /RESULTS/RCHRES_R004/CONS (Group) ''
# /RESULTS/RCHRES_R004/GQUAL (Group) ''
# /RESULTS/RCHRES_R004/HTRCH (Group) ''
# /RESULTS/RCHRES_R004/HYDR (Group) ''
# /RESULTS/RCHRES_R004/SEDTRN (Group) ''
# /RESULTS/RCHRES_R005/CONS (Group) ''
# /RESULTS/RCHRES_R005/GQUAL (Group) ''
# /RESULTS/RCHRES_R005/HTRCH (Group) ''
# /RESULTS/RCHRES_R005/HYDR (Group) ''
# /RESULTS/RCHRES_R005/SEDTRN (Group) ''
# /RESULTS/RCHRES_R005/CONS/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R005/GQUAL/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R005/HTRCH/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R005/HYDR/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R005/SEDTRN/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R004/CONS/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R004/GQUAL/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R004/HTRCH/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R004/HYDR/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R004/SEDTRN/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R003/CONS/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R003/GQUAL/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R003/HTRCH/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R003/HYDR/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R003/SEDTRN/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R002/CONS/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R002/GQUAL/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R002/HTRCH/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R002/HYDR/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R002/SEDTRN/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R001/CONS/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R001/GQUAL/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R001/HTRCH/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R001/HYDR/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R001/SEDTRN/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/PERLND_P001/PSTEMP/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/PERLND_P001/PWATER/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/PERLND_P001/PWTGAS/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/PERLND_P001/SNOW/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/IMPLND_I001/IQUAL/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/IMPLND_I001/IWATER/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/IMPLND_I001/IWTGAS/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/IMPLND_I001/SNOW/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/IMPLND_I001/SOLIDS/table (Table(8784,), shuffle, blosc(9)) ''
# /RCHRES/CONS/CONS1 (Group) ''
# /RCHRES/CONS/PARAMETERS (Group) ''
# /RCHRES/CONS/SAVE (Group) ''
# /RCHRES/GENERAL/ACTIVITY (Group) ''
# /RCHRES/GENERAL/INFO (Group) ''
# /RCHRES/GQUAL/EXTENDEDS (Group) ''
# /RCHRES/GQUAL/GQUAL1 (Group) ''
# /RCHRES/GQUAL/PARAMETERS (Group) ''
# /RCHRES/GQUAL/SAVE (Group) ''
# /RCHRES/HTRCH/PARAMETERS (Group) ''
# /RCHRES/HTRCH/SAVE (Group) ''
# /RCHRES/HTRCH/STATES (Group) ''
# /RCHRES/HYDR/PARAMETERS (Group) ''
# /RCHRES/HYDR/SAVE (Group) ''
# /RCHRES/HYDR/STATES (Group) ''
# /RCHRES/NUTRX/FLAGS (Group) ''
# /RCHRES/NUTRX/PARAMETERS (Group) ''
# /RCHRES/NUTRX/SAVE (Group) ''
# /RCHRES/NUTRX/STATES (Group) ''
# /RCHRES/OXRX/FLAGS (Group) ''
# /RCHRES/OXRX/PARAMETERS (Group) ''
# /RCHRES/OXRX/SAVE (Group) ''
# /RCHRES/OXRX/STATES (Group) ''
# /RCHRES/PHCARB/PARAMETERS (Group) ''
# /RCHRES/PHCARB/SAVE (Group) ''
# /RCHRES/PHCARB/STATES (Group) ''
# /RCHRES/PLANK/FLAGS (Group) ''
# /RCHRES/PLANK/PARAMETERS (Group) ''
# /RCHRES/PLANK/SAVE (Group) ''
# /RCHRES/PLANK/STATES (Group) ''
# /RCHRES/RQUAL/FLAGS (Group) ''
# /RCHRES/RQUAL/PARAMETERS (Group) ''
# /RCHRES/SEDTRN/CLAY (Group) ''
# /RCHRES/SEDTRN/FLAGS (Group) ''
# /RCHRES/SEDTRN/PARAMETERS (Group) ''
# /RCHRES/SEDTRN/SAVE (Group) ''
# /RCHRES/SEDTRN/SILT (Group) ''
# /RCHRES/SEDTRN/STATES (Group) ''
# /RCHRES/SEDTRN/CLAY/table (Table(5,)) ''
# /RCHRES/SEDTRN/FLAGS/table (Table(5,)) ''
# /RCHRES/SEDTRN/PARAMETERS/table (Table(5,)) ''
# /RCHRES/SEDTRN/SAVE/table (Table(5,)) ''
# /RCHRES/SEDTRN/SILT/table (Table(5,)) ''
# /RCHRES/SEDTRN/STATES/table (Table(5,)) ''
# /RCHRES/RQUAL/FLAGS/table (Table(5,)) ''
# /RCHRES/RQUAL/PARAMETERS/table (Table(5,)) ''
# /RCHRES/PLANK/FLAGS/table (Table(5,)) ''
# /RCHRES/PLANK/PARAMETERS/table (Table(5,)) ''
# /RCHRES/PLANK/SAVE/table (Table(5,)) ''
# /RCHRES/PLANK/STATES/table (Table(5,)) ''
# /RCHRES/PHCARB/PARAMETERS/table (Table(5,)) ''
# /RCHRES/PHCARB/SAVE/table (Table(5,)) ''
# /RCHRES/PHCARB/STATES/table (Table(5,)) ''
# /RCHRES/OXRX/FLAGS/table (Table(5,)) ''
# /RCHRES/OXRX/PARAMETERS/table (Table(5,)) ''
# /RCHRES/OXRX/SAVE/table (Table(5,)) ''
# /RCHRES/OXRX/STATES/table (Table(5,)) ''
# /RCHRES/NUTRX/FLAGS/table (Table(5,)) ''
# /RCHRES/NUTRX/PARAMETERS/table (Table(5,)) ''
# /RCHRES/NUTRX/SAVE/table (Table(5,)) ''
# /RCHRES/NUTRX/STATES/table (Table(5,)) ''
# /RCHRES/HYDR/PARAMETERS/table (Table(5,)) ''
# /RCHRES/HYDR/SAVE/table (Table(5,)) ''
# /RCHRES/HYDR/STATES/table (Table(5,)) ''
# /RCHRES/HTRCH/PARAMETERS/table (Table(5,)) ''
# /RCHRES/HTRCH/SAVE/table (Table(5,)) ''
# /RCHRES/HTRCH/STATES/table (Table(5,)) ''
# /RCHRES/GQUAL/EXTENDEDS/ALPH (Group) ''
# /RCHRES/GQUAL/EXTENDEDS/DEL (Group) ''
# /RCHRES/GQUAL/EXTENDEDS/GAMM (Group) ''
# /RCHRES/GQUAL/EXTENDEDS/KCLD (Group) ''
# /RCHRES/GQUAL/EXTENDEDS/PHOTPM (Group) ''
# /RCHRES/GQUAL/GQUAL1/table (Table(5,)) ''
# /RCHRES/GQUAL/PARAMETERS/table (Table(5,)) ''
# /RCHRES/GQUAL/SAVE/table (Table(5,)) ''
# /RCHRES/GQUAL/EXTENDEDS/ALPH/table (Table(5,)) ''
# /RCHRES/GQUAL/EXTENDEDS/DEL/table (Table(5,)) ''
# /RCHRES/GQUAL/EXTENDEDS/GAMM/table (Table(5,)) ''
# /RCHRES/GQUAL/EXTENDEDS/KCLD/table (Table(5,)) ''
# /RCHRES/GQUAL/EXTENDEDS/PHOTPM/table (Table(5,)) ''
# /RCHRES/GENERAL/ACTIVITY/table (Table(5,)) ''
# /RCHRES/GENERAL/INFO/table (Table(5,)) ''
# /RCHRES/CONS/CONS1/table (Table(5,)) ''
# /RCHRES/CONS/PARAMETERS/table (Table(5,)) ''
# /RCHRES/CONS/SAVE/table (Table(5,)) ''
# /PERLND/GENERAL/ACTIVITY (Group) ''
# /PERLND/GENERAL/INFO (Group) ''
# /PERLND/PSTEMP/PARAMETERS (Group) ''
# /PERLND/PSTEMP/SAVE (Group) ''
# /PERLND/PWATER/MONTHLY (Group) ''
# /PERLND/PWATER/PARAMETERS (Group) ''
# /PERLND/PWATER/SAVE (Group) ''
# /PERLND/PWATER/STATES (Group) ''
# /PERLND/PWTGAS/PARAMETERS (Group) ''
# /PERLND/PWTGAS/SAVE (Group) ''
# /PERLND/SNOW/FLAGS (Group) ''
# /PERLND/SNOW/PARAMETERS (Group) ''
# /PERLND/SNOW/SAVE (Group) ''
# /PERLND/SNOW/STATES (Group) ''
# /PERLND/SNOW/FLAGS/table (Table(1,)) ''
# /PERLND/SNOW/PARAMETERS/table (Table(1,)) ''
# /PERLND/SNOW/SAVE/table (Table(1,)) ''
# /PERLND/SNOW/STATES/table (Table(1,)) ''
# /PERLND/PWTGAS/PARAMETERS/table (Table(1,)) ''
# /PERLND/PWTGAS/SAVE/table (Table(1,)) ''
# /PERLND/PWATER/MONTHLY/CEPSC (Group) ''
# /PERLND/PWATER/MONTHLY/LZETP (Group) ''
# /PERLND/PWATER/MONTHLY/NSUR (Group) ''
# /PERLND/PWATER/MONTHLY/UZSN (Group) ''
# /PERLND/PWATER/PARAMETERS/table (Table(1,)) ''
# /PERLND/PWATER/SAVE/table (Table(1,)) ''
# /PERLND/PWATER/STATES/table (Table(1,)) ''
# /PERLND/PWATER/MONTHLY/CEPSC/table (Table(1,)) ''
# /PERLND/PWATER/MONTHLY/LZETP/table (Table(1,)) ''
# /PERLND/PWATER/MONTHLY/NSUR/table (Table(1,)) ''
# /PERLND/PWATER/MONTHLY/UZSN/table (Table(1,)) ''
# /PERLND/PSTEMP/PARAMETERS/table (Table(1,)) ''
# /PERLND/PSTEMP/SAVE/table (Table(1,)) ''
# /PERLND/GENERAL/ACTIVITY/table (Table(1,)) ''
# /PERLND/GENERAL/INFO/table (Table(1,)) ''
# /IMPLND/GENERAL/ACTIVITY (Group) ''
# /IMPLND/GENERAL/INFO (Group) ''
# /IMPLND/IQUAL/IQUAL1 (Group) ''
# /IMPLND/IQUAL/PARAMETERS (Group) ''
# /IMPLND/IQUAL/SAVE (Group) ''
# /IMPLND/IWATER/PARAMETERS (Group) ''
# /IMPLND/IWATER/SAVE (Group) ''
# /IMPLND/IWATER/STATES (Group) ''
# /IMPLND/IWTGAS/PARAMETERS (Group) ''
# /IMPLND/IWTGAS/SAVE (Group) ''
# /IMPLND/SNOW/FLAGS (Group) ''
# /IMPLND/SNOW/PARAMETERS (Group) ''
# /IMPLND/SNOW/SAVE (Group) ''
# /IMPLND/SNOW/STATES (Group) ''
# /IMPLND/SOLIDS/PARAMETERS (Group) ''
# /IMPLND/SOLIDS/SAVE (Group) ''
# /IMPLND/SOLIDS/PARAMETERS/table (Table(1,)) ''
# /IMPLND/SOLIDS/SAVE/table (Table(1,)) ''
# /IMPLND/SNOW/FLAGS/table (Table(1,)) ''
# /IMPLND/SNOW/PARAMETERS/table (Table(1,)) ''
# /IMPLND/SNOW/SAVE/table (Table(1,)) ''
# /IMPLND/SNOW/STATES/table (Table(1,)) ''
# /IMPLND/IWTGAS/PARAMETERS/table (Table(1,)) ''
# /IMPLND/IWTGAS/SAVE/table (Table(1,)) ''
# /IMPLND/IWATER/PARAMETERS/table (Table(1,)) ''
# /IMPLND/IWATER/SAVE/table (Table(1,)) ''
# /IMPLND/IWATER/STATES/table (Table(1,)) ''
# /IMPLND/IQUAL/IQUAL1/FLAGS (Group) ''
# /IMPLND/IQUAL/IQUAL1/PARAMETERS (Group) ''
# /IMPLND/IQUAL/PARAMETERS/table (Table(1,)) ''
# /IMPLND/IQUAL/SAVE/table (Table(1,)) ''
# /IMPLND/IQUAL/IQUAL1/FLAGS/table (Table(1,)) ''
# /IMPLND/IQUAL/IQUAL1/PARAMETERS/table (Table(1,)) ''
# /IMPLND/GENERAL/ACTIVITY/table (Table(1,)) ''
# /IMPLND/GENERAL/INFO/table (Table(1,)) ''
# /FTABLES/FT001/table (Table(14,)) ''
# /FTABLES/FT002/table (Table(13,)) ''
# /FTABLES/FT003/table (Table(13,)) ''
# /FTABLES/FT004/table (Table(13,)) ''
# /FTABLES/FT005/table (Table(13,)) ''
# /CONTROL/EXT_SOURCES/table (Table(50,)) ''
# /CONTROL/GLOBAL/table (Table(3,)) ''
# /CONTROL/LINKS/table (Table(7,)) ''
# /CONTROL/MASS_LINKS/table (Table(15,)) ''
# /CONTROL/OP_SEQUENCE/table (Table(7,)) ''

# %%
for group in h5file.walk_groups():
    print(group)
# Out:
# / (RootGroup) ''
# /CONTROL (Group) ''
# /FTABLES (Group) ''
# /IMPLND (Group) ''
# /PERLND (Group) ''
# /RCHRES (Group) ''
# /RESULTS (Group) ''
# /RUN_INFO (Group) ''
# /TIMESERIES (Group) ''
# /TIMESERIES/LAPSE_Table (Group) ''
# /TIMESERIES/SEASONS_Table (Group) ''
# /TIMESERIES/SUMMARY (Group) ''
# /TIMESERIES/Saturated_Vapor_Pressure_Table (Group) ''
# /TIMESERIES/TS039 (Group) ''
# /TIMESERIES/TS041 (Group) ''
# /TIMESERIES/TS042 (Group) ''
# /TIMESERIES/TS046 (Group) ''
# /TIMESERIES/TS113 (Group) ''
# /TIMESERIES/TS119 (Group) ''
# /TIMESERIES/TS121 (Group) ''
# /TIMESERIES/TS122 (Group) ''
# /TIMESERIES/TS123 (Group) ''
# /TIMESERIES/TS124 (Group) ''
# /TIMESERIES/TS125 (Group) ''
# /TIMESERIES/TS126 (Group) ''
# /TIMESERIES/TS127 (Group) ''
# /TIMESERIES/TS131 (Group) ''
# /TIMESERIES/TS132 (Group) ''
# /TIMESERIES/TS134 (Group) ''
# /TIMESERIES/TS135 (Group) ''
# /TIMESERIES/TS136 (Group) ''
# /TIMESERIES/TS140 (Group) ''
# /RUN_INFO/LOGFILE (Group) ''
# /RUN_INFO/VERSIONS (Group) ''
# /RESULTS/IMPLND_I001 (Group) ''
# /RESULTS/PERLND_P001 (Group) ''
# /RESULTS/RCHRES_R001 (Group) ''
# /RESULTS/RCHRES_R002 (Group) ''
# /RESULTS/RCHRES_R003 (Group) ''
# /RESULTS/RCHRES_R004 (Group) ''
# /RESULTS/RCHRES_R005 (Group) ''
# /RESULTS/RCHRES_R005/CONS (Group) ''
# /RESULTS/RCHRES_R005/GQUAL (Group) ''
# /RESULTS/RCHRES_R005/HTRCH (Group) ''
# /RESULTS/RCHRES_R005/HYDR (Group) ''
# /RESULTS/RCHRES_R005/SEDTRN (Group) ''
# /RESULTS/RCHRES_R004/CONS (Group) ''
# /RESULTS/RCHRES_R004/GQUAL (Group) ''
# /RESULTS/RCHRES_R004/HTRCH (Group) ''
# /RESULTS/RCHRES_R004/HYDR (Group) ''
# /RESULTS/RCHRES_R004/SEDTRN (Group) ''
# /RESULTS/RCHRES_R003/CONS (Group) ''
# /RESULTS/RCHRES_R003/GQUAL (Group) ''
# /RESULTS/RCHRES_R003/HTRCH (Group) ''
# /RESULTS/RCHRES_R003/HYDR (Group) ''
# /RESULTS/RCHRES_R003/SEDTRN (Group) ''
# /RESULTS/RCHRES_R002/CONS (Group) ''
# /RESULTS/RCHRES_R002/GQUAL (Group) ''
# /RESULTS/RCHRES_R002/HTRCH (Group) ''
# /RESULTS/RCHRES_R002/HYDR (Group) ''
# /RESULTS/RCHRES_R002/SEDTRN (Group) ''
# /RESULTS/RCHRES_R001/CONS (Group) ''
# /RESULTS/RCHRES_R001/GQUAL (Group) ''
# /RESULTS/RCHRES_R001/HTRCH (Group) ''
# /RESULTS/RCHRES_R001/HYDR (Group) ''
# /RESULTS/RCHRES_R001/SEDTRN (Group) ''
# /RESULTS/PERLND_P001/PSTEMP (Group) ''
# /RESULTS/PERLND_P001/PWATER (Group) ''
# /RESULTS/PERLND_P001/PWTGAS (Group) ''
# /RESULTS/PERLND_P001/SNOW (Group) ''
# /RESULTS/IMPLND_I001/IQUAL (Group) ''
# /RESULTS/IMPLND_I001/IWATER (Group) ''
# /RESULTS/IMPLND_I001/IWTGAS (Group) ''
# /RESULTS/IMPLND_I001/SNOW (Group) ''
# /RESULTS/IMPLND_I001/SOLIDS (Group) ''
# /RCHRES/CONS (Group) ''
# /RCHRES/GENERAL (Group) ''
# /RCHRES/GQUAL (Group) ''
# /RCHRES/HTRCH (Group) ''
# /RCHRES/HYDR (Group) ''
# /RCHRES/NUTRX (Group) ''
# /RCHRES/OXRX (Group) ''
# /RCHRES/PHCARB (Group) ''
# /RCHRES/PLANK (Group) ''
# /RCHRES/RQUAL (Group) ''
# /RCHRES/SEDTRN (Group) ''
# /RCHRES/SEDTRN/CLAY (Group) ''
# /RCHRES/SEDTRN/FLAGS (Group) ''
# /RCHRES/SEDTRN/PARAMETERS (Group) ''
# /RCHRES/SEDTRN/SAVE (Group) ''
# /RCHRES/SEDTRN/SILT (Group) ''
# /RCHRES/SEDTRN/STATES (Group) ''
# /RCHRES/RQUAL/FLAGS (Group) ''
# /RCHRES/RQUAL/PARAMETERS (Group) ''
# /RCHRES/PLANK/FLAGS (Group) ''
# /RCHRES/PLANK/PARAMETERS (Group) ''
# /RCHRES/PLANK/SAVE (Group) ''
# /RCHRES/PLANK/STATES (Group) ''
# /RCHRES/PHCARB/PARAMETERS (Group) ''
# /RCHRES/PHCARB/SAVE (Group) ''
# /RCHRES/PHCARB/STATES (Group) ''
# /RCHRES/OXRX/FLAGS (Group) ''
# /RCHRES/OXRX/PARAMETERS (Group) ''
# /RCHRES/OXRX/SAVE (Group) ''
# /RCHRES/OXRX/STATES (Group) ''
# /RCHRES/NUTRX/FLAGS (Group) ''
# /RCHRES/NUTRX/PARAMETERS (Group) ''
# /RCHRES/NUTRX/SAVE (Group) ''
# /RCHRES/NUTRX/STATES (Group) ''
# /RCHRES/HYDR/PARAMETERS (Group) ''
# /RCHRES/HYDR/SAVE (Group) ''
# /RCHRES/HYDR/STATES (Group) ''
# /RCHRES/HTRCH/PARAMETERS (Group) ''
# /RCHRES/HTRCH/SAVE (Group) ''
# /RCHRES/HTRCH/STATES (Group) ''
# /RCHRES/GQUAL/EXTENDEDS (Group) ''
# /RCHRES/GQUAL/GQUAL1 (Group) ''
# /RCHRES/GQUAL/PARAMETERS (Group) ''
# /RCHRES/GQUAL/SAVE (Group) ''
# /RCHRES/GQUAL/EXTENDEDS/ALPH (Group) ''
# /RCHRES/GQUAL/EXTENDEDS/DEL (Group) ''
# /RCHRES/GQUAL/EXTENDEDS/GAMM (Group) ''
# /RCHRES/GQUAL/EXTENDEDS/KCLD (Group) ''
# /RCHRES/GQUAL/EXTENDEDS/PHOTPM (Group) ''
# /RCHRES/GENERAL/ACTIVITY (Group) ''
# /RCHRES/GENERAL/INFO (Group) ''
# /RCHRES/CONS/CONS1 (Group) ''
# /RCHRES/CONS/PARAMETERS (Group) ''
# /RCHRES/CONS/SAVE (Group) ''
# /PERLND/GENERAL (Group) ''
# /PERLND/PSTEMP (Group) ''
# /PERLND/PWATER (Group) ''
# /PERLND/PWTGAS (Group) ''
# /PERLND/SNOW (Group) ''
# /PERLND/SNOW/FLAGS (Group) ''
# /PERLND/SNOW/PARAMETERS (Group) ''
# /PERLND/SNOW/SAVE (Group) ''
# /PERLND/SNOW/STATES (Group) ''
# /PERLND/PWTGAS/PARAMETERS (Group) ''
# /PERLND/PWTGAS/SAVE (Group) ''
# /PERLND/PWATER/MONTHLY (Group) ''
# /PERLND/PWATER/PARAMETERS (Group) ''
# /PERLND/PWATER/SAVE (Group) ''
# /PERLND/PWATER/STATES (Group) ''
# /PERLND/PWATER/MONTHLY/CEPSC (Group) ''
# /PERLND/PWATER/MONTHLY/LZETP (Group) ''
# /PERLND/PWATER/MONTHLY/NSUR (Group) ''
# /PERLND/PWATER/MONTHLY/UZSN (Group) ''
# /PERLND/PSTEMP/PARAMETERS (Group) ''
# /PERLND/PSTEMP/SAVE (Group) ''
# /PERLND/GENERAL/ACTIVITY (Group) ''
# /PERLND/GENERAL/INFO (Group) ''
# /IMPLND/GENERAL (Group) ''
# /IMPLND/IQUAL (Group) ''
# /IMPLND/IWATER (Group) ''
# /IMPLND/IWTGAS (Group) ''
# /IMPLND/SNOW (Group) ''
# /IMPLND/SOLIDS (Group) ''
# /IMPLND/SOLIDS/PARAMETERS (Group) ''
# /IMPLND/SOLIDS/SAVE (Group) ''
# /IMPLND/SNOW/FLAGS (Group) ''
# /IMPLND/SNOW/PARAMETERS (Group) ''
# /IMPLND/SNOW/SAVE (Group) ''
# /IMPLND/SNOW/STATES (Group) ''
# /IMPLND/IWTGAS/PARAMETERS (Group) ''
# /IMPLND/IWTGAS/SAVE (Group) ''
# /IMPLND/IWATER/PARAMETERS (Group) ''
# /IMPLND/IWATER/SAVE (Group) ''
# /IMPLND/IWATER/STATES (Group) ''
# /IMPLND/IQUAL/IQUAL1 (Group) ''
# /IMPLND/IQUAL/PARAMETERS (Group) ''
# /IMPLND/IQUAL/SAVE (Group) ''
# /IMPLND/IQUAL/IQUAL1/FLAGS (Group) ''
# /IMPLND/IQUAL/IQUAL1/PARAMETERS (Group) ''
# /IMPLND/GENERAL/ACTIVITY (Group) ''
# /IMPLND/GENERAL/INFO (Group) ''
# /FTABLES/FT001 (Group) ''
# /FTABLES/FT002 (Group) ''
# /FTABLES/FT003 (Group) ''
# /FTABLES/FT004 (Group) ''
# /FTABLES/FT005 (Group) ''
# /CONTROL/EXT_SOURCES (Group) ''
# /CONTROL/GLOBAL (Group) ''
# /CONTROL/LINKS (Group) ''
# /CONTROL/MASS_LINKS (Group) ''
# /CONTROL/OP_SEQUENCE (Group) ''

# %%
# From https://www.pytables.org/usersguide/tutorials.html#setting-and-getting-user-attributes

h5file.root
# Out:
# / (RootGroup) ''
#   children := ['CONTROL' (Group), 'FTABLES' (Group), 'IMPLND' (Group), 'PERLND' (Group), 'RCHRES' (Group), 'RESULTS' (Group), 'RUN_INFO' (Group), 'TIMESERIES' (Group)]

# %%
h5file.root.CONTROL
# Out:
# /CONTROL (Group) ''
#   children := ['EXT_SOURCES' (Group), 'GLOBAL' (Group), 'LINKS' (Group), 'MASS_LINKS' (Group), 'OP_SEQUENCE' (Group)]

# %%
h5file.root.CONTROL.EXT_SOURCES.table
# Out:
# /CONTROL/EXT_SOURCES/table (Table(50,)) ''
#   description := {
#   "index": Int64Col(shape=(), dflt=0, pos=0),
#   "SVOL": StringCol(itemsize=1, shape=(), dflt=b'', pos=1),
#   "SVOLNO": StringCol(itemsize=5, shape=(), dflt=b'', pos=2),
#   "SMEMN": StringCol(itemsize=4, shape=(), dflt=b'', pos=3),
#   "SMEMSB": StringCol(itemsize=2, shape=(), dflt=b'', pos=4),
#   "SSYST": StringCol(itemsize=4, shape=(), dflt=b'', pos=5),
#   "SGAPST": StringCol(itemsize=4, shape=(), dflt=b'', pos=6),
#   "MFACTOR": Float64Col(shape=(), dflt=0.0, pos=7),
#   "TRAN": StringCol(itemsize=4, shape=(), dflt=b'', pos=8),
#   "TVOL": StringCol(itemsize=6, shape=(), dflt=b'', pos=9),
#   "TGRPN": StringCol(itemsize=5, shape=(), dflt=b'', pos=10),
#   "TMEMN": StringCol(itemsize=6, shape=(), dflt=b'', pos=11),
#   "TMEMSB": StringCol(itemsize=1, shape=(), dflt=b'', pos=12),
#   "TVOLNO": StringCol(itemsize=4, shape=(), dflt=b'', pos=13),
#   "COMMENT": StringCol(itemsize=1, shape=(), dflt=b'', pos=14)}
#   byteorder := 'little'
#   chunkshape := (1040,)
#   autoindex := True
#   colindexes := {
#     "index": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SVOL": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SVOLNO": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SMEMN": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SMEMSB": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SSYST": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "SGAPST": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "MFACTOR": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TRAN": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TVOL": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TGRPN": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TMEMN": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TMEMSB": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "TVOLNO": Index(6, medium, shuffle, zlib(1)).is_csi=False,
#     "COMMENT": Index(6, medium, shuffle, zlib(1)).is_csi=False}

# %% [markdown]
# ## Always close an HDF5 file!
#
# It is important to close the HDF5 file, using `h5file.close()`). Otherwise it will be corrupted to other programs. See https://www.pytables.org/usersguide/tutorials.html#closing-the-file-and-looking-at-its-content

# %%
# Check if open (1 = True)
h5file.isopen
# Out:
# 1

# %%
h5file.close()

# %%
h5file
# Out:
# <closed File>

# %% [markdown]
# ## PyTables `ptdump` command line utility
#
# The command line “ptdump” PyTables utility (located in utils/ directory)
# https://www.pytables.org/usersguide/tutorials.html#closing-the-file-and-looking-at-its-content

# %%
# get path, as pathlib only works within Python and not at the operating system command prompt.
file_to_open
# Out:
# PosixPath('/Users/aaufdenkampe/Documents/Python/limno.HSPsquared/HSP2notebooks/Data/hsp2.h5')

# %%
# This uses the `!` ipython magic command to run from the console
# !ptdump '/Users/aaufdenkampe/Documents/Python/limno.HSPsquared/HSP2notebooks/Data/hsp2.h5'

# You can pass the -v or -d options to ptdump if you want more verbosity
# Out:
# / (RootGroup) ''
# /CONTROL (Group) ''
# /FTABLES (Group) ''
# /IMPLND (Group) ''
# /PERLND (Group) ''
# /RCHRES (Group) ''
# /RESULTS (Group) ''
# /RUN_INFO (Group) ''
# /TIMESERIES (Group) ''
# /TIMESERIES/LAPSE_Table (Group) ''
# /TIMESERIES/LAPSE_Table/table (Table(24,)) ''
# /TIMESERIES/SEASONS_Table (Group) ''
# /TIMESERIES/SEASONS_Table/table (Table(12,)) ''
# /TIMESERIES/SUMMARY (Group) ''
# /TIMESERIES/SUMMARY/table (Table(19,)) ''
# /TIMESERIES/Saturated_Vapor_Pressure_Table (Group) ''
# /TIMESERIES/Saturated_Vapor_Pressure_Table/table (Table(40,)) ''
# /TIMESERIES/TS039 (Group) ''
# /TIMESERIES/TS039/table (Table(8784,), shuffle, blosc(9)) ''
# /TIMESERIES/TS041 (Group) ''
# /TIMESERIES/TS041/table (Table(366,), shuffle, blosc(9)) ''
# /TIMESERIES/TS042 (Group) ''
# /TIMESERIES/TS042/table (Table(366,), shuffle, blosc(9)) ''
# /TIMESERIES/TS046 (Group) ''
# /TIMESERIES/TS046/table (Table(4392,), shuffle, blosc(9)) ''
# /TIMESERIES/TS113 (Group) ''
# /TIMESERIES/TS113/table (Table(366,), shuffle, blosc(9)) ''
# /TIMESERIES/TS119 (Group) ''
# /TIMESERIES/TS119/table (Table(366,), shuffle, blosc(9)) ''
# /TIMESERIES/TS121 (Group) ''
# /TIMESERIES/TS121/table (Table(4392,), shuffle, blosc(9)) ''
# /TIMESERIES/TS122 (Group) ''
# /TIMESERIES/TS122/table (Table(4392,), shuffle, blosc(9)) ''
# /TIMESERIES/TS123 (Group) ''
# /TIMESERIES/TS123/table (Table(4392,), shuffle, blosc(9)) ''
# /TIMESERIES/TS124 (Group) ''
# /TIMESERIES/TS124/table (Table(366,), shuffle, blosc(9)) ''
# /TIMESERIES/TS125 (Group) ''
# /TIMESERIES/TS125/table (Table(366,), shuffle, blosc(9)) ''
# /TIMESERIES/TS126 (Group) ''
# /TIMESERIES/TS126/table (Table(366,), shuffle, blosc(9)) ''
# /TIMESERIES/TS127 (Group) ''
# /TIMESERIES/TS127/table (Table(366,), shuffle, blosc(9)) ''
# /TIMESERIES/TS131 (Group) ''
# /TIMESERIES/TS131/table (Table(8784,), shuffle, blosc(9)) ''
# /TIMESERIES/TS132 (Group) ''
# /TIMESERIES/TS132/table (Table(8784,), shuffle, blosc(9)) ''
# /TIMESERIES/TS134 (Group) ''
# /TIMESERIES/TS134/table (Table(366,), shuffle, blosc(9)) ''
# /TIMESERIES/TS135 (Group) ''
# /TIMESERIES/TS135/table (Table(366,), shuffle, blosc(9)) ''
# /TIMESERIES/TS136 (Group) ''
# /TIMESERIES/TS136/table (Table(366,), shuffle, blosc(9)) ''
# /TIMESERIES/TS140 (Group) ''
# /TIMESERIES/TS140/table (Table(366,), shuffle, blosc(9)) ''
# /RUN_INFO/LOGFILE (Group) ''
# /RUN_INFO/LOGFILE/table (Table(49,)) ''
# /RUN_INFO/VERSIONS (Group) ''
# /RUN_INFO/VERSIONS/table (Table(10,)) ''
# /RESULTS/IMPLND_I001 (Group) ''
# /RESULTS/PERLND_P001 (Group) ''
# /RESULTS/RCHRES_R001 (Group) ''
# /RESULTS/RCHRES_R002 (Group) ''
# /RESULTS/RCHRES_R003 (Group) ''
# /RESULTS/RCHRES_R004 (Group) ''
# /RESULTS/RCHRES_R005 (Group) ''
# /RESULTS/RCHRES_R005/CONS (Group) ''
# /RESULTS/RCHRES_R005/CONS/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R005/GQUAL (Group) ''
# /RESULTS/RCHRES_R005/GQUAL/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R005/HTRCH (Group) ''
# /RESULTS/RCHRES_R005/HTRCH/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R005/HYDR (Group) ''
# /RESULTS/RCHRES_R005/HYDR/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R005/SEDTRN (Group) ''
# /RESULTS/RCHRES_R005/SEDTRN/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R004/CONS (Group) ''
# /RESULTS/RCHRES_R004/CONS/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R004/GQUAL (Group) ''
# /RESULTS/RCHRES_R004/GQUAL/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R004/HTRCH (Group) ''
# /RESULTS/RCHRES_R004/HTRCH/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R004/HYDR (Group) ''
# /RESULTS/RCHRES_R004/HYDR/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R004/SEDTRN (Group) ''
# /RESULTS/RCHRES_R004/SEDTRN/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R003/CONS (Group) ''
# /RESULTS/RCHRES_R003/CONS/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R003/GQUAL (Group) ''
# /RESULTS/RCHRES_R003/GQUAL/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R003/HTRCH (Group) ''
# /RESULTS/RCHRES_R003/HTRCH/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R003/HYDR (Group) ''
# /RESULTS/RCHRES_R003/HYDR/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R003/SEDTRN (Group) ''
# /RESULTS/RCHRES_R003/SEDTRN/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R002/CONS (Group) ''
# /RESULTS/RCHRES_R002/CONS/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R002/GQUAL (Group) ''
# /RESULTS/RCHRES_R002/GQUAL/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R002/HTRCH (Group) ''
# /RESULTS/RCHRES_R002/HTRCH/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R002/HYDR (Group) ''
# /RESULTS/RCHRES_R002/HYDR/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R002/SEDTRN (Group) ''
# /RESULTS/RCHRES_R002/SEDTRN/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R001/CONS (Group) ''
# /RESULTS/RCHRES_R001/CONS/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R001/GQUAL (Group) ''
# /RESULTS/RCHRES_R001/GQUAL/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R001/HTRCH (Group) ''
# /RESULTS/RCHRES_R001/HTRCH/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R001/HYDR (Group) ''
# /RESULTS/RCHRES_R001/HYDR/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/RCHRES_R001/SEDTRN (Group) ''
# /RESULTS/RCHRES_R001/SEDTRN/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/PERLND_P001/PSTEMP (Group) ''
# /RESULTS/PERLND_P001/PSTEMP/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/PERLND_P001/PWATER (Group) ''
# /RESULTS/PERLND_P001/PWATER/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/PERLND_P001/PWTGAS (Group) ''
# /RESULTS/PERLND_P001/PWTGAS/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/PERLND_P001/SNOW (Group) ''
# /RESULTS/PERLND_P001/SNOW/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/IMPLND_I001/IQUAL (Group) ''
# /RESULTS/IMPLND_I001/IQUAL/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/IMPLND_I001/IWATER (Group) ''
# /RESULTS/IMPLND_I001/IWATER/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/IMPLND_I001/IWTGAS (Group) ''
# /RESULTS/IMPLND_I001/IWTGAS/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/IMPLND_I001/SNOW (Group) ''
# /RESULTS/IMPLND_I001/SNOW/table (Table(8784,), shuffle, blosc(9)) ''
# /RESULTS/IMPLND_I001/SOLIDS (Group) ''
# /RESULTS/IMPLND_I001/SOLIDS/table (Table(8784,), shuffle, blosc(9)) ''
# /RCHRES/CONS (Group) ''
# /RCHRES/GENERAL (Group) ''
# /RCHRES/GQUAL (Group) ''
# /RCHRES/HTRCH (Group) ''
# /RCHRES/HYDR (Group) ''
# /RCHRES/NUTRX (Group) ''
# /RCHRES/OXRX (Group) ''
# /RCHRES/PHCARB (Group) ''
# /RCHRES/PLANK (Group) ''
# /RCHRES/RQUAL (Group) ''
# /RCHRES/SEDTRN (Group) ''
# /RCHRES/SEDTRN/CLAY (Group) ''
# /RCHRES/SEDTRN/CLAY/table (Table(5,)) ''
# /RCHRES/SEDTRN/FLAGS (Group) ''
# /RCHRES/SEDTRN/FLAGS/table (Table(5,)) ''
# /RCHRES/SEDTRN/PARAMETERS (Group) ''
# /RCHRES/SEDTRN/PARAMETERS/table (Table(5,)) ''
# /RCHRES/SEDTRN/SAVE (Group) ''
# /RCHRES/SEDTRN/SAVE/table (Table(5,)) ''
# /RCHRES/SEDTRN/SILT (Group) ''
# /RCHRES/SEDTRN/SILT/table (Table(5,)) ''
# /RCHRES/SEDTRN/STATES (Group) ''
# /RCHRES/SEDTRN/STATES/table (Table(5,)) ''
# /RCHRES/RQUAL/FLAGS (Group) ''
# /RCHRES/RQUAL/FLAGS/table (Table(5,)) ''
# /RCHRES/RQUAL/PARAMETERS (Group) ''
# /RCHRES/RQUAL/PARAMETERS/table (Table(5,)) ''
# /RCHRES/PLANK/FLAGS (Group) ''
# /RCHRES/PLANK/FLAGS/table (Table(5,)) ''
# /RCHRES/PLANK/PARAMETERS (Group) ''
# /RCHRES/PLANK/PARAMETERS/table (Table(5,)) ''
# /RCHRES/PLANK/SAVE (Group) ''
# /RCHRES/PLANK/SAVE/table (Table(5,)) ''
# /RCHRES/PLANK/STATES (Group) ''
# /RCHRES/PLANK/STATES/table (Table(5,)) ''
# /RCHRES/PHCARB/PARAMETERS (Group) ''
# /RCHRES/PHCARB/PARAMETERS/table (Table(5,)) ''
# /RCHRES/PHCARB/SAVE (Group) ''
# /RCHRES/PHCARB/SAVE/table (Table(5,)) ''
# /RCHRES/PHCARB/STATES (Group) ''
# /RCHRES/PHCARB/STATES/table (Table(5,)) ''
# /RCHRES/OXRX/FLAGS (Group) ''
# /RCHRES/OXRX/FLAGS/table (Table(5,)) ''
# /RCHRES/OXRX/PARAMETERS (Group) ''
# /RCHRES/OXRX/PARAMETERS/table (Table(5,)) ''
# /RCHRES/OXRX/SAVE (Group) ''
# /RCHRES/OXRX/SAVE/table (Table(5,)) ''
# /RCHRES/OXRX/STATES (Group) ''
# /RCHRES/OXRX/STATES/table (Table(5,)) ''
# /RCHRES/NUTRX/FLAGS (Group) ''
# /RCHRES/NUTRX/FLAGS/table (Table(5,)) ''
# /RCHRES/NUTRX/PARAMETERS (Group) ''
# /RCHRES/NUTRX/PARAMETERS/table (Table(5,)) ''
# /RCHRES/NUTRX/SAVE (Group) ''
# /RCHRES/NUTRX/SAVE/table (Table(5,)) ''
# /RCHRES/NUTRX/STATES (Group) ''
# /RCHRES/NUTRX/STATES/table (Table(5,)) ''
# /RCHRES/HYDR/PARAMETERS (Group) ''
# /RCHRES/HYDR/PARAMETERS/table (Table(5,)) ''
# /RCHRES/HYDR/SAVE (Group) ''
# /RCHRES/HYDR/SAVE/table (Table(5,)) ''
# /RCHRES/HYDR/STATES (Group) ''
# /RCHRES/HYDR/STATES/table (Table(5,)) ''
# /RCHRES/HTRCH/PARAMETERS (Group) ''
# /RCHRES/HTRCH/PARAMETERS/table (Table(5,)) ''
# /RCHRES/HTRCH/SAVE (Group) ''
# /RCHRES/HTRCH/SAVE/table (Table(5,)) ''
# /RCHRES/HTRCH/STATES (Group) ''
# /RCHRES/HTRCH/STATES/table (Table(5,)) ''
# /RCHRES/GQUAL/EXTENDEDS (Group) ''
# /RCHRES/GQUAL/GQUAL1 (Group) ''
# /RCHRES/GQUAL/GQUAL1/table (Table(5,)) ''
# /RCHRES/GQUAL/PARAMETERS (Group) ''
# /RCHRES/GQUAL/PARAMETERS/table (Table(5,)) ''
# /RCHRES/GQUAL/SAVE (Group) ''
# /RCHRES/GQUAL/SAVE/table (Table(5,)) ''
# /RCHRES/GQUAL/EXTENDEDS/ALPH (Group) ''
# /RCHRES/GQUAL/EXTENDEDS/ALPH/table (Table(5,)) ''
# /RCHRES/GQUAL/EXTENDEDS/DEL (Group) ''
# /RCHRES/GQUAL/EXTENDEDS/DEL/table (Table(5,)) ''
# /RCHRES/GQUAL/EXTENDEDS/GAMM (Group) ''
# /RCHRES/GQUAL/EXTENDEDS/GAMM/table (Table(5,)) ''
# /RCHRES/GQUAL/EXTENDEDS/KCLD (Group) ''
# /RCHRES/GQUAL/EXTENDEDS/KCLD/table (Table(5,)) ''
# /RCHRES/GQUAL/EXTENDEDS/PHOTPM (Group) ''
# /RCHRES/GQUAL/EXTENDEDS/PHOTPM/table (Table(5,)) ''
# /RCHRES/GENERAL/ACTIVITY (Group) ''
# /RCHRES/GENERAL/ACTIVITY/table (Table(5,)) ''
# /RCHRES/GENERAL/INFO (Group) ''
# /RCHRES/GENERAL/INFO/table (Table(5,)) ''
# /RCHRES/CONS/CONS1 (Group) ''
# /RCHRES/CONS/CONS1/table (Table(5,)) ''
# /RCHRES/CONS/PARAMETERS (Group) ''
# /RCHRES/CONS/PARAMETERS/table (Table(5,)) ''
# /RCHRES/CONS/SAVE (Group) ''
# /RCHRES/CONS/SAVE/table (Table(5,)) ''
# /PERLND/GENERAL (Group) ''
# /PERLND/PSTEMP (Group) ''
# /PERLND/PWATER (Group) ''
# /PERLND/PWTGAS (Group) ''
# /PERLND/SNOW (Group) ''
# /PERLND/SNOW/FLAGS (Group) ''
# /PERLND/SNOW/FLAGS/table (Table(1,)) ''
# /PERLND/SNOW/PARAMETERS (Group) ''
# /PERLND/SNOW/PARAMETERS/table (Table(1,)) ''
# /PERLND/SNOW/SAVE (Group) ''
# /PERLND/SNOW/SAVE/table (Table(1,)) ''
# /PERLND/SNOW/STATES (Group) ''
# /PERLND/SNOW/STATES/table (Table(1,)) ''
# /PERLND/PWTGAS/PARAMETERS (Group) ''
# /PERLND/PWTGAS/PARAMETERS/table (Table(1,)) ''
# /PERLND/PWTGAS/SAVE (Group) ''
# /PERLND/PWTGAS/SAVE/table (Table(1,)) ''
# /PERLND/PWATER/MONTHLY (Group) ''
# /PERLND/PWATER/PARAMETERS (Group) ''
# /PERLND/PWATER/PARAMETERS/table (Table(1,)) ''
# /PERLND/PWATER/SAVE (Group) ''
# /PERLND/PWATER/SAVE/table (Table(1,)) ''
# /PERLND/PWATER/STATES (Group) ''
# /PERLND/PWATER/STATES/table (Table(1,)) ''
# /PERLND/PWATER/MONTHLY/CEPSC (Group) ''
# /PERLND/PWATER/MONTHLY/CEPSC/table (Table(1,)) ''
# /PERLND/PWATER/MONTHLY/LZETP (Group) ''
# /PERLND/PWATER/MONTHLY/LZETP/table (Table(1,)) ''
# /PERLND/PWATER/MONTHLY/NSUR (Group) ''
# /PERLND/PWATER/MONTHLY/NSUR/table (Table(1,)) ''
# /PERLND/PWATER/MONTHLY/UZSN (Group) ''
# /PERLND/PWATER/MONTHLY/UZSN/table (Table(1,)) ''
# /PERLND/PSTEMP/PARAMETERS (Group) ''
# /PERLND/PSTEMP/PARAMETERS/table (Table(1,)) ''
# /PERLND/PSTEMP/SAVE (Group) ''
# /PERLND/PSTEMP/SAVE/table (Table(1,)) ''
# /PERLND/GENERAL/ACTIVITY (Group) ''
# /PERLND/GENERAL/ACTIVITY/table (Table(1,)) ''
# /PERLND/GENERAL/INFO (Group) ''
# /PERLND/GENERAL/INFO/table (Table(1,)) ''
# /IMPLND/GENERAL (Group) ''
# /IMPLND/IQUAL (Group) ''
# /IMPLND/IWATER (Group) ''
# /IMPLND/IWTGAS (Group) ''
# /IMPLND/SNOW (Group) ''
# /IMPLND/SOLIDS (Group) ''
# /IMPLND/SOLIDS/PARAMETERS (Group) ''
# /IMPLND/SOLIDS/PARAMETERS/table (Table(1,)) ''
# /IMPLND/SOLIDS/SAVE (Group) ''
# /IMPLND/SOLIDS/SAVE/table (Table(1,)) ''
# /IMPLND/SNOW/FLAGS (Group) ''
# /IMPLND/SNOW/FLAGS/table (Table(1,)) ''
# /IMPLND/SNOW/PARAMETERS (Group) ''
# /IMPLND/SNOW/PARAMETERS/table (Table(1,)) ''
# /IMPLND/SNOW/SAVE (Group) ''
# /IMPLND/SNOW/SAVE/table (Table(1,)) ''
# /IMPLND/SNOW/STATES (Group) ''
# /IMPLND/SNOW/STATES/table (Table(1,)) ''
# /IMPLND/IWTGAS/PARAMETERS (Group) ''
# /IMPLND/IWTGAS/PARAMETERS/table (Table(1,)) ''
# /IMPLND/IWTGAS/SAVE (Group) ''
# /IMPLND/IWTGAS/SAVE/table (Table(1,)) ''
# /IMPLND/IWATER/PARAMETERS (Group) ''
# /IMPLND/IWATER/PARAMETERS/table (Table(1,)) ''
# /IMPLND/IWATER/SAVE (Group) ''
# /IMPLND/IWATER/SAVE/table (Table(1,)) ''
# /IMPLND/IWATER/STATES (Group) ''
# /IMPLND/IWATER/STATES/table (Table(1,)) ''
# /IMPLND/IQUAL/IQUAL1 (Group) ''
# /IMPLND/IQUAL/PARAMETERS (Group) ''
# /IMPLND/IQUAL/PARAMETERS/table (Table(1,)) ''
# /IMPLND/IQUAL/SAVE (Group) ''
# /IMPLND/IQUAL/SAVE/table (Table(1,)) ''
# /IMPLND/IQUAL/IQUAL1/FLAGS (Group) ''
# /IMPLND/IQUAL/IQUAL1/FLAGS/table (Table(1,)) ''
# /IMPLND/IQUAL/IQUAL1/PARAMETERS (Group) ''
# /IMPLND/IQUAL/IQUAL1/PARAMETERS/table (Table(1,)) ''
# /IMPLND/GENERAL/ACTIVITY (Group) ''
# /IMPLND/GENERAL/ACTIVITY/table (Table(1,)) ''
# /IMPLND/GENERAL/INFO (Group) ''
# /IMPLND/GENERAL/INFO/table (Table(1,)) ''
# /FTABLES/FT001 (Group) ''
# /FTABLES/FT001/table (Table(14,)) ''
# /FTABLES/FT002 (Group) ''
# /FTABLES/FT002/table (Table(13,)) ''
# /FTABLES/FT003 (Group) ''
# /FTABLES/FT003/table (Table(13,)) ''
# /FTABLES/FT004 (Group) ''
# /FTABLES/FT004/table (Table(13,)) ''
# /FTABLES/FT005 (Group) ''
# /FTABLES/FT005/table (Table(13,)) ''
# /CONTROL/EXT_SOURCES (Group) ''
# /CONTROL/EXT_SOURCES/table (Table(50,)) ''
# /CONTROL/GLOBAL (Group) ''
# /CONTROL/GLOBAL/table (Table(3,)) ''
# /CONTROL/LINKS (Group) ''
# /CONTROL/LINKS/table (Table(7,)) ''
# /CONTROL/MASS_LINKS (Group) ''
# /CONTROL/MASS_LINKS/table (Table(15,)) ''
# /CONTROL/OP_SEQUENCE (Group) ''
# /CONTROL/OP_SEQUENCE/table (Table(7,)) ''

# %% [markdown]
# # Open with h5py library
#
# Docs: https://docs.h5py.org
# Demo: https://nbviewer.jupyter.org/github/jackdbd/hdf5-pydata-munich/blob/master/hdf5_in_python.ipynb

# %%
# https://docs.h5py.org/en/stable/high/file.html#opening-creating-files

h5py_file = h5py.File(paths[0])

# NOTE: if the file was left open, you might get this error: `OSError: Unable to open file (File signature not found)`
# https://stackoverflow.com/questions/38089950/error-opening-file-in-h5py-file-signature-not-found/43607837

# %%
h5py_file?
# Out:
# Type:           File
# String form:    <HDF5 file "hsp2.h5" (mode r)>
# Length:         8
# File:           ~/opt/anaconda3/envs/hsp2_py38_dev/lib/python3.8/site-packages/h5py/_hl/files.py
# Docstring:      Represents an HDF5 file.
# Init docstring:
# Create a new file object.
#
# See the h5py user guide for a detailed explanation of the options.
#
# name
#     Name of the file on disk, or file-like object.  Note: for files
#     created with the 'core' driver, HDF5 still requires this be
#     non-empty.
# mode
#     r        Readonly, file must exist (default)
#     r+       Read/write, file must exist
#     w        Create file, truncate if exists
#     w- or x  Create file, fail if exists
#     a        Read/write if exists, create otherwise
# driver
#     Name of the driver to use.  Legal values are None (default,
#     recommended), 'core', 'sec2', 'stdio', 'mpio'.
# libver
#     Library version bounds.  Supported values: 'earliest', 'v108',
#     'v110', 'v112'  and 'latest'. The 'v108', 'v110' and 'v112'
#     options can only be specified with the HDF5 1.10.2 library or later.
# userblock_size
#     Desired size of user block.  Only allowed when creating a new
#     file (mode w, w- or x).
# swmr
#     Open the file in SWMR read mode. Only used when mode = 'r'.
# rdcc_nbytes
#     Total size of the raw data chunk cache in bytes. The default size
#     is 1024**2 (1 MB) per dataset.
# rdcc_w0
#     The chunk preemption policy for all datasets.  This must be
#     between 0 and 1 inclusive and indicates the weighting according to
#     which chunks which have been fully read or written are penalized
#     when determining which chunks to flush from cache.  A value of 0
#     means fully read or written chunks are treated no differently than
#     other chunks (the preemption is strictly LRU) while a value of 1
#     means fully read or written chunks are always preempted before
#     other chunks.  If your application only reads or writes data once,
#     this can be safely set to 1.  Otherwise, this should be set lower
#     depending on how often you re-read or re-write the same data.  The
#     default value is 0.75.
# rdcc_nslots
#     The number of chunk slots in the raw data chunk cache for this
#     file. Increasing this value reduces the number of cache collisions,
#     but slightly increases the memory used. Due to the hashing
#     strategy, this value should ideally be a prime number. As a rule of
#     thumb, this value should be at least 10 times the number of chunks
#     that can fit in rdcc_nbytes bytes. For maximum performance, this
#     value should be set approximately 100 times that number of
#     chunks. The default value is 521.
# track_order
#     Track dataset/group/attribute creation order under root group
#     if True. If None use global default h5.get_config().track_order.
# fs_strategy
#     The file space handling strategy to be used.  Only allowed when
#     creating a new file (mode w, w- or x).  Defined as:
#     "fsm"        FSM, Aggregators, VFD
#     "page"       Paged FSM, VFD
#     "aggregate"  Aggregators, VFD
#     "none"       VFD
#     If None use HDF5 defaults.
# fs_persist
#     A boolean value to indicate whether free space should be persistent
#     or not.  Only allowed when creating a new file.  The default value
#     is False.
# fs_threshold
#     The smallest free-space section size that the free space manager
#     will track.  Only allowed when creating a new file.  The default
#     value is 1.
# Additional keywords
#     Passed on to the selected file driver.

# %%
h5py_file.attrs
# Out:
# <Attributes of HDF5 object at 140644074207248>

# %%
h5py_file.keys()
# Out:
# <KeysViewHDF5 ['CONTROL', 'FTABLES', 'IMPLND', 'PERLND', 'RCHRES', 'RESULTS', 'RUN_INFO', 'TIMESERIES']>

# %%
for key in h5py_file.keys():
  print(key)
# Out:
# CONTROL
# FTABLES
# IMPLND
# PERLND
# RCHRES
# RESULTS
# RUN_INFO
# TIMESERIES

# %%
h5py_file['CONTROL'].keys()
# Out:
# <KeysViewHDF5 ['EXT_SOURCES', 'GLOBAL', 'LINKS', 'MASS_LINKS', 'OP_SEQUENCE']>

# %%
h5py_file['CONTROL']['GLOBAL'].keys()
# Out:
# <KeysViewHDF5 ['_i_table', 'table']>

# %%
key_list = [k for k in h5py_file.keys()]
key_list
# Out:
# ['CONTROL',
#  'FTABLES',
#  'IMPLND',
#  'PERLND',
#  'RCHRES',
#  'RESULTS',
#  'RUN_INFO',
#  'TIMESERIES']

# %%
for name in h5py_file:
    for subname in h5py_file[name]:
        print(name+r'\ '+subname)
#         print(r'')
#         for subsubname in h5py_file[name][subname]:
#             print(name+r'\ '+subname+r'\ '+subsubname)
# Out:
# CONTROL\ EXT_SOURCES
# CONTROL\ GLOBAL
# CONTROL\ LINKS
# CONTROL\ MASS_LINKS
# CONTROL\ OP_SEQUENCE
# FTABLES\ FT001
# FTABLES\ FT002
# FTABLES\ FT003
# FTABLES\ FT004
# FTABLES\ FT005
# IMPLND\ GENERAL
# IMPLND\ IQUAL
# IMPLND\ IWATER
# IMPLND\ IWTGAS
# IMPLND\ SNOW
# IMPLND\ SOLIDS
# PERLND\ GENERAL
# PERLND\ PSTEMP
# PERLND\ PWATER
# PERLND\ PWTGAS
# PERLND\ SNOW
# RCHRES\ CONS
# RCHRES\ GENERAL
# RCHRES\ GQUAL
# RCHRES\ HTRCH
# RCHRES\ HYDR
# RCHRES\ NUTRX
# RCHRES\ OXRX
# RCHRES\ PHCARB
# RCHRES\ PLANK
# RCHRES\ RQUAL
# RCHRES\ SEDTRN
# RESULTS\ IMPLND_I001
# RESULTS\ PERLND_P001
# RESULTS\ RCHRES_R001
# RESULTS\ RCHRES_R002
# RESULTS\ RCHRES_R003
# RESULTS\ RCHRES_R004
# RESULTS\ RCHRES_R005
# RUN_INFO\ LOGFILE
# RUN_INFO\ VERSIONS
# TIMESERIES\ LAPSE_Table
# TIMESERIES\ SEASONS_Table
# TIMESERIES\ SUMMARY
# TIMESERIES\ Saturated_Vapor_Pressure_Table
# TIMESERIES\ TS039
# TIMESERIES\ TS041
# TIMESERIES\ TS042
# TIMESERIES\ TS046
# TIMESERIES\ TS113
# TIMESERIES\ TS119
# TIMESERIES\ TS121
# TIMESERIES\ TS122
# TIMESERIES\ TS123
# TIMESERIES\ TS124
# TIMESERIES\ TS125
# TIMESERIES\ TS126
# TIMESERIES\ TS127
# TIMESERIES\ TS131
# TIMESERIES\ TS132
# TIMESERIES\ TS134
# TIMESERIES\ TS135
# TIMESERIES\ TS136
# TIMESERIES\ TS140

# %%
h5py_file.close()

# %%
h5py_file
# Out:
# <Closed HDF5 file>

# %% [markdown]
# ### h5py `h5dump` command line utility
#
# The command line “h5dump” utility can also be useful, but it is very verbose!
# https://nbviewer.jupyter.org/github/jackdbd/hdf5-pydata-munich/blob/master/hdf5_in_python.ipynb

# %%
# get path, as pathlib only works within Python and not at the operating system command prompt.
paths[0]
# Out:
# PosixPath('/Users/aaufdenkampe/Documents/Python/limno.HSPsquared/HSP2notebooks/Data/hsp2.h5')

# %%
# !h5dump '/Users/aaufdenkampe/Documents/Python/limno.HSPsquared/HSP2notebooks/Data/hsp2.h5'

# WARNING: This is extremely verbose!!!!
